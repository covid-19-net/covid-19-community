# %% [markdown]
# # Analyze SARS-CoV-2 3D Protein Structures
# [Work in progress]
#
# This notebook analyzes available 3D protein structures for the SAR-CoV-2 virus in the [Protein Data Bank](https://www.wwpdb.org/).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from py2neo import Graph

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %% [markdown]
# #### Connect to COVID-19-Community Knowledge Graph

# %%
graph = Graph("bolt://132.249.238.185:7687", user="reader", password="demo")

# %% [markdown]
# ### Number of PDB Structures by Protein

# %%
reference_genome = 'ncbiprotein:NC_045512' # Genbank reference sequence

# %%
query = """
MATCH (r:Strain{id: $reference_genome})-[:HAS]->(g:Gene)-[:ENCODES]->(p:Protein)
      -[:HAS_TERTIARY_STRUCTURE]->(:Chain)-[:IS_PART_OF_STRUCTURE]->(s:Structure)
WHERE (g.end - g.start) < 10000 // exclude polyproteins
RETURN r.id AS referenceGenome, r.name AS strain, g.name AS gene, g.start AS geneStart, g.end AS geneEnd, 
       p.name AS protein, p.accession AS accession, p.proId AS uniprotChain, count(s) AS structures
ORDER BY geneStart, accession, geneEnd DESC
"""
pdbs = graph.run(query, reference_genome=reference_genome).to_data_frame()
pdbs.head(1000)
# Out:
#           referenceGenome      strain    gene  geneStart  geneEnd  \
# 0   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab        266      805
# 1   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab       2720     8554
# 2   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      10055    10972
# 3   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      11843    12091
# 4   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      12092    12685
# 5   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      12686    13024
# 6   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      13025    13441
# 7   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      13442    16236
# 8   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      16237    18039
# 9   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      19621    20658
# 10  ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      20659    21552
# 11  ncbiprotein:NC_045512  Wuhan-Hu-1       S      21563    25384
# 12  ncbiprotein:NC_045512  Wuhan-Hu-1   ORF3a      25393    26220
# 13  ncbiprotein:NC_045512  Wuhan-Hu-1   ORF7a      27394    27759
# 14  ncbiprotein:NC_045512  Wuhan-Hu-1    ORF8      27894    28259
# 15  ncbiprotein:NC_045512  Wuhan-Hu-1       N      28274    29533
#
#                                 protein       accession  \
# 0       Host translation inhibitor nsp1  uniprot:P0DTD1
# 1              Non-structural protein 3  uniprot:P0DTD1
# 2                    3C-like proteinase  uniprot:P0DTD1
# 3              Non-structural protein 7  uniprot:P0DTD1
# 4              Non-structural protein 8  uniprot:P0DTD1
# 5              Non-structural protein 9  uniprot:P0DTD1
# 6             Non-structural protein 10  uniprot:P0DTD1
# 7           RNA-directed RNA polymerase  uniprot:P0DTD1
# 8                              Helicase  uniprot:P0DTD1
# 9   Uridylate-specific endoribonuclease  uniprot:P0DTD1
# 10               2'-O-methyltransferase  uniprot:P0DTD1
# 11                   Spike glycoprotein  uniprot:P0DTC2
# 12                        ORF3a protein  uniprot:P0DTC3
# 13                        ORF7a protein  uniprot:P0DTC7
# 14                         ORF8 protein  uniprot:P0DTC8
# 15                        Nucleoprotein  uniprot:P0DTC9
#
#                     uniprotChain  structures
# 0   uniprot.chain:PRO_0000449619          11
# 1   uniprot.chain:PRO_0000449621          59
# 2   uniprot.chain:PRO_0000449623         205
# 3   uniprot.chain:PRO_0000449625          23
# 4   uniprot.chain:PRO_0000449626          33
# 5   uniprot.chain:PRO_0000449627           7
# 6   uniprot.chain:PRO_0000449628          21
# 7   uniprot.chain:PRO_0000449629          11
# 8   uniprot.chain:PRO_0000449630           4
# 9   uniprot.chain:PRO_0000449632          14
# 10  uniprot.chain:PRO_0000449633          19
# 11                          None         206
# 12  uniprot.chain:PRO_0000449650           2
# 13                          None           1
# 14                          None           2
# 15  uniprot.chain:PRO_0000449656          42

# %% [markdown]
# ### Number of structures by protein and structure determination method

# %%
query = """
MATCH (r:Strain{id: $reference_genome})-[:HAS]->(g:Gene)-[:ENCODES]->(p:Protein)
      -[:HAS_TERTIARY_STRUCTURE]->(:Chain)-[:IS_PART_OF_STRUCTURE]->(s:Structure)
WHERE (g.end - g.start) < 10000 // exclude polyproteins
RETURN r.id AS referenceGenome, r.name AS strain, g.name AS gene, g.start AS geneStart, g.end AS geneEnd, 
       p.name AS protein, p.accession AS accession, p.proId AS uniprotChain, s.method AS method, count(s.method) AS structures
ORDER BY geneStart, accession, geneEnd DESC
"""
pdbs = graph.run(query, reference_genome=reference_genome).to_data_frame()
pdbs.head(1000)
# Out:
#           referenceGenome      strain    gene  geneStart  geneEnd  \
# 0   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab        266      805
# 1   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab       2720     8554
# 2   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      10055    10972
# 3   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      11843    12091
# 4   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      11843    12091
# 5   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      12092    12685
# 6   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      12092    12685
# 7   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      12686    13024
# 8   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      13025    13441
# 9   ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      13442    16236
# 10  ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      16237    18039
# 11  ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      16237    18039
# 12  ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      19621    20658
# 13  ncbiprotein:NC_045512  Wuhan-Hu-1  ORF1ab      20659    21552
# 14  ncbiprotein:NC_045512  Wuhan-Hu-1       S      21563    25384
# 15  ncbiprotein:NC_045512  Wuhan-Hu-1       S      21563    25384
# 16  ncbiprotein:NC_045512  Wuhan-Hu-1   ORF3a      25393    26220
# 17  ncbiprotein:NC_045512  Wuhan-Hu-1   ORF7a      27394    27759
# 18  ncbiprotein:NC_045512  Wuhan-Hu-1    ORF8      27894    28259
# 19  ncbiprotein:NC_045512  Wuhan-Hu-1       N      28274    29533
# 20  ncbiprotein:NC_045512  Wuhan-Hu-1       N      28274    29533
#
#                                 protein       accession  \
# 0       Host translation inhibitor nsp1  uniprot:P0DTD1
# 1              Non-structural protein 3  uniprot:P0DTD1
# 2                    3C-like proteinase  uniprot:P0DTD1
# 3              Non-structural protein 7  uniprot:P0DTD1
# 4              Non-structural protein 7  uniprot:P0DTD1
# 5              Non-structural protein 8  uniprot:P0DTD1
# 6              Non-structural protein 8  uniprot:P0DTD1
# 7              Non-structural protein 9  uniprot:P0DTD1
# 8             Non-structural protein 10  uniprot:P0DTD1
# 9           RNA-directed RNA polymerase  uniprot:P0DTD1
# 10                             Helicase  uniprot:P0DTD1
# 11                             Helicase  uniprot:P0DTD1
# 12  Uridylate-specific endoribonuclease  uniprot:P0DTD1
# 13               2'-O-methyltransferase  uniprot:P0DTD1
# 14                   Spike glycoprotein  uniprot:P0DTC2
# 15                   Spike glycoprotein  uniprot:P0DTC2
# 16                        ORF3a protein  uniprot:P0DTC3
# 17                        ORF7a protein  uniprot:P0DTC7
# 18                         ORF8 protein  uniprot:P0DTC8
# 19                        Nucleoprotein  uniprot:P0DTC9
# 20                        Nucleoprotein  uniprot:P0DTC9
#
#                     uniprotChain               method  structures
# 0   uniprot.chain:PRO_0000449619  ELECTRON MICROSCOPY          11
# 1   uniprot.chain:PRO_0000449621    X-RAY DIFFRACTION          59
# 2   uniprot.chain:PRO_0000449623    X-RAY DIFFRACTION         205
# 3   uniprot.chain:PRO_0000449625  ELECTRON MICROSCOPY          11
# 4   uniprot.chain:PRO_0000449625    X-RAY DIFFRACTION          12
# 5   uniprot.chain:PRO_0000449626  ELECTRON MICROSCOPY          21
# 6   uniprot.chain:PRO_0000449626    X-RAY DIFFRACTION          12
# 7   uniprot.chain:PRO_0000449627    X-RAY DIFFRACTION           7
# 8   uniprot.chain:PRO_0000449628    X-RAY DIFFRACTION          21
# 9   uniprot.chain:PRO_0000449629  ELECTRON MICROSCOPY          11
# 10  uniprot.chain:PRO_0000449630    X-RAY DIFFRACTION           2
# 11  uniprot.chain:PRO_0000449630  ELECTRON MICROSCOPY           2
# 12  uniprot.chain:PRO_0000449632    X-RAY DIFFRACTION          14
# 13  uniprot.chain:PRO_0000449633    X-RAY DIFFRACTION          19
# 14                          None  ELECTRON MICROSCOPY         160
# 15                          None    X-RAY DIFFRACTION          46
# 16  uniprot.chain:PRO_0000449650  ELECTRON MICROSCOPY           2
# 17                          None    X-RAY DIFFRACTION           1
# 18                          None    X-RAY DIFFRACTION           2
# 19  uniprot.chain:PRO_0000449656    X-RAY DIFFRACTION          41
# 20  uniprot.chain:PRO_0000449656         SOLUTION NMR           1

# %% [markdown]
# ### Number of structures by protein and release date

# %%
query = """
MATCH (r:Strain{id: $reference_genome})-[:HAS]->(g:Gene)-[:ENCODES]->(p:Protein)
      -[:HAS_TERTIARY_STRUCTURE]->(:Chain)-[:IS_PART_OF_STRUCTURE]->(s:Structure)
WHERE (g.end - g.start) < 10000 // exclude polyproteins
RETURN p.name AS protein, s.releaseDate AS releaseDate, count(s.releaseDate) AS structures
ORDER BY protein, releaseDate
"""
pdbs_by_date = graph.run(query, reference_genome=reference_genome).to_data_frame()

# %%
pdbs_by_date['cummulativeStructures'] = pdbs_by_date.groupby(['protein'])['structures'].cumsum()

# %%
pdbs_by_date.head()
# Out:
#                   protein releaseDate  structures  cummulativeStructures
# 0  2'-O-methyltransferase  2020-03-17           1                      1
# 1  2'-O-methyltransferase  2020-03-24           2                      3
# 2  2'-O-methyltransferase  2020-04-21           2                      5
# 3  2'-O-methyltransferase  2020-04-28           2                      7
# 4  2'-O-methyltransferase  2020-05-05           2                      9

# %%
df_date = pd.DataFrame(pdbs_by_date.pivot(index='releaseDate', columns='protein', values='cummulativeStructures').to_records())

# %% [markdown]
# Convert neo4j date object to datetime

# %%
df_date['releaseDate'] = df_date['releaseDate'].astype(str)
df_date['releaseDate'] = pd.to_datetime(df_date['releaseDate'], infer_datetime_format=False)

# %% [markdown]
# Fill gaps by value from previous day

# %%
df_date.fillna(method='ffill', inplace=True)
df_date['releaseDate'] = pd.to_datetime(df_date['releaseDate'], infer_datetime_format=False)

# %%
df_date.head(1000)
# Out:
#    releaseDate  2'-O-methyltransferase  3C-like proteinase  Helicase  \
# 0   2020-02-04                     NaN                 1.0       NaN
# 1   2020-02-25                     NaN                 1.0       NaN
# 2   2020-03-03                     NaN                 5.0       NaN
# 3   2020-03-10                     NaN                14.0       NaN
# 4   2020-03-17                     1.0                14.0       NaN
# 5   2020-03-24                     3.0                84.0       NaN
# 6   2020-03-31                     3.0                85.0       NaN
# 7   2020-04-07                     3.0                85.0       NaN
# 8   2020-04-14                     3.0               106.0       NaN
# 9   2020-04-21                     5.0               107.0       NaN
# 10  2020-04-28                     7.0               111.0       NaN
# 11  2020-05-05                     9.0               114.0       NaN
# 12  2020-05-12                    12.0               119.0       NaN
# 13  2020-05-19                    12.0               128.0       NaN
# 14  2020-05-26                    14.0               146.0       NaN
# 15  2020-06-02                    14.0               146.0       NaN
# 16  2020-06-09                    14.0               151.0       NaN
# 17  2020-06-16                    15.0               164.0       NaN
# 18  2020-06-23                    15.0               166.0       NaN
# 19  2020-06-30                    15.0               168.0       NaN
# 20  2020-07-07                    16.0               175.0       NaN
# 21  2020-07-14                    16.0               179.0       NaN
# 22  2020-07-21                    16.0               183.0       NaN
# 23  2020-07-28                    16.0               186.0       4.0
# 24  2020-08-04                    16.0               186.0       4.0
# 25  2020-08-11                    16.0               188.0       4.0
# 26  2020-08-18                    16.0               191.0       4.0
# 27  2020-08-25                    19.0               193.0       4.0
# 28  2020-09-01                    19.0               203.0       4.0
# 29  2020-09-08                    19.0               205.0       4.0
#
#     Host translation inhibitor nsp1  Non-structural protein 10  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        1.0
# 5                               NaN                        4.0
# 6                               NaN                        4.0
# 7                               NaN                        4.0
# 8                               NaN                        4.0
# 9                               NaN                        6.0
# 10                              NaN                        8.0
# 11                              NaN                       10.0
# 12                              NaN                       13.0
# 13                              NaN                       13.0
# 14                              NaN                       15.0
# 15                              NaN                       15.0
# 16                              NaN                       15.0
# 17                              NaN                       16.0
# 18                              NaN                       17.0
# 19                              NaN                       17.0
# 20                              NaN                       18.0
# 21                              NaN                       18.0
# 22                              1.0                       18.0
# 23                              7.0                       18.0
# 24                              7.0                       18.0
# 25                              8.0                       18.0
# 26                             11.0                       18.0
# 27                             11.0                       21.0
# 28                             11.0                       21.0
# 29                             11.0                       21.0
#
#     Non-structural protein 3  Non-structural protein 7  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        2.0                       NaN
# 3                        4.0                       NaN
# 4                        4.0                       NaN
# 5                        6.0                       NaN
# 6                        9.0                       1.0
# 7                        9.0                       2.0
# 8                       11.0                       2.0
# 9                       11.0                       5.0
# 10                      12.0                       7.0
# 11                      30.0                       9.0
# 12                      31.0                      12.0
# 13                      36.0                      12.0
# 14                      37.0                      13.0
# 15                      37.0                      15.0
# 16                      37.0                      15.0
# 17                      41.0                      16.0
# 18                      42.0                      16.0
# 19                      42.0                      18.0
# 20                      42.0                      18.0
# 21                      42.0                      18.0
# 22                      42.0                      18.0
# 23                      42.0                      20.0
# 24                      46.0                      20.0
# 25                      47.0                      20.0
# 26                      47.0                      20.0
# 27                      49.0                      22.0
# 28                      59.0                      23.0
# 29                      59.0                      23.0
#
#     Non-structural protein 8  Non-structural protein 9  Nucleoprotein  \
# 0                        NaN                       NaN            NaN
# 1                        NaN                       NaN            NaN
# 2                        NaN                       NaN            NaN
# 3                        NaN                       NaN            4.0
# 4                        NaN                       2.0            8.0
# 5                        NaN                       2.0            8.0
# 6                        2.0                       2.0            8.0
# 7                        4.0                       3.0            9.0
# 8                        4.0                       3.0            9.0
# 9                        8.0                       3.0           15.0
# 10                      10.0                       3.0           19.0
# 11                      12.0                       3.0           19.0
# 12                      16.0                       3.0           19.0
# 13                      16.0                       5.0           25.0
# 14                      18.0                       5.0           33.0
# 15                      22.0                       5.0           33.0
# 16                      22.0                       5.0           33.0
# 17                      23.0                       5.0           33.0
# 18                      23.0                       5.0           33.0
# 19                      25.0                       5.0           34.0
# 20                      25.0                       5.0           34.0
# 21                      25.0                       5.0           34.0
# 22                      25.0                       5.0           34.0
# 23                      29.0                       5.0           34.0
# 24                      29.0                       7.0           34.0
# 25                      29.0                       7.0           34.0
# 26                      29.0                       7.0           34.0
# 27                      31.0                       7.0           34.0
# 28                      33.0                       7.0           42.0
# 29                      33.0                       7.0           42.0
#
#     ORF3a protein  ORF7a protein  ORF8 protein  RNA-directed RNA polymerase  \
# 0             NaN            NaN           NaN                          NaN
# 1             NaN            NaN           NaN                          NaN
# 2             NaN            NaN           NaN                          NaN
# 3             NaN            NaN           NaN                          NaN
# 4             NaN            NaN           NaN                          NaN
# 5             NaN            NaN           NaN                          NaN
# 6             NaN            NaN           NaN                          1.0
# 7             NaN            NaN           NaN                          2.0
# 8             NaN            NaN           NaN                          2.0
# 9             NaN            NaN           NaN                          4.0
# 10            NaN            1.0           NaN                          4.0
# 11            NaN            1.0           NaN                          4.0
# 12            NaN            1.0           NaN                          5.0
# 13            NaN            1.0           NaN                          5.0
# 14            NaN            1.0           NaN                          6.0
# 15            NaN            1.0           NaN                          8.0
# 16            NaN            1.0           NaN                          8.0
# 17            2.0            1.0           NaN                          8.0
# 18            2.0            1.0           NaN                          8.0
# 19            2.0            1.0           NaN                          8.0
# 20            2.0            1.0           NaN                          8.0
# 21            2.0            1.0           NaN                          8.0
# 22            2.0            1.0           NaN                          8.0
# 23            2.0            1.0           NaN                         10.0
# 24            2.0            1.0           NaN                         10.0
# 25            2.0            1.0           NaN                         10.0
# 26            2.0            1.0           NaN                         10.0
# 27            2.0            1.0           2.0                         10.0
# 28            2.0            1.0           2.0                         11.0
# 29            2.0            1.0           2.0                         11.0
#
#     Spike glycoprotein  Uridylate-specific endoribonuclease
# 0                  NaN                                  NaN
# 1                 13.0                                  NaN
# 2                 15.0                                  2.0
# 3                 23.0                                  4.0
# 4                 25.0                                  4.0
# 5                 26.0                                  4.0
# 6                 26.0                                  4.0
# 7                 26.0                                  4.0
# 8                 28.0                                  4.0
# 9                 28.0                                  4.0
# 10                31.0                                  6.0
# 11                31.0                                  6.0
# 12                32.0                                  6.0
# 13                32.0                                  8.0
# 14                52.0                                 10.0
# 15                62.0                                 12.0
# 16                68.0                                 12.0
# 17                68.0                                 14.0
# 18                76.0                                 14.0
# 19               104.0                                 14.0
# 20               112.0                                 14.0
# 21               115.0                                 14.0
# 22               145.0                                 14.0
# 23               165.0                                 14.0
# 24               168.0                                 14.0
# 25               181.0                                 14.0
# 26               184.0                                 14.0
# 27               198.0                                 14.0
# 28               206.0                                 14.0
# 29               206.0                                 14.0

# %% [markdown]
# #### TODO: use scatter plot instead of line plot since release dates are not continuous

# %%
import matplotlib.dates as mdates
ax = df_date.plot(figsize=(16, 8), x='releaseDate', title='Cummulative SARS-CoV-2 structures by release date');
ax.set_xlabel('Release Date');
ax.set_ylabel('Structures');
ax.fmt_xdata = mdates.DateFormatter('%Y-%m-%d')
