# %% [markdown]
# # Example queries for biological entities on COVID-19 Knowledge Graph
# [Work in progress]
#
# This notebook demonstrates how to run Cypher queries in a Jupyter Notebook by connecting to a database server.

# %%
import os
import time
import pandas as pd
from py2neo import Graph

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
graph = Graph("bolt://132.249.238.185:7687", user="reader", password="demo")

# %% [markdown]
# ### List Node Metadata

# %%
query = """
MATCH (n:NodeMetadata)
RETURN n.name, n.shortDescription, n.description, n.example, n.details
"""
graph.run(query).to_data_frame()
# Out:
#                   n.name                            n.shortDescription  \
# 0               Location                           Geographic location
# 1                  World                                     The World
# 2               UNRegion                           Continental regions
# 3            UNSubRegion                        Subcontinental regions
# 4   UNIntermediateRegion        Subdivisions of subcontinental regions
# 5                Country           Countries and dependent Territories
# 6                 Admin1                 State, Province, Municipality
# 7                 Admin2                                        County
# 8                   City                                          City
# 9               USRegion                             Regions of the US
# 10            USDivision                              Subregions of US
# 11                 Cases                                   Case counts
# 12              Outbreak                 Increase in disease occurance
# 13              Organism                                 Living system
# 14                Strain                Genetic variant of an organism
# 15                 Clade  Group of organisms based on common ancestors
# 16                Genome                              Genetic material
# 17                  Gene                             SARS-CoV-2 S gene
# 18               Protein                       Sequence of amino acids
# 19           Publication                            Published document
#
#                                         n.description  \
# 0                                A geograpic location
# 1                                  Top level location
# 2    Continental regions according to the M49 stan...
# 3   Subcontinental regions according to the M49 st...
# 4   Subdivisions of subcontinental regions accordi...
# 5    Countries and dependent Territories defined b...
# 6   First administrative divisions, e.g, State, Pr...
# 7   Second administrative divisions: County in the US
# 8                                                City
# 9             Regions defined by the US Census Bureau
# 10           Divisions defined by the US Census Burea
# 11  Number of case for outbreaks or diseases at sp...
# 12  Statistically significant increase in disease ...
# 13  Individual living system, such as animal, plan...
# 14  A population of organisms that is geneticaly d...
# 15  An identifier that denotes a group of organism...
# 16  A genome is the sum of genetic material within...
# 17                            Sequence of nucleotides
# 18  Proteins are large biomolecules consisting of ...
# 19   A document that has been accepted by a publisher
#
#                                             n.example  \
# 0   World, ..., Country, State, Country, City, Cru...
# 1                                                None
# 2                                            Americas
# 3                     Latin America and the Caribbean
# 4                                           Caribbean
# 5                                       United States
# 6                                          California
# 7                                    San Diego County
# 8                                           San Diego
# 9                                         West Region
# 10                                   Pacific Division
# 11                                  COVID-19-YYYYMMDD
# 12                                           COVID-19
# 13                                       Homo sapiens
# 14                                    COVID-19 strain
# 15                                       SARS-CoV-2 A
# 16                                  SARS-CoV-2 genome
# 17  Sequence of nucleotides in DNA or RNA that enc...
# 18                                      Spike protein
# 19                                               None
#
#                                             n.details
# 0                                                None
# 1                                                None
# 2        https://unstats.un.org/unsd/methodology/m49/
# 3        https://unstats.un.org/unsd/methodology/m49/
# 4        https://unstats.un.org/unsd/methodology/m49/
# 5                            http://www.geonames.org/
# 6                            http://www.geonames.org/
# 7                            http://www.geonames.org/
# 8                            http://www.geonames.org/
# 9   https://www.census.gov/geographies/reference-f...
# 10  https://www.census.gov/geographies/reference-f...
# 11                                               None
# 12         http://purl.obolibrary.org/obo/IDO_0000502
# 13         http://purl.obolibrary.org/obo/OBI_0100026
# 14  https://semanticscience.org/resource/SIO_01005...
# 15  http://purl.obolibrary.org/obo/APOLLO_SV_00000232
# 16          http://purl.obolibrary.org/obo/SO_0001026
# 17                                               None
# 18          http://purl.obolibrary.org/obo/SO_0000104
# 19  http://www.ontobee.org/ontology/IAO?iri=http:/...

# %% [markdown]
# ### List Organisms in KG

# %%
query = """
MATCH (p:Organism)
RETURN p.name as name, p.scientificName as scientificName, p.id as taxonomy
"""
graph.run(query).to_data_frame()
# Out:
#                           name  \
# 0                   SARS-CoV-2
# 1                     MERS-CoV
# 2                     SARS-CoV
# 3                        human
# 4   intermediate horseshoe bat
# 5        Malayan horseshoe bat
# 6                horseshoe bat
# 7             Malayan pangolin
# 8                   palm civet
# 9                   carnivores
# 10                         cat
# 11               European mink
# 12               Malayan tiger
#
#                                        scientificName          taxonomy
# 0     Severe acute respiratory syndrome coronavirus 2  taxonomy:2697049
# 1   Middle East respiratory syndrome-related coron...  taxonomy:1335626
# 2   Severe acute respiratory syndrome-related coro...   taxonomy:694009
# 3                                        Homo sapiens     taxonomy:9606
# 4                                Rhinolophus affinis     taxonomy:59477
# 5                               Rhinolophus malayanus   taxonomy:608659
# 6                                         Rhinolophus    taxonomy:49442
# 7                                      Manis javanica     taxonomy:9974
# 8                                         Paradoxurus    taxonomy:71116
# 9                                             Canidae     taxonomy:9608
# 10                                        Felis catus     taxonomy:9685
# 11                                   Mustela lutreola     taxonomy:9666
# 12                           Panthera tigris jacksoni   taxonomy:419130

# %% [markdown]
# ### List Coronavirus Outbreaks

# %%
query = """
MATCH (p:Organism)-[:CAUSES]->(o:Outbreak)
RETURN p.name as name, p.scientificName as scientificName, p.id as taxonomy, o.id as outbreak, o.startDate as startDate
"""
graph.run(query).to_data_frame()
# Out:
#          name                                     scientificName  \
# 0  SARS-CoV-2    Severe acute respiratory syndrome coronavirus 2
# 1    MERS-CoV  Middle East respiratory syndrome-related coron...
# 2    SARS-CoV  Severe acute respiratory syndrome-related coro...
#
#            taxonomy  outbreak startDate
# 0  taxonomy:2697049  COVID-19      2019
# 1  taxonomy:1335626      MERS      2012
# 2   taxonomy:694009      SARS      2003

# %% [markdown]
# ### List Strains that are mentioned in PubMed Central Articles

# %%
query = """
MATCH (p:Publication)-[:MENTIONS]->(s:Strain)<-[:CARRIES]-(o:Organism)
RETURN p.id as pmc, s.name as name, s.collectionDate  as collectionDate, o.name as host, s.id as host_id
ORDER by s.collectionDate
"""
graph.run(query).to_data_frame().head(20)
# Out:
#                pmc                              name collectionDate   host  \
# 0   pmc:PMC7106203          BetaCoV/Wuhan/WH-01/2019     2019-12-26  human
# 1   pmc:PMC7106203  BetaCoV/Wuhan/IPBCAMS-WH-03/2019     2019-12-30  human
# 2   pmc:PMC7106203                             WIV02     2019-12-30  human
# 3   pmc:PMC7106203                             WIV05     2019-12-30  human
# 4   pmc:PMC7045880     BetaCoV/Wuhan/IVDC-HB-01/2019     2019-12-30  human
# 5   pmc:PMC7224157                             WIV04     2019-12-30  human
# 6   pmc:PMC7228367                        Wuhan-Hu-1     2019-12-30  human
# 7   pmc:PMC7228367  BetaCoV/Wuhan/IPBCAMS-WH-03/2019     2019-12-30  human
# 8   pmc:PMC7228367                             WIV04     2019-12-30  human
# 9   pmc:PMC7108203     BetaCoV/Wuhan/IVDC-HB-05/2019     2019-12-30  human
# 10  pmc:PMC7108203     BetaCoV/Wuhan/IVDC-HB-01/2019     2019-12-30  human
# 11  pmc:PMC7108203                             WIV04     2019-12-30  human
# 12  pmc:PMC7095418                             WIV04     2019-12-30  human
# 13  pmc:PMC7095418                             WIV02     2019-12-30  human
# 14  pmc:PMC7118693                             WIV02     2019-12-30  human
# 15  pmc:PMC7211182                             WIV02     2019-12-30  human
# 16  pmc:PMC7156227                        Wuhan-Hu-1     2019-12-30  human
# 17  pmc:PMC7233248                        Wuhan-Hu-1     2019-12-30  human
# 18  pmc:PMC7166825                        Wuhan-Hu-1     2019-12-30  human
# 19  pmc:PMC7102556                             WIV04     2019-12-30  human
#
#                                   host_id
# 0   https://www.gisaid.org/EPI_ISL_406798
# 1   https://www.gisaid.org/EPI_ISL_403930
# 2   https://www.gisaid.org/EPI_ISL_402127
# 3   https://www.gisaid.org/EPI_ISL_402128
# 4   https://www.gisaid.org/EPI_ISL_402119
# 5   https://www.gisaid.org/EPI_ISL_402124
# 6   https://www.gisaid.org/EPI_ISL_402125
# 7   https://www.gisaid.org/EPI_ISL_403930
# 8   https://www.gisaid.org/EPI_ISL_402124
# 9   https://www.gisaid.org/EPI_ISL_402121
# 10  https://www.gisaid.org/EPI_ISL_402119
# 11  https://www.gisaid.org/EPI_ISL_402124
# 12  https://www.gisaid.org/EPI_ISL_402124
# 13  https://www.gisaid.org/EPI_ISL_402127
# 14  https://www.gisaid.org/EPI_ISL_402127
# 15  https://www.gisaid.org/EPI_ISL_402127
# 16  https://www.gisaid.org/EPI_ISL_402125
# 17  https://www.gisaid.org/EPI_ISL_402125
# 18  https://www.gisaid.org/EPI_ISL_402125
# 19  https://www.gisaid.org/EPI_ISL_402124

# %% [markdown]
# ### List Gene and Protein information for Reference Genome
# This query lists the genes and proteins encoded by the SARS-CoV-2 reference genome. This is the first genome of SARS-CoV-2 collected in Wuhan on Dec. 5, 2019.

# %%
query = """
MATCH (s:Strain)-[:HAS]->(g:Gene)-[:ENCODES]->(p:Protein)
RETURN s.id as referenceGenome, s.name as name, s.collectionDate  as collectionDate, 
       g.name as gene, g.id as geneId, p.name as protein, p.id as protein_id 
ORDER by s.collectionDate
"""
graph.run(query).to_data_frame()
# Out:
#           referenceGenome        name collectionDate    gene  \
# 0   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 1   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 2   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06       S
# 3   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06   ORF3a
# 4   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06       E
# 5   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06       M
# 6   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06    ORF6
# 7   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06   ORF7a
# 8   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06   ORF7b
# 9   ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06    ORF8
# 10  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06       N
# 11  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06   ORF10
# 12  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 13  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 14  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 15  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 16  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 17  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 18  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 19  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 20  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 21  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 22  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 23  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 24  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 25  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 26  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
# 27  ncbiprotein:NC_045512  Wuhan-Hu-1     2019-12-06  ORF1ab
#
#                          geneId                              protein  \
# 0     ncbigene:4374057826621555            Replicase polyprotein 1ab
# 1     ncbigene:4374057826613483             Replicase polyprotein 1a
# 2   ncbigene:437405682156325384                   Spike glycoprotein
# 3   ncbigene:437405692539326220                           Protein 3a
# 4   ncbigene:437405702624526472      Envelope small membrane protein
# 5   ncbigene:437405712652327191                     Membrane protein
# 6   ncbigene:437405722720227387             Non-structural protein 6
# 7   ncbigene:437405732739427759                           Protein 7a
# 8   ncbigene:437405742775627887            Protein non-structural 7b
# 9   ncbigene:437405772789428259             Non-structural protein 8
# 10  ncbigene:437405752827429533                        Nucleoprotein
# 11  ncbigene:437405762955829674                        ORF10 protein
# 12      ncbigene:43740578266805      Host translation inhibitor nsp1
# 13     ncbigene:437405788062719             Non-structural protein 2
# 14    ncbigene:4374057827208554             Non-structural protein 3
# 15   ncbigene:43740578855510054             Non-structural protein 4
# 16  ncbigene:437405781005510972                   3C-like proteinase
# 17  ncbigene:437405781097311842             Non-structural protein 6
# 18  ncbigene:437405781184312091             Non-structural protein 7
# 19  ncbigene:437405781209212685             Non-structural protein 8
# 20  ncbigene:437405781268613024             Non-structural protein 9
# 21  ncbigene:437405781302513441            Non-structural protein 10
# 22  ncbigene:437405781344216236          RNA-directed RNA polymerase
# 23  ncbigene:437405781623718039                             Helicase
# 24  ncbigene:437405781804019620         Proofreading exoribonuclease
# 25  ncbigene:437405781962120658  Uridylate-specific endoribonuclease
# 26  ncbigene:437405782065921552               2'-O-methyltransferase
# 27  ncbigene:437405781344213480            Non-structural protein 11
#
#                               protein_id
# 0   md5:e6608b50fcd6e004708a875615ddf2d9
# 1   md5:e781b58591b8dbdd15f84dcbdec82105
# 2   md5:4c35f09aac2f7be4f3cffd30c6aecac8
# 3   md5:f5c8b89ceac3f14e456577557df1ef40
# 4   md5:375e0f905c315e06a99c80b736c125d2
# 5   md5:1cd6abff79ad3633e17582eb0e576539
# 6   md5:90b50e0be9abd893bd32b163d6933f0c
# 7   md5:f65213344e2e68de1cae4feb9c5e07b1
# 8   md5:c7f0179da4ca26456ee905081f485cc8
# 9   md5:3a77ad9207d29beacfbf6f18b0da9e26
# 10  md5:b100d0849c3e01fc6c75ead0e916ce0f
# 11  md5:06bfef85cf1319e805e05f5bee3ec601
# 12  md5:5c2c364f44079728c451280435c4236a
# 13  md5:073edb2349ddcd9a72ecd9f5c1dccdc4
# 14  md5:73935ca55d0ab6130627210ef6743c39
# 15  md5:6890e7e8e12f73c2dfdae6805ebc9c4f
# 16  md5:dc6436f559bc873ac013085f6e56d467
# 17  md5:99424071c355c54269f6cd3522680033
# 18  md5:173be79f5a6fd85a7edb5c75cdc41fa3
# 19  md5:92ebecdcff1a59d6123f4e3133264695
# 20  md5:8c32758bc2f4b49ed8c6dfe7caa7ea49
# 21  md5:af0cec59296f3c845a7b04500cd6886b
# 22  md5:b88e641d00c17a3ce19cc9852c37717c
# 23  md5:a489cf148afc7205eec14549ffe4ebfd
# 24  md5:96fda12ecf3dcfec082377cc27e80e55
# 25  md5:d7d018de059ea6b8c092267ff6371d38
# 26  md5:42b973dceb72cdea04fda203c55b67bc
# 27  md5:63d2c81f37726f44c600eb5225676a66

# %% [markdown]
# ### Find Mutations in the SARS-CoV-2 "S" gene
# The S gene is translated by the human or other species to the spike protein, which binds the human ACE2 receptor to gain entrance into the cell. Here we compare the mutations (missense mutations) found at different locations.

# %%
query = """
MATCH (g:Gene{name:'S'})-[:HAS_VARIANT]->(v:Variant{variantConsequence:'missense_variant'})
<-[:HAS_VARIANT]-(s:Strain)-[:FOUND_IN]->(l:Location)-[:IN*]->(r:USRegion{name:$region}) 
RETURN v.name AS mutation, l.name AS location, r.name AS region
ORDER BY v.name, l.name
"""

# %% [markdown]
# ##### Variants in the US West Region

# %%
region = 'West Region'
graph.run(query, region=region).to_data_frame().head(100)
# Out:
#            mutation           location       region
# 0   S:c.1042Gca>Aca         Washington  West Region
# 1   S:c.1042Gca>Aca         Washington  West Region
# 2   S:c.1151cCt>cTt        King County  West Region
# 3   S:c.1151cCt>cTt          San Diego  West Region
# 4   S:c.1153Act>Gct  Washington County  West Region
# 5   S:c.1183Gtc>Atc          San Diego  West Region
# 6   S:c.1214gAt>gTt            Arizona  West Region
# 7   S:c.1240Caa>Gaa            Arizona  West Region
# 8   S:c.1240Caa>Gaa            Arizona  West Region
# 9   S:c.1240Caa>Gaa            Arizona  West Region
# 10  S:c.1240Caa>Gaa            Arizona  West Region
# 11  S:c.1240Caa>Gaa            Arizona  West Region
# 12  S:c.1240Caa>Gaa            Arizona  West Region
# 13  S:c.1241cAa>cCa            Arizona  West Region
# 14    S:c.13Ctt>Ttt            Arizona  West Region
# 15    S:c.13Ctt>Ttt             Nevada  West Region
# 16    S:c.13Ctt>Ttt             Nevada  West Region
# 17    S:c.13Ctt>Ttt      Pierce County  West Region
# 18    S:c.13Ctt>Ttt      Pierce County  West Region
# 19    S:c.13Ctt>Ttt      Pierce County  West Region
# 20    S:c.13Ctt>Ttt      Pierce County  West Region
# 21    S:c.13Ctt>Ttt      Pierce County  West Region
# 22    S:c.13Ctt>Ttt      Skagit County  West Region
# 23    S:c.13Ctt>Ttt         Washington  West Region
# 24    S:c.13Ctt>Ttt         Washington  West Region
# 25    S:c.13Ctt>Ttt      Yakima County  West Region
# 26    S:c.13Ctt>Ttt      Yakima County  West Region
# 27    S:c.13Ctt>Ttt      Yakima County  West Region
# 28    S:c.13Ctt>Ttt      Yakima County  West Region
# 29    S:c.13Ctt>Ttt      Yakima County  West Region
# 30    S:c.13Ctt>Ttt      Yakima County  West Region
# 31  S:c.1424gCc>gTc            Arizona  West Region
# 32  S:c.1424gCc>gTc            Arizona  West Region
# 33  S:c.1426Ggt>Agt              Idaho  West Region
# 34  S:c.1426Ggt>Agt              Idaho  West Region
# 35  S:c.1426Ggt>Agt             Oregon  West Region
# 36  S:c.1426Ggt>Agt             Oregon  West Region
# 37  S:c.1426Ggt>Agt   Snohomish County  West Region
# 38  S:c.1426Ggt>Agt   Snohomish County  West Region
# 39  S:c.1426Ggt>Agt         Washington  West Region
# 40  S:c.1426Ggt>Agt         Washington  West Region
# 41  S:c.1448gTt>gCt        King County  West Region
# 42  S:c.1448gTt>gCt        King County  West Region
# 43  S:c.1448gTt>gCt        King County  West Region
# 44  S:c.1448gTt>gCt        King County  West Region
# 45  S:c.1448gTt>gCt        King County  West Region
# 46  S:c.1448gTt>gCt        King County  West Region
# 47  S:c.1448gTt>gCt        King County  West Region
# 48  S:c.1448gTt>gCt        King County  West Region
# 49  S:c.1448gTt>gCt   Snohomish County  West Region
# 50  S:c.1448gTt>gCt   Snohomish County  West Region
# 51  S:c.1448gTt>gCt         Washington  West Region
# 52  S:c.1448gTt>gCt         Washington  West Region
# 53  S:c.1448gTt>gCt         Washington  West Region
# 54  S:c.1448gTt>gCt         Washington  West Region
# 55  S:c.1448gTt>gCt         Washington  West Region
# 56  S:c.1448gTt>gCt         Washington  West Region
# 57  S:c.1448gTt>gCt         Washington  West Region
# 58  S:c.1448gTt>gCt         Washington  West Region
# 59  S:c.1448gTt>gCt         Washington  West Region
# 60  S:c.1448gTt>gCt         Washington  West Region
# 61  S:c.1448gTt>gCt         Washington  West Region
# 62  S:c.1448gTt>gCt         Washington  West Region
# 63  S:c.1448gTt>gCt         Washington  West Region
# 64  S:c.1448gTt>gCt         Washington  West Region
# 65   S:c.145Cat>Tat         California  West Region
# 66   S:c.145Cat>Tat         California  West Region
# 67  S:c.1557caT>caA         Washington  West Region
# 68  S:c.1557caT>caA         Washington  West Region
# 69  S:c.1558Gca>Tca             Alaska  West Region
# 70  S:c.1558Gca>Tca        King County  West Region
# 71  S:c.1558Gca>Tca        King County  West Region
# 72  S:c.1558Gca>Tca        King County  West Region
# 73  S:c.1558Gca>Tca         Washington  West Region
# 74  S:c.1558Gca>Tca         Washington  West Region
# 75  S:c.1558Gca>Tca         Washington  West Region
# 76  S:c.1558Gca>Tca         Washington  West Region
# 77  S:c.1565gCa>gTa        King County  West Region
# 78   S:c.162ttG>ttC              Idaho  West Region
# 79   S:c.162ttG>ttC              Idaho  West Region
# 80   S:c.162ttG>ttT       Adams County  West Region
# 81   S:c.162ttG>ttT       Adams County  West Region
# 82  S:c.1640aCa>aTa        King County  West Region
# 83  S:c.1658aCt>aTt         California  West Region
# 84  S:c.1658aCt>aTt      San Francisco  West Region
# 85  S:c.1715aCt>aTt          San Diego  West Region
# 86  S:c.1715aCt>aTt          San Diego  West Region
# 87  S:c.1841gAt>gGt       Adams County  West Region
# 88  S:c.1841gAt>gGt             Alaska  West Region
# 89  S:c.1841gAt>gGt             Alaska  West Region
# 90  S:c.1841gAt>gGt             Alaska  West Region
# 91  S:c.1841gAt>gGt             Alaska  West Region
# 92  S:c.1841gAt>gGt             Alaska  West Region
# 93  S:c.1841gAt>gGt             Alaska  West Region
# 94  S:c.1841gAt>gGt             Alaska  West Region
# 95  S:c.1841gAt>gGt             Alaska  West Region
# 96  S:c.1841gAt>gGt             Alaska  West Region
# 97  S:c.1841gAt>gGt             Alaska  West Region
# 98  S:c.1841gAt>gGt             Alaska  West Region
# 99  S:c.1841gAt>gGt             Alaska  West Region

# %% [markdown]
# ##### Variants in the US Northeast Region

# %%
region = 'Northeast Region'
graph.run(query, region=region).to_data_frame().head(100)
# Out:
#            mutation       location            region
# 0   S:c.1076aGc>aAc         Queens  Northeast Region
# 1   S:c.1150Cct>Tct         Queens  Northeast Region
# 2   S:c.1150Cct>Tct         Queens  Northeast Region
# 3     S:c.13Ctt>Ttt       Brooklyn  Northeast Region
# 4     S:c.13Ctt>Ttt       Brooklyn  Northeast Region
# 5     S:c.13Ctt>Ttt       Brooklyn  Northeast Region
# 6     S:c.13Ctt>Ttt  Hudson County  Northeast Region
# 7     S:c.13Ctt>Ttt      Manhattan  Northeast Region
# 8     S:c.13Ctt>Ttt  Massachusetts  Northeast Region
# 9     S:c.13Ctt>Ttt  Massachusetts  Northeast Region
# 10    S:c.13Ctt>Ttt  Massachusetts  Northeast Region
# 11    S:c.13Ctt>Ttt  Massachusetts  Northeast Region
# 12    S:c.13Ctt>Ttt  Massachusetts  Northeast Region
# 13    S:c.13Ctt>Ttt  Massachusetts  Northeast Region
# 14    S:c.13Ctt>Ttt  Massachusetts  Northeast Region
# 15    S:c.13Ctt>Ttt  Nassau County  Northeast Region
# 16    S:c.13Ctt>Ttt  Nassau County  Northeast Region
# 17    S:c.13Ctt>Ttt  Nassau County  Northeast Region
# 18    S:c.13Ctt>Ttt  Nassau County  Northeast Region
# 19    S:c.13Ctt>Ttt       New York  Northeast Region
# 20    S:c.13Ctt>Ttt       New York  Northeast Region
# 21    S:c.13Ctt>Ttt         Queens  Northeast Region
# 22    S:c.13Ctt>Ttt  Staten Island  Northeast Region
# 23  S:c.1501Aat>Tat         Queens  Northeast Region
# 24  S:c.1507Gtt>Ttt       Brooklyn  Northeast Region
# 25  S:c.1558Gca>Tca       Brooklyn  Northeast Region
# 26  S:c.1586aAg>aGg     Pittsburgh  Northeast Region
# 27   S:c.162ttG>ttT         Queens  Northeast Region
# 28  S:c.1662gaG>gaT      Manhattan  Northeast Region
# 29  S:c.1708Gct>Act         Queens  Northeast Region
# 30  S:c.1709gCt>gTt  Massachusetts  Northeast Region
# 31  S:c.1749gaG>gaT      Manhattan  Northeast Region
# 32  S:c.1749gaG>gaT      Manhattan  Northeast Region
# 33  S:c.1841gAt>gGt  Albany County  Northeast Region
# 34  S:c.1841gAt>gGt  Bergen County  Northeast Region
# 35  S:c.1841gAt>gGt  Bergen County  Northeast Region
# 36  S:c.1841gAt>gGt  Bergen County  Northeast Region
# 37  S:c.1841gAt>gGt  Bergen County  Northeast Region
# 38  S:c.1841gAt>gGt  Bergen County  Northeast Region
# 39  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 40  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 41  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 42  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 43  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 44  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 45  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 46  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 47  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 48  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 49  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 50  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 51  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 52  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 53  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 54  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 55  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 56  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 57  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 58  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 59  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 60  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 61  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 62  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 63  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 64  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 65  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 66  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 67  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 68  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 69  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 70  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 71  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 72  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 73  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 74  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 75  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 76  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 77  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 78  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 79  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 80  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 81  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 82  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 83  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 84  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 85  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 86  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 87  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 88  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 89  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 90  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 91  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 92  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 93  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 94  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 95  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 96  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 97  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 98  S:c.1841gAt>gGt       Brooklyn  Northeast Region
# 99  S:c.1841gAt>gGt       Brooklyn  Northeast Region

# %% [markdown]
# ### Cases in a specific County (Admin2)

# %%
admin2 = 'San Diego County'

query = """
MATCH (c:Cases{date: date("2020-06-04")})-[:REPORTED_IN]->(a:Admin2{name: $admin2})
RETURN a.name as name, c.cummulativeConfirmed as confirmed, c.cummulativeDeaths as deaths
"""
graph.run(query, admin2=admin2).to_data_frame()
# Out:
#                name  confirmed  deaths
# 0  San Diego County       7798     283

# %% [markdown]
# ### Aggregate cases by State (Admin1)

# %%
query = """
MATCH (o:Outbreak{id: "COVID-19"})<-[:RELATED_TO]-(c:Cases{date: date("2020-06-04")})-[:REPORTED_IN]->(a:Admin2)-[:IN]->(a1:Admin1)
RETURN a1.name as state, sum(c.cummulativeDeaths) as deaths, sum(c.cummulativeConfirmed) as confirmed
ORDER BY deaths DESC
"""
graph.run(query).to_data_frame()
# Out:
#              state  deaths  confirmed
# 0         New York   30174     375133
# 1       New Jersey   11970     162104
# 2    Massachusetts    7190     101698
# 3     Pennsylvania    5832      78335
# 4         Illinois    5644     123329
# 5         Michigan    5475      53474
# 6       California    4401     119524
# 7      Connecticut    4007      42998
# 8          Florida    2570      59291
# 9             None    2435      48191
# 10            Ohio    2340      37282
# 11        Maryland    2331      49410
# 12       Louisiana    2324      36285
# 13         Georgia    2118      46344
# 14         Indiana    2016      34759
# 15           Texas    1776      70555
# 16        Colorado    1512      27346
# 17        Virginia    1158      37137
# 18      Washington    1138      22692
# 19       Minnesota    1101      26080
# 20  North Carolina    1006      32075
# 21         Arizona     996      22886
# 22     Mississippi     784      15985
# 23         Alabama     650      18631
# 24       Wisconsin     626      19792
# 25            Iowa     583      20806
# 26  South Carolina     501      12415
# 27        Kentucky     458      10696
# 28          Nevada     430       9129
# 29       Tennessee     397      24603
# 30        Delaware     385       9693
# 31      New Mexico     380       7367
# 32        Oklahoma     344       6907
# 33   New Hampshire     273       4868
# 34          Kansas     227      10167
# 35        Nebraska     168      14922
# 36          Oregon     159       4474
# 37        Arkansas     150       7502
# 38        Missouri     122       5010
# 39            Utah     104       9541
# 40           Maine      95       2442
# 41           Idaho      83       2990
# 42   West Virginia      79       2102
# 43    North Dakota      66       2706
# 44    South Dakota      64       5247
# 45         Vermont      55       1021
# 46          Hawaii      17        644
# 47         Montana      17        539
# 48          Alaska      10        512
# 49         Wyoming       1        921
# 50    Rhode Island       0      13071
