# %% [markdown]
# # Example queries for geographic locations on COVID-19 Knowledge Graph
# [Work in progress]
#
# This notebook demonstrates how to run Cypher queries in a Jupyter Notebook by connecting to a database server.

# %%
import datetime
import pandas as pd
from py2neo import Graph

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
graph = Graph("bolt://132.249.238.185:7687", user="reader", password="demo")

# %% [markdown]
# ### List Node Metadata

# %%
query = """
MATCH (n:NodeMetadata)
RETURN n.name, n.shortDescription, n.description, n.example, n.definitionSource, n.dataProviders
"""
graph.run(query).to_data_frame()
# Out:
#                   n.name                            n.shortDescription  \
# 0               Location                           Geographic location
# 1                  World                                     The World
# 2               UNRegion                           Continental regions
# 3            UNSubRegion                        Subcontinental regions
# 4   UNIntermediateRegion        Subdivisions of subcontinental regions
# 5                Country           Countries and dependent Territories
# 6                 Admin1                 State, Province, Municipality
# 7                 Admin2                                        County
# 8                   City                                          City
# 9             PostalCode                                   Postal Code
# 10                 Tract                                  Census tract
# 11            CruiseShip                                   Cruise ship
# 12              USRegion                             Regions of the US
# 13            USDivision                              Subregions of US
# 14                 Cases                                   Case counts
# 15              Outbreak                 Increase in disease occurance
# 16              Organism                                 Living system
# 17                  Host                     Host organism for a virus
# 18              Pathogen                       Diseae causing organism
# 19                Strain                Genetic variant of an organism
# 20                 Clade  Group of organisms based on common ancestors
# 21                  Gene                       Sequence of nucleotides
# 22               Protein                       Sequence of amino acids
# 23           Publication                            Published document
#
#                                         n.description  \
# 0                               A geographic location
# 1                                  Top level location
# 2    Continental regions according to the M49 stan...
# 3   Subcontinental regions according to the M49 st...
# 4   Subdivisions of subcontinental regions accordi...
# 5    Countries and dependent Territories defined b...
# 6   First administrative divisions, e.g, State, Pr...
# 7   Second administrative divisions: County in the US
# 8                                                City
# 9   E.g., a ZIP Code is a postal code used by the ...
# 10  Census tracts are small, relatively permanent ...
# 11                                        Cruise ship
# 12            Regions defined by the US Census Bureau
# 13           Divisions defined by the US Census Burea
# 14  Number of case for outbreaks or diseases at sp...
# 15  Statistically significant increase in disease ...
# 16  Individual living system, such as animal, plan...
# 17  A host organism provides an environment suppor...
# 18  A bacterium, virus, or other microorganism tha...
# 19  A population of organisms that is geneticaly d...
# 20  An identifier that denotes a group of organism...
# 21  Sequence of nucleotides in DNA or RNA that enc...
# 22  Proteins are large biomolecules consisting of ...
# 23   A document that has been accepted by a publisher
#
#                                             n.example  \
# 0   World, ..., Country, State, Country, City, Cru...
# 1                                                None
# 2                                            Americas
# 3                     Latin America and the Caribbean
# 4                                           Caribbean
# 5                                       United States
# 6                                          California
# 7                                    San Diego County
# 8                                           San Diego
# 9                                               92121
# 10                                        06073008346
# 11                                   Diamond Princess
# 12                                        West Region
# 13                                   Pacific Division
# 14                                  COVID-19-YYYYMMDD
# 15                                           COVID-19
# 16                                       Homo sapiens
# 17                                       Homo sapiens
# 18                                         SARS-CoV-2
# 19                                    COVID-19 strain
# 20                                       SARS-CoV-2 A
# 21                                  SARS-CoV-2 S gene
# 22                                      Spike protein
# 23                                               None
#
#                                    n.definitionSource  \
# 0                                                None
# 1                                                None
# 2        https://unstats.un.org/unsd/methodology/m49/
# 3        https://unstats.un.org/unsd/methodology/m49/
# 4        https://unstats.un.org/unsd/methodology/m49/
# 5                            http://www.geonames.org/
# 6                            http://www.geonames.org/
# 7                            http://www.geonames.org/
# 8                            http://www.geonames.org/
# 9         http://purl.obolibrary.org/obo/OPMI_0000120
# 10  https://www2.census.gov/geo/pdfs/education/Cen...
# 11     http://www.productontology.org/doc/Cruise_ship
# 12  https://www.census.gov/geographies/reference-f...
# 13  https://www.census.gov/geographies/reference-f...
# 14                                               None
# 15         http://purl.obolibrary.org/obo/IDO_0000502
# 16         http://purl.obolibrary.org/obo/OBI_0100026
# 17         http://purl.obolibrary.org/obo/IDO_0000531
# 18         http://purl.obolibrary.org/obo/IDO_0000528
# 19  https://semanticscience.org/resource/SIO_01005...
# 20  http://purl.obolibrary.org/obo/APOLLO_SV_00000232
# 21          http://purl.obolibrary.org/obo/SO_0000704
# 22          http://purl.obolibrary.org/obo/SO_0000104
# 23         http://purl.obolibrary.org/obo/IAO_0000311
#
#                          n.dataProviders
# 0   [GeoNames, UNSD, USCensus, HUD, JHU]
# 1                                   None
# 2                                 [UNSD]
# 3                                 [UNSD]
# 4                                 [UNSD]
# 5                             [GeoNames]
# 6                   [GeoNames, USCensus]
# 7                   [GeoNames, USCensus]
# 8                   [GeoNames, USCensus]
# 9                                  [HUD]
# 10                                 [HUD]
# 11                                 [JHU]
# 12                            [USCensus]
# 13                            [USCensus]
# 14                                 [JHU]
# 15                             [DO, JHU]
# 16                                [NCBI]
# 17              [NCBI, CNCB, Nextstrain]
# 18              [NCBI, CNCB, Nextstrain]
# 19              [NCBI, CNCB, Nextstrain]
# 20                          [Nextstrain]
# 21                                [NCBI]
# 22               [NCBI, UniProt, IntAct]
# 23                           [EuropePMC]

# %% [markdown]
# ### Run a fuzzy full text search for locations
# Results are ordered by match score.

# %%
query = """
CALL db.index.fulltext.queryNodes('locations', 'Los Angeles') YIELD node, score
RETURN node.name, node.location, node.population, labels(node), score
"""
df = graph.run(query).to_data_frame()
df.head(25)
# Out:
#                                node.name           node.location  \
# 0                            Los Angeles    (-95.1654, 17.39485)
# 1                            Los Angeles  (-108.48095, 25.60289)
# 2                            Los Angeles  (-103.56757, 25.52206)
# 3                            Los Angeles  (-100.94167, 20.55361)
# 4                            Los Angeles    (-82.19997, 8.52271)
# 5                            Los Angeles    (-80.35772, 7.88422)
# 6                            Los Angeles     (125.60806, 9.0125)
# 7                            Los Angeles  (-118.24368, 34.05223)
# 8                       East Los Angeles   (-118.17202, 34.0239)
# 9            Fraccionamiento los Angeles     (-106.33, 23.18833)
# 10                      Lake Los Angeles  (-117.82812, 34.61249)
# 11                   Colonia los Angeles  (-100.48828, 20.53523)
# 12                    Los Angeles County  (-118.26102, 34.19801)
# 13  General Felipe Angeles (Los Angeles)    (-98.92611, 19.8975)
# 14                               Angeles    (-84.05126, 9.99591)
# 15             Torrecilla de los Angeles    (-6.41606, 40.24788)
# 16                Santa Rosa los Angeles  (-100.92356, 20.56585)
# 17                  Noria de los Angeles  (-101.90846, 22.44321)
# 18              Rinconada de los Angeles   (-98.71139, 20.02611)
# 19         Gildardo Magana (Los Angeles)  (-102.45861, 19.54889)
# 20                        Angeles Barrio   (-66.80214, 18.29168)
# 21                          Angeles City      (120.58333, 15.15)
# 22                        Felipe Angeles   (-109.0408, 25.86763)
# 23                          Port Angeles  (-123.43074, 48.11815)
# 24            Santa Maria de los Angeles  (-103.18886, 22.19245)
#
#     node.population        labels(node)     score
# 0            1144.0    [Location, City]  5.888777
# 1            4217.0    [Location, City]  5.888777
# 2            1616.0    [Location, City]  5.888777
# 3             178.0    [Location, City]  5.888777
# 4              25.0    [Location, City]  5.888777
# 5             342.0    [Location, City]  5.888777
# 6             454.0    [Location, City]  5.888777
# 7         3971883.0    [Location, City]  5.888777
# 8          126496.0    [Location, City]  4.704502
# 9            6282.0    [Location, City]  4.704502
# 10          12328.0    [Location, City]  4.704502
# 11            439.0    [Location, City]  4.704502
# 12         981865.0  [Location, Admin2]  4.704502
# 13           3776.0    [Location, City]  4.612986
# 14           1355.0    [Location, City]  4.592111
# 15             75.0    [Location, City]  3.916805
# 16           2727.0    [Location, City]  3.916805
# 17           1662.0    [Location, City]  3.916805
# 18           2738.0    [Location, City]  3.916805
# 19            146.0    [Location, City]  3.916805
# 20              NaN  [Location, Admin2]  3.436129
# 21         299391.0    [Location, City]  3.436129
# 22            143.0    [Location, City]  3.436129
# 23          19448.0    [Location, City]  3.436129
# 24              NaN  [Location, Admin2]  3.355052

# %% [markdown]
# ### List all US States

# %%
query = """
MATCH (a:Admin1)-[:IN]->(:Country{name: 'United States'})
RETURN a.name, a.code, a.fips, a.population, a.elevation, a.location
ORDER by a.fips
"""
graph.run(query).to_data_frame()
# Out:
#               a.name a.code a.fips  a.population  a.elevation  \
# 0            Alabama     AL     01        453315        141.0
# 1             Alaska     AK     02         66633        421.0
# 2            Arizona     AZ     04        586389       1927.0
# 3           Arkansas     AR     05       2757631        185.0
# 4         California     CA     06      37691912        469.0
# 5           Colorado     CO     08        467863       3049.0
# 6        Connecticut     CT     09       3527249         45.0
# 7           Delaware     DE     10        838549          9.0
# 8            Florida     FL     12      17671452         26.0
# 9            Georgia     GA     13       8975842        155.0
# 10            Hawaii     HI     15        128422          0.0
# 11             Idaho     ID     16       1416564       1681.0
# 12          Illinois     IL     17      12772888        191.0
# 13           Indiana     IN     18       6265933        272.0
# 14              Iowa     IA     19         29551        292.0
# 15            Kansas     KS     20        274759        545.0
# 16          Kentucky     KY     21         42674          NaN
# 17         Louisiana     LA     22       4515939         14.0
# 18             Maine     ME     23       1325518        362.0
# 19          Maryland     MD     24       5624246         42.0
# 20     Massachusetts     MA     25       6433422          NaN
# 21          Michigan     MI     26        988336        394.0
# 22         Minnesota     MN     27       5141953        367.0
# 23       Mississippi     MS     28        291371        110.0
# 24          Missouri     MO     29       5768151        238.0
# 25           Montana     MT     30         93698       1202.0
# 26          Nebraska     NE     31       1757399        817.0
# 27            Nevada     NV     32       2399532       2260.0
# 28     New Hampshire     NH     33       1316216        164.0
# 29        New Jersey     NJ     34       8751436         42.0
# 30        New Mexico     NM     35       1912684       1889.0
# 31          New York     NY     36      19274244        281.0
# 32    North Carolina     NC     37       8611367        137.0
# 33      North Dakota     ND     38         63529        582.0
# 34              Ohio     OH     39      11467123        290.0
# 35          Oklahoma     OK     40        354749        369.0
# 36            Oregon     OR     41       3642919       1460.0
# 37      Pennsylvania     PA     42       1244621          NaN
# 38      Rhode Island     RI     44         15292         69.0
# 39    South Carolina     SC     45       4229842         92.0
# 40      South Dakota     SD     46         77184        548.0
# 41         Tennessee     TN     47        593599        325.0
# 42             Texas     TX     48      22875689        559.0
# 43              Utah     UT     49        242734       1808.0
# 44           Vermont     VT     50         62451        271.0
# 45          Virginia     VA     51       7642884          NaN
# 46        Washington     WA     53       6271775        555.0
# 47     West Virginia     WV     54       1817871        705.0
# 48         Wisconsin     WI     55       5535168        340.0
# 49           Wyoming     WY     56          5597       1889.0
# 50  Washington, D.C.     DC   None        552433         27.0
#
#                 a.location
# 0    (-86.75026, 32.75041)
# 1   (-150.00028, 64.00028)
# 2    (-111.50098, 34.5003)
# 3    (-92.50044, 34.75037)
# 4   (-119.75126, 37.25022)
# 5   (-105.50083, 39.00027)
# 6    (-72.66648, 41.66704)
# 7    (-75.49992, 39.00039)
# 8     (-82.5001, 28.75054)
# 9    (-83.50018, 32.75042)
# 10  (-156.38612, 20.78785)
# 11   (-114.25118, 44.5002)
# 12   (-89.25037, 40.00032)
# 13   (-86.25027, 40.00032)
# 14   (-93.50049, 42.00027)
# 15   (-98.50063, 38.50029)
# 16   (-84.87762, 38.20042)
# 17    (-92.0004, 31.00047)
# 18   (-69.24977, 45.50032)
# 19   (-76.74997, 39.00039)
# 20   (-71.10832, 42.36565)
# 21   (-85.50033, 44.25029)
# 22   (-94.25055, 46.25024)
# 23   (-89.75036, 32.75041)
# 24   (-92.50046, 38.25031)
# 25  (-109.75102, 47.00025)
# 26   (-99.75067, 41.50028)
# 27  (-116.75119, 39.25021)
# 28    (-71.4998, 43.66702)
# 29   (-74.49987, 40.16706)
# 30  (-106.00085, 34.50034)
# 31    (-75.4999, 43.00035)
# 32   (-80.00032, 35.50069)
# 33  (-100.00068, 47.50027)
# 34   (-83.00018, 40.25034)
# 35   (-97.50328, 35.49209)
# 36  (-120.50139, 44.00013)
# 37           (-77.7, 40.8)
# 38   (-71.49978, 41.75038)
# 39   (-81.00009, 34.00043)
# 40  (-100.25069, 44.50026)
# 41   (-86.25027, 35.75035)
# 42   (-99.25061, 31.25044)
# 43  (-111.75103, 39.25024)
# 44   (-72.74983, 44.00034)
# 45   (-77.44675, 37.54812)
# 46  (-120.50147, 47.50012)
# 47   (-80.50009, 38.50038)
# 48   (-90.00041, 44.50024)
# 49   (-107.5009, 43.00024)
# 50   (-77.00025, 38.91706)

# %% [markdown]
# ### Calculate distances between locations

# %%
query = """
MATCH (a:City {name:"Denver"}), (b: City {name:"Houston"})
WHERE a.elevation > 1000 AND b.elevation < 25
RETURN a.name, a.elevation, a.location, b.name, b.elevation, b.location, distance(a.location, b.location) / 1000.0 as distance_KM
"""
graph.run(query).to_data_frame()
# Out:
#    a.name  a.elevation             a.location   b.name  b.elevation  \
# 0  Denver         1609  (-104.9847, 39.73915)  Houston           12
#
#               b.location  distance_KM
# 0  (-95.36327, 29.76328)  1415.017179

# %% [markdown]
# ### Find nearby locations
# Distances are in meters

# %%
# Example from: https://maxdemarzi.com/2018/03/21/neo4j-geospatial-queries/
query = """
MATCH (c:City)-[:IN*]->(s:Admin1), (c2:City)
WHERE c.name = "Union City"
  AND s.name = "California"
  AND distance(c.location, c2.location) <= 10000
RETURN c2.name, c2.location.longitude, c2.location.latitude, distance(c.location, c2.location)
"""
graph.run(query).to_data_frame()
# Out:
#       c2.name  c2.location.longitude  c2.location.latitude  \
# 0     Fremont             -121.98857              37.54827
# 1     Hayward             -122.08080              37.66882
# 2      Newark             -122.04024              37.52966
# 3  Union City             -122.01913              37.59577
# 4    Fairview             -122.04580              37.67854
#
#    distance(c.location, c2.location)
# 0                        5935.461291
# 1                        9781.927235
# 2                        7591.426269
# 3                           0.000000
# 4                        9509.138592
