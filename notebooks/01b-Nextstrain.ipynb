# %% [markdown]
# # Load SARS-CoV-2 Strain Metadata from Nextstrain.org
# **[Work in progress]**
#
# This notebook downloads and standardizes SARS-CoV-2 strain metadata from [Nextstrain.org](https://nextstrain.org) obtained from [GISAID](https://www.gisaid.org/) for ingestion into a Knowledge Graph.
#
# This notebook uses a local copy of the [nextstrain_ncov_global_metadata.tsv](../reference_data/nextstrain_ncov_global_metadata.tsv) file, since it must be manually downloaded from Nextstrain.org. It will not be updated daily.
#
# Additional information about these strains will be loaded later in the [01e-CNCBStrain.ipynb](01e-CNCBStrain.ipynb) notebook.
#
# Data source: [Nextstrain.org](https://nextstrain.org/ncov/)
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import pandas as pd
import dateutil
from pathlib import Path

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_HOME = Path(os.getenv('NEO4J_HOME'))
print(NEO4J_HOME)
# Out:
# /Users/peter/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-4af96121-2328-4e2f-ba60-6d8b728a26d5/installation-4.0.3

# %%
df = pd.read_csv("../reference_data/nextstrain_ncov_global_metadata.tsv", sep = '\t', dtype=str, error_bad_lines=False)
# Out:
# b'Skipping line 2920: expected 19 fields, saw 24\n'

# %% [markdown]
# ## Transform and standardize data

# %% [markdown]
# Graph databases don't have "null" values. By setting missing values to '', they will not be represented in the graph.

# %%
df.replace('?', '', inplace=True)
df.replace('Unknown', '', inplace=True)
df.fillna('', inplace=True)

# %%
df.head()
# Out:
#                     Strain Admin Division  gisaid_epi_isl url Country Age  \
# 0     Shanghai/SH0007/2020       Shanghai  EPI_ISL_416320       China  65
# 1          Wuhan/WH01/2019          Hubei  EPI_ISL_406798       China  44
# 2     Hangzhou/ZJU-07/2020       Zhejiang  EPI_ISL_416425       China   0
# 3  Guangzhou/GZMU0060/2020      Guangdong  EPI_ISL_429103       China  25
# 4    Wuhan/IVDC-HB-05/2019          Hubei  EPI_ISL_402121       China  32
#
#     Sex   Host Submission Date  \
# 0  Male  Human           Older
# 1  Male  Human           Older
# 2  Male  Human           Older
# 3        Human   One month ago
# 4  Male  Human           Older
#
#                                       Submitting Lab  \
# 0  National Research Center for Translational Med...
# 1  BGI & Institute of Microbiology, Chinese Acade...
# 2  State Key Laboratory for Diagnosis and Treatme...
# 3  BGI-shenzhen & The First Affiliated Hospital o...
# 4  National Institute for Viral Disease Control a...
#
#                                      Originating Lab Region  \
# 0  Shanghai Public Health Clinical Center, Shangh...   Asia
# 1  General Hospital of Central Theater Command of...   Asia
# 2  State Key Laboratory for Diagnosis and Treatme...   Asia
# 3  The First Affiliated Hospital of Guangzhou Med...   Asia
# 4  National Institute for Viral Disease Control a...   Asia
#
#   Division of exposure Clade Collection Data               Author  \
# 0             Shanghai            2020-01-28  Shengyue Wang et al
# 1                Hubei            2019-12-26    Weijun Chen et al
# 2             Zhejiang            2020-02-03   Hangping Yao et al
# 3            Guangdong            2020-02-09                et al
# 4                Hubei            2019-12-30     Wenjie Tan et al
#
#   genbank_accession   Location Country of exposure
# 0
# 1          LR757998      Wuhan
# 2                     Hangzhou
# 3                    Guangzhou
# 4                        Wuhan

# %% [markdown]
# Apply Neo4j property naming conventions

# %%
df.rename(columns={'Strain': 'name', 'Clade': 'clade', 'Age': 'age', 'Sex': 'sex', 'Collection Data': 'collectionDate'}, inplace=True)
df.rename(columns={'Country of exposure': 'exposureCountry', 'Division of exposure': 'exposureAdmin1'}, inplace=True)

# %% [markdown]
# Fix collection dates

# %%
df['collectionDate'] = df['collectionDate'].apply(lambda d: dateutil.parser.parse(d) if len(d) > 0 else '')

# %% [markdown]
# Taxonomy

# %%
# assign taxonomy for SARS-CoV-2
df['taxonomyId'] = 'taxonomy:2697049'

# %%
# TODO a find general solution to map host name to NCBI taxonomy**

# some host specifications are ambiguous, 
# they don't match a specific species in NCBI taxonomy

taxonomy_to_id = {'Human': 'taxonomy:9606', 
                  'Homo sapiens': 'taxonomy:9606',
                  'Rhinolophus affinis': 'taxonomy:59477', 
                  'Rhinolophus sp. (bat)': 'taxonomy:49442',
                  'Mustela lutreola': 'taxonomy:9666',
                  'Panthera tigris jacksoni': 'taxonomy:419130',
                  'bat': 'taxonomy:49442',
                  'Manis javanica': 'taxonomy:9974',
                  'palm civet': 'taxonomy:71116',
                  'Canine': 'taxonomy:9608',
                  'Felis catus': 'taxonomy:9685'
                 }

# %%
# assign taxonomy id for host
df['Host'] = df['Host'].str.strip()
df['hostTaxonomyId'] = df['Host'].apply(lambda s: taxonomy_to_id.get(s, ''))
df = df.query("hostTaxonomyId != ''")

# %%
df['hostTaxonomyId'].unique()
# Out:
# array(['taxonomy:9606', 'taxonomy:9666', 'taxonomy:9685',
#        'taxonomy:419130'], dtype=object)

# %%
# for consistency with NCBI, use lower case
df['sex'] = df['sex'].str.lower()

# %%
df.head()
# Out:
#                       name Admin Division  gisaid_epi_isl url Country age  \
# 0     Shanghai/SH0007/2020       Shanghai  EPI_ISL_416320       China  65
# 1          Wuhan/WH01/2019          Hubei  EPI_ISL_406798       China  44
# 2     Hangzhou/ZJU-07/2020       Zhejiang  EPI_ISL_416425       China   0
# 3  Guangzhou/GZMU0060/2020      Guangdong  EPI_ISL_429103       China  25
# 4    Wuhan/IVDC-HB-05/2019          Hubei  EPI_ISL_402121       China  32
#
#     sex   Host Submission Date  \
# 0  male  Human           Older
# 1  male  Human           Older
# 2  male  Human           Older
# 3        Human   One month ago
# 4  male  Human           Older
#
#                                       Submitting Lab  \
# 0  National Research Center for Translational Med...
# 1  BGI & Institute of Microbiology, Chinese Acade...
# 2  State Key Laboratory for Diagnosis and Treatme...
# 3  BGI-shenzhen & The First Affiliated Hospital o...
# 4  National Institute for Viral Disease Control a...
#
#                                      Originating Lab Region exposureAdmin1  \
# 0  Shanghai Public Health Clinical Center, Shangh...   Asia       Shanghai
# 1  General Hospital of Central Theater Command of...   Asia          Hubei
# 2  State Key Laboratory for Diagnosis and Treatme...   Asia       Zhejiang
# 3  The First Affiliated Hospital of Guangzhou Med...   Asia      Guangdong
# 4  National Institute for Viral Disease Control a...   Asia          Hubei
#
#   clade collectionDate               Author genbank_accession   Location  \
# 0           2020-01-28  Shengyue Wang et al
# 1           2019-12-26    Weijun Chen et al          LR757998      Wuhan
# 2           2020-02-03   Hangping Yao et al                     Hangzhou
# 3           2020-02-09                et al                    Guangzhou
# 4           2019-12-30     Wenjie Tan et al                        Wuhan
#
#   exposureCountry        taxonomyId hostTaxonomyId
# 0                  taxonomy:2697049  taxonomy:9606
# 1                  taxonomy:2697049  taxonomy:9606
# 2                  taxonomy:2697049  taxonomy:9606
# 3                  taxonomy:2697049  taxonomy:9606
# 4                  taxonomy:2697049  taxonomy:9606

# %% [markdown]
# ### Create unique and interoperable identifiers

# %% [markdown]
# **id**: URI: [https://www.gisaid.org/](https://www.gisaid.org/help/publish-with-gisaid-references) (Global Initiative on Sharing All Influenza Data, GISAID)

# %%
df['id'] = 'https://www.gisaid.org/' + df['gisaid_epi_isl']

# %% [markdown]
# ### Save data for Knowledge Graph Import

# %%
df = df[['id', 'name', 'taxonomyId', 'collectionDate',
         'hostTaxonomyId', 'sex', 'age', 'clade',
         'exposureCountry', 'exposureAdmin1']]
df.head()
# Out:
#                                       id                     name  \
# 0  https://www.gisaid.org/EPI_ISL_416320     Shanghai/SH0007/2020
# 1  https://www.gisaid.org/EPI_ISL_406798          Wuhan/WH01/2019
# 2  https://www.gisaid.org/EPI_ISL_416425     Hangzhou/ZJU-07/2020
# 3  https://www.gisaid.org/EPI_ISL_429103  Guangzhou/GZMU0060/2020
# 4  https://www.gisaid.org/EPI_ISL_402121    Wuhan/IVDC-HB-05/2019
#
#          taxonomyId collectionDate hostTaxonomyId   sex age clade  \
# 0  taxonomy:2697049     2020-01-28  taxonomy:9606  male  65
# 1  taxonomy:2697049     2019-12-26  taxonomy:9606  male  44
# 2  taxonomy:2697049     2020-02-03  taxonomy:9606  male   0
# 3  taxonomy:2697049     2020-02-09  taxonomy:9606        25
# 4  taxonomy:2697049     2019-12-30  taxonomy:9606  male  32
#
#   exposureCountry exposureAdmin1
# 0                       Shanghai
# 1                          Hubei
# 2                       Zhejiang
# 3                      Guangdong
# 4                          Hubei

# %%
df.to_csv(NEO4J_HOME / "import/01b-Nextstrain.csv", index=False)
