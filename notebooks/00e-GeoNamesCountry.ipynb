# %% [markdown]
# # Countries

# %% [markdown]
# **[Work in progress]**
#
# This notebook creates a .csv file with country information for ingestion into the Knowledge Graph.
#
# Data source: [GeoNames.org](https://download.geonames.org/export/dump/)
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
from pathlib import Path
import pandas as pd

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_HOME = Path(os.getenv('NEO4J_HOME'))
print(NEO4J_HOME)
# Out:
# /Users/peter/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-4af96121-2328-4e2f-ba60-6d8b728a26d5/installation-4.0.3

# %% [markdown]
# ### Create countries

# %%
country_url = 'https://download.geonames.org/export/dump/countryInfo.txt'

# %%
names = ['ISO','ISO3','ISO-Numeric','fips','Country','Capital','Area(in sq km)','Population',
         'Continent','tld','CurrencyCode','CurrencyName','Phone','Postal Code Format',
         'Postal Code Regex','Languages','geonameid','neighbours','EquivalentFipsCode'
        ]

# %%
countries = pd.read_csv(country_url, sep='\t',comment='#', dtype='str', names=names)

# %% [markdown]
# ### Add missing data
# TODO North American Countries and island nations are missing the Continent data

# %% [markdown]
# Add missing iso code for Namibia

# %%
index = countries.query("ISO3 == 'NAM'").index
countries.at[index, 'ISO'] = 'NA'
countries.head()
# Out:
#   ISO ISO3 ISO-Numeric fips               Country           Capital  \
# 0  AD  AND         020   AN               Andorra  Andorra la Vella
# 1  AE  ARE         784   AE  United Arab Emirates         Abu Dhabi
# 2  AF  AFG         004   AF           Afghanistan             Kabul
# 3  AG  ATG         028   AC   Antigua and Barbuda        St. John's
# 4  AI  AIA         660   AV              Anguilla        The Valley
#
#   Area(in sq km) Population Continent  tld CurrencyCode CurrencyName   Phone  \
# 0            468      77006        EU  .ad          EUR         Euro     376
# 1          82880    9630959        AS  .ae          AED       Dirham     971
# 2         647500   37172386        AS  .af          AFN      Afghani      93
# 3            443      96286       NaN  .ag          XCD       Dollar  +1-268
# 4            102      13254       NaN  .ai          XCD       Dollar  +1-264
#
#   Postal Code Format Postal Code Regex          Languages geonameid  \
# 0                 AD               NaN                NaN       NaN
# 1                NaN               NaN  ar-AE,fa,en,hi,ur    290557
# 2                NaN               NaN  fa-AF,ps,uz-AF,tk   1149361
# 3                NaN               NaN              en-AG   3576396
# 4                NaN               NaN              en-AI   3573511
#
#           neighbours EquivalentFipsCode
# 0                NaN                NaN
# 1              SA,OM                NaN
# 2  TM,CN,IR,TJ,PK,UZ                NaN
# 3                NaN                NaN
# 4                NaN                NaN

# %% [markdown]
# ### Standardize column names for Knowlege Graph
# * id: unique identifier for country
# * name: name of node
# * parentId: unique identifier for continent
# * properties: camelCase

# %%
countries['id'] = countries['ISO'] # standard id column to link nodes
countries.rename(columns={'ISO': 'iso'}, inplace=True)
countries.rename(columns={'ISO3': 'iso3'}, inplace=True)
countries.rename(columns={'Country': 'name'}, inplace=True)
countries.rename(columns={'Population': 'population'}, inplace=True)
countries.rename(columns={'Area(in sq km)': 'areaSqKm'}, inplace=True)
countries.rename(columns={'Continent': 'parentId'}, inplace=True)

# %% [markdown]
# ### Export a minimum subset for now

# %%
countries = countries[['id','name','iso','iso3','population','areaSqKm','parentId']]
countries = countries.fillna('')

# %%
countries.head(1000)
# Out:
#      id                                          name iso iso3  population  \
# 0    AD                                       Andorra  AD  AND       77006
# 1    AE                          United Arab Emirates  AE  ARE     9630959
# 2    AF                                   Afghanistan  AF  AFG    37172386
# 3    AG                           Antigua and Barbuda  AG  ATG       96286
# 4    AI                                      Anguilla  AI  AIA       13254
# 5    AL                                       Albania  AL  ALB     2866376
# 6    AM                                       Armenia  AM  ARM     2951776
# 7    AO                                        Angola  AO  AGO    30809762
# 8    AQ                                    Antarctica  AQ  ATA           0
# 9    AR                                     Argentina  AR  ARG    44494502
# 10   AS                                American Samoa  AS  ASM       55465
# 11   AT                                       Austria  AT  AUT     8847037
# 12   AU                                     Australia  AU  AUS    24992369
# 13   AW                                         Aruba  AW  ABW      105845
# 14   AX                                 Aland Islands  AX  ALA       26711
# 15   AZ                                    Azerbaijan  AZ  AZE     9942334
# 16   BA                        Bosnia and Herzegovina  BA  BIH     3323929
# 17   BB                                      Barbados  BB  BRB      286641
# 18   BD                                    Bangladesh  BD  BGD   161356039
# 19   BE                                       Belgium  BE  BEL    11422068
# 20   BF                                  Burkina Faso  BF  BFA    19751535
# 21   BG                                      Bulgaria  BG  BGR     7000039
# 22   BH                                       Bahrain  BH  BHR     1569439
# 23   BI                                       Burundi  BI  BDI    11175378
# 24   BJ                                         Benin  BJ  BEN    11485048
# 25   BL                              Saint Barthelemy  BL  BLM        8450
# 26   BM                                       Bermuda  BM  BMU       63968
# 27   BN                                        Brunei  BN  BRN      428962
# 28   BO                                       Bolivia  BO  BOL    11353142
# 29   BQ            Bonaire, Saint Eustatius and Saba   BQ  BES       18012
# 30   BR                                        Brazil  BR  BRA   209469333
# 31   BS                                       Bahamas  BS  BHS      385640
# 32   BT                                        Bhutan  BT  BTN      754394
# 33   BV                                 Bouvet Island  BV  BVT           0
# 34   BW                                      Botswana  BW  BWA     2254126
# 35   BY                                       Belarus  BY  BLR     9485386
# 36   BZ                                        Belize  BZ  BLZ      383071
# 37   CA                                        Canada  CA  CAN    37058856
# 38   CC                                 Cocos Islands  CC  CCK         628
# 39   CD              Democratic Republic of the Congo  CD  COD    84068091
# 40   CF                      Central African Republic  CF  CAF     4666377
# 41   CG                         Republic of the Congo  CG  COG     5244363
# 42   CH                                   Switzerland  CH  CHE     8516543
# 43   CI                                   Ivory Coast  CI  CIV    25069229
# 44   CK                                  Cook Islands  CK  COK       21388
# 45   CL                                         Chile  CL  CHL    18729160
# 46   CM                                      Cameroon  CM  CMR    25216237
# 47   CN                                         China  CN  CHN  1392730000
# 48   CO                                      Colombia  CO  COL    49648685
# 49   CR                                    Costa Rica  CR  CRI     4999441
# 50   CU                                          Cuba  CU  CUB    11338138
# 51   CV                                    Cabo Verde  CV  CPV      543767
# 52   CW                                       Curacao  CW  CUW      159849
# 53   CX                              Christmas Island  CX  CXR        1500
# 54   CY                                        Cyprus  CY  CYP     1189265
# 55   CZ                                       Czechia  CZ  CZE    10625695
# 56   DE                                       Germany  DE  DEU    82927922
# 57   DJ                                      Djibouti  DJ  DJI      958920
# 58   DK                                       Denmark  DK  DNK     5797446
# 59   DM                                      Dominica  DM  DMA       71625
# 60   DO                            Dominican Republic  DO  DOM    10627165
# 61   DZ                                       Algeria  DZ  DZA    42228429
# 62   EC                                       Ecuador  EC  ECU    17084357
# 63   EE                                       Estonia  EE  EST     1320884
# 64   EG                                         Egypt  EG  EGY    98423595
# 65   EH                                Western Sahara  EH  ESH      273008
# 66   ER                                       Eritrea  ER  ERI           0
# 67   ES                                         Spain  ES  ESP    46723749
# 68   ET                                      Ethiopia  ET  ETH   109224559
# 69   FI                                       Finland  FI  FIN     5518050
# 70   FJ                                          Fiji  FJ  FJI      883483
# 71   FK                              Falkland Islands  FK  FLK        2638
# 72   FM                                    Micronesia  FM  FSM      112640
# 73   FO                                 Faroe Islands  FO  FRO       48497
# 74   FR                                        France  FR  FRA    66987244
# 75   GA                                         Gabon  GA  GAB     2119275
# 76   GB                                United Kingdom  GB  GBR    66488991
# 77   GD                                       Grenada  GD  GRD      111454
# 78   GE                                       Georgia  GE  GEO     3731000
# 79   GF                                 French Guiana  GF  GUF      195506
# 80   GG                                      Guernsey  GG  GGY       65228
# 81   GH                                         Ghana  GH  GHA    29767108
# 82   GI                                     Gibraltar  GI  GIB       33718
# 83   GL                                     Greenland  GL  GRL       56025
# 84   GM                                        Gambia  GM  GMB     2280102
# 85   GN                                        Guinea  GN  GIN    12414318
# 86   GP                                    Guadeloupe  GP  GLP      443000
# 87   GQ                             Equatorial Guinea  GQ  GNQ     1308974
# 88   GR                                        Greece  GR  GRC    10727668
# 89   GS  South Georgia and the South Sandwich Islands  GS  SGS          30
# 90   GT                                     Guatemala  GT  GTM    17247807
# 91   GU                                          Guam  GU  GUM      165768
# 92   GW                                 Guinea-Bissau  GW  GNB     1874309
# 93   GY                                        Guyana  GY  GUY      779004
# 94   HK                                     Hong Kong  HK  HKG     7451000
# 95   HM             Heard Island and McDonald Islands  HM  HMD           0
# 96   HN                                      Honduras  HN  HND     9587522
# 97   HR                                       Croatia  HR  HRV     4089400
# 98   HT                                         Haiti  HT  HTI    11123176
# 99   HU                                       Hungary  HU  HUN     9768785
# 100  ID                                     Indonesia  ID  IDN   267663435
# 101  IE                                       Ireland  IE  IRL     4853506
# 102  IL                                        Israel  IL  ISR     8883800
# 103  IM                                   Isle of Man  IM  IMN       84077
# 104  IN                                         India  IN  IND  1352617328
# 105  IO                British Indian Ocean Territory  IO  IOT        4000
# 106  IQ                                          Iraq  IQ  IRQ    38433600
# 107  IR                                          Iran  IR  IRN    81800269
# 108  IS                                       Iceland  IS  ISL      353574
# 109  IT                                         Italy  IT  ITA    60431283
# 110  JE                                        Jersey  JE  JEY       90812
# 111  JM                                       Jamaica  JM  JAM     2934855
# 112  JO                                        Jordan  JO  JOR     9956011
# 113  JP                                         Japan  JP  JPN   126529100
# 114  KE                                         Kenya  KE  KEN    51393010
# 115  KG                                    Kyrgyzstan  KG  KGZ     6315800
# 116  KH                                      Cambodia  KH  KHM    16249798
# 117  KI                                      Kiribati  KI  KIR      115847
# 118  KM                                       Comoros  KM  COM      832322
# 119  KN                         Saint Kitts and Nevis  KN  KNA       52441
# 120  KP                                   North Korea  KP  PRK    25549819
# 121  KR                                   South Korea  KR  KOR    51635256
# 122  XK                                        Kosovo  XK  XKX     1845300
# 123  KW                                        Kuwait  KW  KWT     4137309
# 124  KY                                Cayman Islands  KY  CYM       64174
# 125  KZ                                    Kazakhstan  KZ  KAZ    18276499
# 126  LA                                          Laos  LA  LAO     7061507
# 127  LB                                       Lebanon  LB  LBN     6848925
# 128  LC                                   Saint Lucia  LC  LCA      181889
# 129  LI                                 Liechtenstein  LI  LIE       37910
# 130  LK                                     Sri Lanka  LK  LKA    21670000
# 131  LR                                       Liberia  LR  LBR     4818977
# 132  LS                                       Lesotho  LS  LSO     2108132
# 133  LT                                     Lithuania  LT  LTU     2789533
# 134  LU                                    Luxembourg  LU  LUX      607728
# 135  LV                                        Latvia  LV  LVA     1926542
# 136  LY                                         Libya  LY  LBY     6678567
# 137  MA                                       Morocco  MA  MAR    36029138
# 138  MC                                        Monaco  MC  MCO       38682
# 139  MD                                       Moldova  MD  MDA     3545883
# 140  ME                                    Montenegro  ME  MNE      622345
# 141  MF                                  Saint Martin  MF  MAF       37264
# 142  MG                                    Madagascar  MG  MDG    26262368
# 143  MH                              Marshall Islands  MH  MHL       58413
# 144  MK                               North Macedonia  MK  MKD     2082958
# 145  ML                                          Mali  ML  MLI    19077690
# 146  MM                                       Myanmar  MM  MMR    53708395
# 147  MN                                      Mongolia  MN  MNG     3170208
# 148  MO                                         Macao  MO  MAC      631636
# 149  MP                      Northern Mariana Islands  MP  MNP       56882
# 150  MQ                                    Martinique  MQ  MTQ      432900
# 151  MR                                    Mauritania  MR  MRT     4403319
# 152  MS                                    Montserrat  MS  MSR        9341
# 153  MT                                         Malta  MT  MLT      483530
# 154  MU                                     Mauritius  MU  MUS     1265303
# 155  MV                                      Maldives  MV  MDV      515696
# 156  MW                                        Malawi  MW  MWI    17563749
# 157  MX                                        Mexico  MX  MEX   126190788
# 158  MY                                      Malaysia  MY  MYS    31528585
# 159  MZ                                    Mozambique  MZ  MOZ    29495962
# 160  NA                                       Namibia  NA  NAM     2448255
# 161  NC                                 New Caledonia  NC  NCL      284060
# 162  NE                                         Niger  NE  NER    22442948
# 163  NF                                Norfolk Island  NF  NFK        1828
# 164  NG                                       Nigeria  NG  NGA   195874740
# 165  NI                                     Nicaragua  NI  NIC     6465513
# 166  NL                                   Netherlands  NL  NLD    17231017
# 167  NO                                        Norway  NO  NOR     5314336
# 168  NP                                         Nepal  NP  NPL    28087871
# 169  NR                                         Nauru  NR  NRU       12704
# 170  NU                                          Niue  NU  NIU        2166
# 171  NZ                                   New Zealand  NZ  NZL     4885500
# 172  OM                                          Oman  OM  OMN     4829483
# 173  PA                                        Panama  PA  PAN     4176873
# 174  PE                                          Peru  PE  PER    31989256
# 175  PF                              French Polynesia  PF  PYF      277679
# 176  PG                              Papua New Guinea  PG  PNG     8606316
# 177  PH                                   Philippines  PH  PHL   106651922
# 178  PK                                      Pakistan  PK  PAK   212215030
# 179  PL                                        Poland  PL  POL    37978548
# 180  PM                     Saint Pierre and Miquelon  PM  SPM        7012
# 181  PN                                      Pitcairn  PN  PCN          46
# 182  PR                                   Puerto Rico  PR  PRI     3195153
# 183  PS                         Palestinian Territory  PS  PSE     4569087
# 184  PT                                      Portugal  PT  PRT    10281762
# 185  PW                                         Palau  PW  PLW       17907
# 186  PY                                      Paraguay  PY  PRY     6956071
# 187  QA                                         Qatar  QA  QAT     2781677
# 188  RE                                       Reunion  RE  REU      776948
# 189  RO                                       Romania  RO  ROU    19473936
# 190  RS                                        Serbia  RS  SRB     6982084
# 191  RU                                        Russia  RU  RUS   144478050
# 192  RW                                        Rwanda  RW  RWA    12301939
# 193  SA                                  Saudi Arabia  SA  SAU    33699947
# 194  SB                               Solomon Islands  SB  SLB      652858
# 195  SC                                    Seychelles  SC  SYC       96762
# 196  SD                                         Sudan  SD  SDN    41801533
# 197  SS                                   South Sudan  SS  SSD     8260490
# 198  SE                                        Sweden  SE  SWE    10183175
# 199  SG                                     Singapore  SG  SGP     5638676
# 200  SH                                  Saint Helena  SH  SHN        7460
# 201  SI                                      Slovenia  SI  SVN     2067372
# 202  SJ                        Svalbard and Jan Mayen  SJ  SJM        2550
# 203  SK                                      Slovakia  SK  SVK     5447011
# 204  SL                                  Sierra Leone  SL  SLE     7650154
# 205  SM                                    San Marino  SM  SMR       33785
# 206  SN                                       Senegal  SN  SEN    15854360
# 207  SO                                       Somalia  SO  SOM    15008154
# 208  SR                                      Suriname  SR  SUR      575991
# 209  ST                         Sao Tome and Principe  ST  STP      197700
# 210  SV                                   El Salvador  SV  SLV     6420744
# 211  SX                                  Sint Maarten  SX  SXM       40654
# 212  SY                                         Syria  SY  SYR    16906283
# 213  SZ                                      Eswatini  SZ  SWZ     1136191
# 214  TC                      Turks and Caicos Islands  TC  TCA       37665
# 215  TD                                          Chad  TD  TCD    15477751
# 216  TF                   French Southern Territories  TF  ATF         140
# 217  TG                                          Togo  TG  TGO     7889094
# 218  TH                                      Thailand  TH  THA    69428524
# 219  TJ                                    Tajikistan  TJ  TJK     9100837
# 220  TK                                       Tokelau  TK  TKL        1466
# 221  TL                                   Timor Leste  TL  TLS     1267972
# 222  TM                                  Turkmenistan  TM  TKM     5850908
# 223  TN                                       Tunisia  TN  TUN    11565204
# 224  TO                                         Tonga  TO  TON      103197
# 225  TR                                        Turkey  TR  TUR    82319724
# 226  TT                           Trinidad and Tobago  TT  TTO     1389858
# 227  TV                                        Tuvalu  TV  TUV       11508
# 228  TW                                        Taiwan  TW  TWN    22894384
# 229  TZ                                      Tanzania  TZ  TZA    56318348
# 230  UA                                       Ukraine  UA  UKR    44622516
# 231  UG                                        Uganda  UG  UGA    42723139
# 232  UM          United States Minor Outlying Islands  UM  UMI           0
# 233  US                                 United States  US  USA   327167434
# 234  UY                                       Uruguay  UY  URY     3449299
# 235  UZ                                    Uzbekistan  UZ  UZB    32955400
# 236  VA                                       Vatican  VA  VAT         921
# 237  VC              Saint Vincent and the Grenadines  VC  VCT      110211
# 238  VE                                     Venezuela  VE  VEN    28870195
# 239  VG                        British Virgin Islands  VG  VGB       29802
# 240  VI                           U.S. Virgin Islands  VI  VIR      106977
# 241  VN                                       Vietnam  VN  VNM    95540395
# 242  VU                                       Vanuatu  VU  VUT      292680
# 243  WF                             Wallis and Futuna  WF  WLF       16025
# 244  WS                                         Samoa  WS  WSM      196130
# 245  YE                                         Yemen  YE  YEM    28498687
# 246  YT                                       Mayotte  YT  MYT      159042
# 247  ZA                                  South Africa  ZA  ZAF    57779622
# 248  ZM                                        Zambia  ZM  ZMB    17351822
# 249  ZW                                      Zimbabwe  ZW  ZWE    14439018
# 250  CS                         Serbia and Montenegro  CS  SCG    10829175
# 251  AN                          Netherlands Antilles  AN  ANT      300000
#
#      areaSqKm parentId
# 0         468       EU
# 1       82880       AS
# 2      647500       AS
# 3         443
# 4         102
# 5       28748       EU
# 6       29800       AS
# 7     1246700       AF
# 8    14000000       AN
# 9     2766890       SA
# 10        199       OC
# 11      83858       EU
# 12    7686850       OC
# 13        193
# 14       1580       EU
# 15      86600       AS
# 16      51129       EU
# 17        431
# 18     144000       AS
# 19      30510       EU
# 20     274200       AF
# 21     110910       EU
# 22        665       AS
# 23      27830       AF
# 24     112620       AF
# 25         21
# 26         53
# 27       5770       AS
# 28    1098580       SA
# 29        328
# 30    8511965       SA
# 31      13940
# 32      47000       AS
# 33         49       AN
# 34     600370       AF
# 35     207600       EU
# 36      22966
# 37    9984670
# 38         14       AS
# 39    2345410       AF
# 40     622984       AF
# 41     342000       AF
# 42      41290       EU
# 43     322460       AF
# 44        240       OC
# 45     756950       SA
# 46     475440       AF
# 47    9596960       AS
# 48    1138910       SA
# 49      51100
# 50     110860
# 51       4033       AF
# 52        444
# 53        135       OC
# 54       9250       EU
# 55      78866       EU
# 56     357021       EU
# 57      23000       AF
# 58      43094       EU
# 59        754
# 60      48730
# 61    2381740       AF
# 62     283560       SA
# 63      45226       EU
# 64    1001450       AF
# 65     266000       AF
# 66     121320       AF
# 67     504782       EU
# 68    1127127       AF
# 69     337030       EU
# 70      18270       OC
# 71      12173       SA
# 72        702       OC
# 73       1399       EU
# 74     547030       EU
# 75     267667       AF
# 76     244820       EU
# 77        344
# 78      69700       AS
# 79      91000       SA
# 80         78       EU
# 81     239460       AF
# 82        6.5       EU
# 83    2166086
# 84      11300       AF
# 85     245857       AF
# 86       1780
# 87      28051       AF
# 88     131940       EU
# 89       3903       AN
# 90     108890
# 91        549       OC
# 92      36120       AF
# 93     214970       SA
# 94       1092       AS
# 95        412       AN
# 96     112090
# 97      56542       EU
# 98      27750
# 99      93030       EU
# 100   1919440       AS
# 101     70280       EU
# 102     20770       AS
# 103       572       EU
# 104   3287590       AS
# 105        60       AS
# 106    437072       AS
# 107   1648000       AS
# 108    103000       EU
# 109    301230       EU
# 110       116       EU
# 111     10991
# 112     92300       AS
# 113    377835       AS
# 114    582650       AF
# 115    198500       AS
# 116    181040       AS
# 117       811       OC
# 118      2170       AF
# 119       261
# 120    120540       AS
# 121     98480       AS
# 122     10908       EU
# 123     17820       AS
# 124       262
# 125   2717300       AS
# 126    236800       AS
# 127     10400       AS
# 128       616
# 129       160       EU
# 130     65610       AS
# 131    111370       AF
# 132     30355       AF
# 133     65200       EU
# 134      2586       EU
# 135     64589       EU
# 136   1759540       AF
# 137    446550       AF
# 138      1.95       EU
# 139     33843       EU
# 140     14026       EU
# 141        53
# 142    587040       AF
# 143     181.3       OC
# 144     25333       EU
# 145   1240000       AF
# 146    678500       AS
# 147   1565000       AS
# 148       254       AS
# 149       477       OC
# 150      1100
# 151   1030700       AF
# 152       102
# 153       316       EU
# 154      2040       AF
# 155       300       AS
# 156    118480       AF
# 157   1972550
# 158    329750       AS
# 159    801590       AF
# 160    825418       AF
# 161     19060       OC
# 162   1267000       AF
# 163      34.6       OC
# 164    923768       AF
# 165    129494
# 166     41526       EU
# 167    324220       EU
# 168    140800       AS
# 169        21       OC
# 170       260       OC
# 171    268680       OC
# 172    212460       AS
# 173     78200
# 174   1285220       SA
# 175      4167       OC
# 176    462840       OC
# 177    300000       AS
# 178    803940       AS
# 179    312685       EU
# 180       242
# 181        47       OC
# 182      9104
# 183      5970       AS
# 184     92391       EU
# 185       458       OC
# 186    406750       SA
# 187     11437       AS
# 188      2517       AF
# 189    237500       EU
# 190     88361       EU
# 191  17100000       EU
# 192     26338       AF
# 193   1960582       AS
# 194     28450       OC
# 195       455       AF
# 196   1861484       AF
# 197    644329       AF
# 198    449964       EU
# 199     692.7       AS
# 200       410       AF
# 201     20273       EU
# 202     62049       EU
# 203     48845       EU
# 204     71740       AF
# 205      61.2       EU
# 206    196190       AF
# 207    637657       AF
# 208    163270       SA
# 209      1001       AF
# 210     21040
# 211        21
# 212    185180       AS
# 213     17363       AF
# 214       430
# 215   1284000       AF
# 216      7829       AN
# 217     56785       AF
# 218    514000       AS
# 219    143100       AS
# 220        10       OC
# 221     15007       OC
# 222    488100       AS
# 223    163610       AF
# 224       748       OC
# 225    780580       AS
# 226      5128
# 227        26       OC
# 228     35980       AS
# 229    945087       AF
# 230    603700       EU
# 231    236040       AF
# 232         0       OC
# 233   9629091
# 234    176220       SA
# 235    447400       AS
# 236      0.44       EU
# 237       389
# 238    912050       SA
# 239       153
# 240       352
# 241    329560       AS
# 242     12200       OC
# 243       274       OC
# 244      2944       OC
# 245    527970       AS
# 246       374       AF
# 247   1219912       AF
# 248    752614       AF
# 249    390580       AF
# 250    102350       EU
# 251       960

# %%
countries.to_csv(NEO4J_HOME / "import/00e-GeoNamesCountry.csv", index=False)
