# %% [markdown]
# # Assigns location to Strain Data from CNCB
# **[Work in progress]**
#
# This notebook standardizes location information for viral strain from CNCB for ingestion into a Knowledge Graph.
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import pandas as pd
from pathlib import Path
from py2neo import Graph

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_HOME = Path(os.getenv('NEO4J_HOME'))
print(NEO4J_HOME)
# Out:
# /Users/peter/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-4af96121-2328-4e2f-ba60-6d8b728a26d5/installation-4.0.3

# %% [markdown]
# ## Standardize Location data for SARS-CoV-2 Strain metadata
#
# TODO this code should be replaced with a general solution.
#
# Below is a workaround for now.

# %%
df = pd.read_csv(NEO4J_HOME / "import/01d-CNCBStrain.csv", dtype='str')
df.fillna('', inplace=True)

# %%
df.head()
# Out:
#                                       id                            name  \
# 0                        NMDC60013088-01  BetaCoV/Wuhan/HBCDC-HB-01/2019
# 1  https://www.gisaid.org/EPI_ISL_402132  BetaCoV/Wuhan/HBCDC-HB-01/2019
# 2  https://www.gisaid.org/EPI_ISL_403963      BetaCoV/Nonthaburi/74/2020
# 3  https://www.gisaid.org/EPI_ISL_403962      BetaCoV/Nonthaburi/61/2020
# 4                        NMDC60013085-01   BetaCoV/Wuhan/IVDC-HB-04/2020
#
#                             alias        taxonomyId hostTaxonomyId  \
# 0  NMDC60013088-01;EPI_ISL_402132  taxonomy:2697049  taxonomy:9606
# 1  NMDC60013088-01;EPI_ISL_402132  taxonomy:2697049  taxonomy:9606
# 2                  EPI_ISL_403963  taxonomy:2697049  taxonomy:9606
# 3                  EPI_ISL_403962  taxonomy:2697049  taxonomy:9606
# 4  NMDC60013085-01;EPI_ISL_402120  taxonomy:2697049  taxonomy:9606
#
#   collectionDate                       location
# 0     2019-12-30                  China / Hubei
# 1     2019-12-30                  China / Hubei
# 2     2020-01-13  Thailand/ Nonthaburi Province
# 3     2020-01-08  Thailand/ Nonthaburi Province
# 4     2020-01-01          China / Hubei / Wuhan

# %% [markdown]
# #### Split locations

# %%
df['locationLevels'] = df['location'].str.count('/')

# %%
df[['location1', 'location2', 'location3', 'location4']] = df['location'].str.split('/', n=3, expand=True)

# %% [markdown]
# #### Clean up extra white space and NaN

# %%
# strip white space
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df.fillna('', inplace=True)

# %%
df.query("locationLevels == 3")
# Out:
#                                          id                              name  \
# 544   https://www.gisaid.org/EPI_ISL_414500      hCoV-19/England/Sheff01/2020
# 9786  https://www.gisaid.org/EPI_ISL_434572  hCoV-19/Czech Republic/2308/2020
#
#                alias        taxonomyId hostTaxonomyId collectionDate  \
# 544   EPI_ISL_414500  taxonomy:2697049  taxonomy:9606     2020-03-04
# 9786  EPI_ISL_434572  taxonomy:2697049  taxonomy:9606     2020-04-14
#
#                                                location  locationLevels  \
# 544    United Kingdom / England / Yorkshire / Sheffield               3
# 9786  Czech Republic / Vysocina Region / Bela - Lede...               3
#
#            location1        location2                location3       location4
# 544   United Kingdom          England                Yorkshire       Sheffield
# 9786  Czech Republic  Vysocina Region  Bela - Ledec na Sazavou  Havlickuv Brod

# %%
location1 = df['location1'].unique()

# %%
print(len(location1))
# Out:
# 86

# %%
graph = Graph("bolt://132.249.238.185:7687", user="reader", password="demo")

# %%
query = """
CALL db.index.fulltext.queryNodes("locations", $location) YIELD node, score
MATCH (node)-[:IN]->(next:Location)
RETURN node.name, labels(node), next.name, labels(next), score
LIMIT 3
"""

# %%
df_list = []
for location in location1:
    df_loc = graph.run(query, location = location).to_data_frame()
    df_loc['location1'] = location
    df_list.append(df_loc)
    
df_loc1 = pd.concat(df_list)

# %%
# failures: Czech Republic
df_loc1.head(100)
# Out:
#                           node.name         labels(node)  \
# 0                             China  [Location, Country]
# 0                          Thailand  [Location, Country]
# 0                     United States  [Location, Country]
# 0                            France  [Location, Country]
# 0                         Australia  [Location, Country]
# 0                           Germany  [Location, Country]
# 0                         Singapore  [Location, Country]
# 0                    United Kingdom  [Location, Country]
# 0                       South Korea  [Location, Country]
# 0                             Japan  [Location, Country]
# 0                           Belgium  [Location, Country]
# 0                           Vietnam  [Location, Country]
# 0                             Nepal  [Location, Country]
# 0                             Italy  [Location, Country]
# 0                          Cambodia  [Location, Country]
# 0                            Sweden  [Location, Country]
# 0                            Brazil  [Location, Country]
# 0                            Mexico  [Location, Country]
# 0                            Canada  [Location, Country]
# 0                       Switzerland  [Location, Country]
# 0                       New Zealand  [Location, Country]
# 0                             India  [Location, Country]
# 0                       Netherlands  [Location, Country]
# 0                        Luxembourg  [Location, Country]
# 0                           Finland  [Location, Country]
# 0                          Portugal  [Location, Country]
# 0                           Ireland  [Location, Country]
# 0                             Chile  [Location, Country]
# 0                             Spain  [Location, Country]
# 0                           Georgia  [Location, Country]
# 0                            Russia  [Location, Country]
# 0                           Denmark  [Location, Country]
# 0                           Hungary  [Location, Country]
# 0                      Saudi Arabia  [Location, Country]
# 0                            Kuwait  [Location, Country]
# 0                            Poland  [Location, Country]
# 0                         Lithuania  [Location, Country]
# 0                          Republic     [Location, City]
# 0                          Malaysia  [Location, Country]
# 0                          Pakistan  [Location, Country]
# 0                            Turkey  [Location, Country]
# 0  Democratic Republic of the Congo  [Location, Country]
# 0                            Norway  [Location, Country]
# 0                           Iceland  [Location, Country]
# 0                          Slovakia  [Location, Country]
# 0                          Colombia  [Location, Country]
# 0                           Senegal  [Location, Country]
# 0                           Algeria  [Location, Country]
# 0                            Greece  [Location, Country]
# 0                            Israel  [Location, Country]
# 0                           Austria  [Location, Country]
# 0                            Latvia  [Location, Country]
# 0                           Belarus  [Location, Country]
# 0                           Estonia  [Location, Country]
# 0                          Slovenia  [Location, Country]
# 0                         Argentina  [Location, Country]
# 0                      South Africa  [Location, Country]
# 0                              Iran  [Location, Country]
# 0                             Qatar  [Location, Country]
# 0                         Sri Lanka  [Location, Country]
# 0                            Gambia  [Location, Country]
# 0                            Jordan  [Location, Country]
# 0                             Egypt  [Location, Country]
# 0                       Philippines  [Location, Country]
# 0                        Kazakhstan  [Location, Country]
# 0              United Arab Emirates  [Location, Country]
# 0                        Costa Rica  [Location, Country]
# 0                         Indonesia  [Location, Country]
# 0                            Brunei  [Location, Country]
# 0                            Serbia  [Location, Country]
# 0                        Bangladesh  [Location, Country]
# 0                           Uruguay  [Location, Country]
# 0                           Romania  [Location, Country]
# 0                           Romania  [Location, Country]
# 0                           Lebanon  [Location, Country]
# 0                           Jamaica  [Location, Country]
# 0                            Uganda  [Location, Country]
# 0                           Croatia  [Location, Country]
# 0                           Nigeria  [Location, Country]
# 0                              Oman  [Location, Country]
# 0                             Kenya  [Location, Country]
# 0                           Morocco  [Location, Country]
# 0            Bosnia and Herzegovina  [Location, Country]
# 0                           Tunisia  [Location, Country]
# 0                            Cyprus  [Location, Country]
# 0                          Mongolia  [Location, Country]
#
#                    next.name                      labels(next)      score  \
# 0               Eastern Asia           [Location, UNSubRegion]   5.306468
# 0         South-eastern Asia           [Location, UNSubRegion]   6.248669
# 0           Northern America           [Location, UNSubRegion]   8.596201
# 0             Western Europe           [Location, UNSubRegion]   5.255381
# 0  Australia and New Zealand           [Location, UNSubRegion]   5.687883
# 0             Western Europe           [Location, UNSubRegion]   5.987919
# 0         South-eastern Asia           [Location, UNSubRegion]   5.987919
# 0            Northern Europe           [Location, UNSubRegion]   8.596201
# 0               Eastern Asia           [Location, UNSubRegion]   6.904882
# 0               Eastern Asia           [Location, UNSubRegion]   6.248669
# 0             Western Europe           [Location, UNSubRegion]   5.687883
# 0         South-eastern Asia           [Location, UNSubRegion]   6.248669
# 0              Southern Asia           [Location, UNSubRegion]   6.248669
# 0            Southern Europe           [Location, UNSubRegion]   5.816166
# 0         South-eastern Asia           [Location, UNSubRegion]   6.248669
# 0            Northern Europe           [Location, UNSubRegion]   6.248669
# 0              South America  [Location, UNIntermediateRegion]   5.987919
# 0            Central America  [Location, UNIntermediateRegion]   4.994630
# 0           Northern America           [Location, UNSubRegion]   4.592162
# 0             Western Europe           [Location, UNSubRegion]   5.987919
# 0  Australia and New Zealand           [Location, UNSubRegion]   6.894639
# 0              Southern Asia           [Location, UNSubRegion]   5.816166
# 0             Western Europe           [Location, UNSubRegion]   5.987919
# 0             Western Europe           [Location, UNSubRegion]   5.585451
# 0            Northern Europe           [Location, UNSubRegion]   5.816166
# 0            Southern Europe           [Location, UNSubRegion]   5.816166
# 0            Northern Europe           [Location, UNSubRegion]   5.816166
# 0              South America  [Location, UNIntermediateRegion]   5.816166
# 0            Southern Europe           [Location, UNSubRegion]   5.816166
# 0               Western Asia           [Location, UNSubRegion]   5.816166
# 0             Eastern Europe           [Location, UNSubRegion]   5.816166
# 0            Northern Europe           [Location, UNSubRegion]   5.306468
# 0             Eastern Europe           [Location, UNSubRegion]   6.248669
# 0               Western Asia           [Location, UNSubRegion]   9.351385
# 0               Western Asia           [Location, UNSubRegion]   5.987919
# 0             Eastern Europe           [Location, UNSubRegion]   5.427132
# 0            Northern Europe           [Location, UNSubRegion]   6.248669
# 0             Fayette County                [Location, Admin2]   4.822878
# 0         South-eastern Asia           [Location, UNSubRegion]   6.248669
# 0              Southern Asia           [Location, UNSubRegion]   6.248669
# 0               Western Asia           [Location, UNSubRegion]   5.687883
# 0              Middle Africa  [Location, UNIntermediateRegion]  10.182800
# 0            Northern Europe           [Location, UNSubRegion]   5.585451
# 0            Northern Europe           [Location, UNSubRegion]   6.248669
# 0             Eastern Europe           [Location, UNSubRegion]   5.987919
# 0              South America  [Location, UNIntermediateRegion]   5.166382
# 0             Western Africa  [Location, UNIntermediateRegion]   6.248669
# 0            Northern Africa           [Location, UNSubRegion]   6.248669
# 0            Southern Europe           [Location, UNSubRegion]   5.687883
# 0               Western Asia           [Location, UNSubRegion]   6.248669
# 0             Western Europe           [Location, UNSubRegion]   5.816166
# 0            Northern Europe           [Location, UNSubRegion]   6.248669
# 0             Eastern Europe           [Location, UNSubRegion]   6.248669
# 0            Northern Europe           [Location, UNSubRegion]   6.248669
# 0            Southern Europe           [Location, UNSubRegion]   6.248669
# 0              South America  [Location, UNIntermediateRegion]   5.585451
# 0            Southern Africa  [Location, UNIntermediateRegion]   6.394973
# 0              Southern Asia           [Location, UNSubRegion]   6.248669
# 0               Western Asia           [Location, UNSubRegion]   6.248669
# 0              Southern Asia           [Location, UNSubRegion]   8.791312
# 0             Western Africa  [Location, UNIntermediateRegion]   6.248669
# 0               Western Asia           [Location, UNSubRegion]   4.994630
# 0            Northern Africa           [Location, UNSubRegion]   5.585451
# 0         South-eastern Asia           [Location, UNSubRegion]   6.248669
# 0               Central Asia           [Location, UNSubRegion]   5.816166
# 0               Western Asia           [Location, UNSubRegion]  10.362250
# 0            Central America  [Location, UNIntermediateRegion]   7.096967
# 0         South-eastern Asia           [Location, UNSubRegion]   6.248669
# 0         South-eastern Asia           [Location, UNSubRegion]   5.987919
# 0            Southern Europe           [Location, UNSubRegion]   5.816166
# 0              Southern Asia           [Location, UNSubRegion]   6.248669
# 0              South America  [Location, UNIntermediateRegion]   5.816166
# 0             Eastern Europe           [Location, UNSubRegion]   5.987919
# 0             Eastern Europe           [Location, UNSubRegion]   5.987919
# 0               Western Asia           [Location, UNSubRegion]   4.711062
# 0                  Caribbean  [Location, UNIntermediateRegion]   5.255381
# 0             Eastern Africa  [Location, UNIntermediateRegion]   6.248669
# 0            Southern Europe           [Location, UNSubRegion]   6.248669
# 0             Western Africa  [Location, UNIntermediateRegion]   6.248669
# 0               Western Asia           [Location, UNSubRegion]   5.987919
# 0             Eastern Africa  [Location, UNIntermediateRegion]   6.248669
# 0            Northern Africa           [Location, UNSubRegion]   5.987919
# 0            Southern Europe           [Location, UNSubRegion]   9.929264
# 0            Northern Africa           [Location, UNSubRegion]   6.248669
# 0               Western Asia           [Location, UNSubRegion]   6.248669
# 0               Eastern Asia           [Location, UNSubRegion]   5.987919
#
#                           location1
# 0                             China
# 0                          Thailand
# 0                     United States
# 0                            France
# 0                         Australia
# 0                           Germany
# 0                         Singapore
# 0                    United Kingdom
# 0                       South Korea
# 0                             Japan
# 0                           Belgium
# 0                           Vietnam
# 0                             Nepal
# 0                             Italy
# 0                          Cambodia
# 0                            Sweden
# 0                            Brazil
# 0                            Mexico
# 0                            Canada
# 0                       Switzerland
# 0                       New Zealand
# 0                             India
# 0                       Netherlands
# 0                        Luxembourg
# 0                           Finland
# 0                          Portugal
# 0                           Ireland
# 0                             Chile
# 0                             Spain
# 0                           Georgia
# 0                            Russia
# 0                           Denmark
# 0                           Hungary
# 0                      Saudi Arabia
# 0                            Kuwait
# 0                            Poland
# 0                         Lithuania
# 0                    Czech Republic
# 0                          Malaysia
# 0                          Pakistan
# 0                            Turkey
# 0  Democratic Republic of the Congo
# 0                            Norway
# 0                           Iceland
# 0                          Slovakia
# 0                          Colombia
# 0                           Senegal
# 0                           Algeria
# 0                            Greece
# 0                            Israel
# 0                           Austria
# 0                            Latvia
# 0                           Belarus
# 0                           Estonia
# 0                          Slovenia
# 0                         Argentina
# 0                      South Africa
# 0                              Iran
# 0                             Qatar
# 0                         Sri Lanka
# 0                            Gambia
# 0                            Jordan
# 0                             Egypt
# 0                       Philippines
# 0                        Kazakhstan
# 0              United Arab Emirates
# 0                        Costa Rica
# 0                         Indonesia
# 0                            Brunei
# 0                            Serbia
# 0                        Bangladesh
# 0                           Uruguay
# 0                          ‎Romania
# 0                           Romania
# 0                           Lebanon
# 0                           Jamaica
# 0                            Uganda
# 0                           Croatia
# 0                           Nigeria
# 0                              Oman
# 0                             Kenya
# 0                           Morocco
# 0            Bosnia and Herzegovina
# 0                           Tunisia
# 0                            Cyprus
# 0                          Mongolia

# %%
location2 = df.query("location2 != ''")['location2'].unique()

# %%
print(len(location2))
# Out:
# 891

# %%
print(location2)
# Out:
# ['Hubei' 'Nonthaburi Province' 'Zhejiang' 'Guangdong Province' 'Guangdong'
#  'Washington' 'Illinois' 'Taiwan' 'California' 'Arizona' 'Ile-de-France'
#  'Yunnan' 'Victoria' 'Bavaria' 'Gyeonggi-do' 'Aichi' 'Queensland'
#  'New South Wales' 'Leuven' 'Chongqing' 'Sichuan' 'Ile De France'
#  'Jiangxi' 'Jiangsu' 'Shandong' 'Tokyo' 'Thanh Hoa' 'Kyoto' 'Wisconsin'
#  'Massachusetts' 'Kathmandu' 'Beijing' 'Rhone-Alpes' 'Nara' 'Osaka'
#  'Guangxi' 'Rome' 'Fujian' 'Sihanoukville' 'Texas' 'Anhui' 'Hong Kong'
#  'Chungcheongnam-do' 'Seoul' 'Baden-Wuerttemberg' 'Sao Paulo' 'Kanagawa'
#  'Lombardy' 'Mexico City' 'Ontario' 'Zurich' 'North Rhine Westphalia'
#  'Auckland' 'Kerala State' 'Wales' 'Haarlem' 'Blaricum'
#  'Hardinxveld Giessendam' 'Naarden' 'Utrecht' 'Zeewolde' 'Nootdorp'
#  'Oisterwijk' 'Tilburg' 'Rotterdam' 'NSW' 'Helsinki' 'Shanghai' 'Geneva'
#  'Argovie' 'Vaud' 'Basel' 'England' 'Tessin' 'Scotland' 'Zuid Holland'
#  'Noord Brabant' 'Noord Holland' 'Gelderland' 'New York' 'Cork' 'MN'
#  'Munich' 'Talca' 'Santiago' 'Limerick' 'Grand-Est' 'Normandie'
#  'Hauts de France' 'Rio de Janeiro' 'Pays de la Loire' 'Bahia'
#  'Espirito Santo' 'Huldenberg' 'Kraainem' 'Sint-Niklaas' 'Brussels'
#  'Genève' 'Flevoland' 'Limburg' 'Utah' 'CA' 'Ho Chi Minh city' 'Valencia'
#  'British Columbia' 'Tbilisi' 'Hauts-de-France' 'IDF'
#  'Bourgogne-France-Comté' 'Hangzhou' 'Saint Petersburg' 'Distrito Federal'
#  'Copenhagen' 'Budapest' 'Quangning' 'Vinhphuc' 'Hanoi' 'Riyadh' 'Hawali'
#  'Holsbeek' 'Kessel-Lo' 'Couthuin' 'Comunitat_Valenciana' 'Zielonogorskie'
#  'WI' 'Ile de France' 'Bretagne' 'Saitama' 'Wellington' 'Dasman'
#  'Connecticut' 'Vilnius' 'Prague' 'Baranya' 'ARA' 'Selangor'
#  'New York City' 'Castilla y León' 'Liège' 'Galicia' 'Madrid'
#  'Amazonas State' 'Gilgit' 'Minnesota' 'Otago' 'Idaho'
#  'Friuli Venezia Giulia' 'Dilbeek' 'Kasterlee' 'Schoten'
#  'Sint-Pieters-Woluwe' 'Rixensart' 'Vorst' 'Kinshasa' 'Duesseldorf' 'Oslo'
#  'Marche' 'Reykjavik' 'Kostoliste' 'Bratislava' 'Kosice' 'Martin'
#  'Kuala Lumpur' 'Medellin' 'Oregon' 'Dakar' 'Touba' 'Centre-Val de Loire'
#  'Boufarik' 'Blida' 'Abruzzo' 'Castilla-La Mancha' 'Castilla La Mancha'
#  'Castilla y Leon' 'Andalusia' 'Basque Country' 'Catalonia' 'Antwerp'
#  'Athens' 'Tipperary' 'Dublin' 'Louth' 'Wicklow' 'Houthalen-Helchteren'
#  'Zonhoven' 'Nevele' 'Ganshoren' 'Kalmthout' 'Chaineux' 'Gierle'
#  'Antioquia' 'Deinze' 'Beersel' 'SK' 'NB' 'MB' 'NS' 'Barcelona' 'Komen'
#  'Virginia' 'Merelbeke' 'Oevel' 'Asse' 'Kaulile' 'Ellezelles' 'Eupen'
#  'KPK' 'WA' 'Ramat Gan' 'Canary Islands' 'LaRioja' 'Ghent' 'Kochi' 'Chiba'
#  'Ishikawa' 'Lisbon' 'Rhode Island' 'Georgia' 'Florida'
#  'Comunitat Valenciana' 'Riga' 'BasqueCountry' 'Northern Territory' 'OR'
#  'Bourgogne-Franche Comte' 'St-Louis' 'Wuhan' 'Alaska' 'Brussel'
#  'Yernee-fraineux' 'Montigny-le-Tilleul' 'Elsene' 'Waterloo'
#  'Braine-le-Chateau' 'Poppel' 'Winksele' 'Alken' 'Riemst' 'Neerpelt'
#  'Bree' 'Herstal' 'Seraing' 'Berloz' 'Bierset' 'Soumagne' 'Herve' 'Saive'
#  'Limbourg' 'Henri-chapelle' 'Theux' 'Temploux' 'Andenne' 'Havelange'
#  'Couvin' 'Charleroi' 'Courcelles' 'Havre' 'Haulchin' 'Geluwe' 'Gent'
#  'Sint-Gillis-Waas' 'Stekene' 'Waasmunster' 'Ronse' 'Etterbeek'
#  'Honnelles' 'Doornik' 'Villerot' 'Quevy' 'Watermaal-Bosvoorde'
#  'Anderlecht' 'Liege' 'Oudergem' 'Knokke-Heist' 'Boussu' 'La Louviere'
#  'Namur' 'Hemisem' 'Couillet' 'Tervuren' 'Zinnik' 'Beringen' 'Frameries'
#  'Tienen' 'Jemappes' 'Saisinne' 'Bassilly' 'Vilvoorde' 'Genappe'
#  'Sint-Agatha-Berchem' 'Mons' 'Quaregnon' 'Linter' 'Bierbeek'
#  'Sint-Pieter-Woluwe' 'Trazegnies' 'Colfontaine' 'Ukkel' 'Zoutleeuw'
#  'Lummen' 'Ath' 'Zolder' 'Geraardsbergen' 'Sint-Truiden' 'Confontaine'
#  'Quevaucamps' 'Braine-l alleud' 'Blandain' 'Tubize' 'Koersel' 'Mouscron'
#  'Wanze' 'Montignies-Sur-Sambre' 'Lasne' 'Saint-Ghislain' 'Nieuwerkerken'
#  'Forchies-la-marche' 'Tielt-Winge' 'Soignies' 'Boutersem' 'Ladeuze'
#  'Cuesmes' 'Saint-Saulve' 'Helden' 'Fontaine-l Eveque' 'Tertre' 'Jumet'
#  'Grimbergen' 'Herselt' 'Kain' 'Sint-Genesius-Rode' 'Lubbeek' 'Hasselt'
#  'Lanaken' 'Wandre' 'Oostrozebeke' 'Western Australia' 'Teramo'
#  'Castel di Sangro' 'New Hampshire' 'Moscow' 'Indiana' 'Wyoming'
#  'North Carolina' 'Centre - Val de Loire' 'KZN' 'New Jersey' 'NC' 'OHIO'
#  'Columbus OH' 'Veneto' 'Friesland' 'VA' 'Bangkok' 'Kayseri'
#  'Estado de Mexico' 'Queretaro' 'Puebla' 'CDMX' 'South Carolina'
#  'District of Columbia' 'Iowa' 'Kansas' 'Louisiana' 'Maryland' 'Missouri'
#  'Nebraska' 'Nevada' 'Ohio' 'Pennsylvania' 'KwaZulu-Natal' 'AZ' 'DC' 'FL'
#  'GA' 'IA' 'IL' 'IN' 'KS' 'LA' 'MA' 'MD' 'MO' 'NE' 'NH' 'NJ' 'NV' 'OH'
#  'PA' 'RI' 'SC' 'UT' 'NY' 'Vasterbotten' 'Toulouse'
#  'Central Czechia and Prague' 'Gujarat' 'CT' 'HI' 'Northern territory'
#  'Alagoas' 'Santa Catarina' 'Saint-Petersburg' 'Istanbul' 'Doha'
#  'Västerbotten' 'Grand-est' 'Hauts De France' 'New Orleans' 'Kastamonu'
#  'Nevsehir' 'Ankara' 'Kocaeli' 'Balikesir' 'Aksaray' 'West Coast Region'
#  'Lipetsk Region' 'Krasnodar Region' 'St. Petersburg' 'Moscow Region'
#  'Krasnoyarsk Region' 'Sverdlovsk Region' 'Republic of Sakha (Yakutia)'
#  'Omsk Region' 'Khabarovsk Region' 'Samara Region'
#  'Republic of Kabardino-Balkaria' 'Republic of Buryatia' 'Perm Region'
#  'Republic of Crymea' 'Orenburg Region' 'Primorskiy Region' 'Pskov Region'
#  'Chechen Republic' 'Sakhalin Region' 'Tatarstan' 'Novosibirsk Region'
#  'Tver Region' 'Chelyabinsk Region' 'Malopolskie' 'Halland' 'Sormland'
#  'Norrbotten' 'Varmland' 'Orebro lan' 'Ostergotland' 'Stockholm'
#  'Gavleborgs lan' 'Unknown' 'Minas gerais' 'PE' 'NL' 'Sakarya' 'Afyon'
#  'Eskisehir' 'Konya' 'Amman' 'Irbid' 'St.Petersburg' 'Buryat Republic'
#  'GP' 'West Bengal' 'West_Bengal' 'Ciudad Autonoma de Buenos Aires'
#  'Buenos Aires' 'Rio Negro' 'Nonthaburi' 'Milheeze' 'Manila'
#  'Vysocina Region' 'Occitanie' 'Uppsala' 'Dalarna' 'Skane' 'Jamtland'
#  'Vastra Gotaland' 'Vastmanland' 'Michigan' 'Nur-Sultan' 'Uttar Pradesh'
#  'Delhi' 'Mumbai' 'Tamil Nadu' 'Nepal' 'Ladakh' 'Bihar' 'Samut Prakarn'
#  'Telangana' 'Puerto_Rico' 'Jakarta' 'Balatonfured' 'Balassagyarmat'
#  'Szeged' 'Kecskemet' 'Oroshaza' 'Bekesszentandras' 'Dolnoslaskie' 'VI'
#  'Rajsathan' 'Assam' 'Andhra Pradesh' 'Karnataka' 'Madhya Pradesh'
#  'Pittsburgh' 'MI' 'Styria' 'Mardin' 'Denizli' 'Agri' 'Tekirdag' 'Tokat'
#  'Montana' 'Kraljevo' 'Novi Pazar' 'Makkah' 'Madinah' 'Jeddah' 'Kanto'
#  'Dolnoslakie' 'Telengana' 'MAKKAH' 'MADINAH' 'JEDDAH' 'Dhaka' 'Ischgl'
#  'Innsbruck' 'Matrei am Brenner' 'Strass im Zillertal' 'Elbigenalp'
#  'Aldrans' 'Ramsau im Zillertal' 'Steinach am Brenner' 'Zams'
#  'Seefeld in Tirol' 'Kematen In Tirol' 'Laengenfeld' 'St. Anton'
#  'Sistrans' 'Vienna' 'Cruise ship' 'Tyrol' 'South Tyrol' 'Burgenland'
#  'Northern Ireland' 'Tehran' 'Semnan' 'Bourgogne'
#  'Bourgogne Franche comte' 'Hyderabad' 'Montevideo' 'Quebec' 'Guam' 'AK'
#  'Bucharest' 'Brasov' 'Puerto Montt' 'Antofagasta' 'Punta Arenas' 'Temuco'
#  'Chillan' 'Valparaiso' 'Rancagua' 'Concepcion' 'Coyhaique' 'VT' 'PR'
#  'Constanta' 'South Coast District' 'South District' 'North District'
#  'Tel Aviv District' 'Jerusalem District' 'Caldas' 'Valle del Cauca'
#  'Boyaca' 'Cundinamarca' 'Narino' 'Choco' 'Huila' 'Tolima' 'Risaralda'
#  'Magdalena' 'Cordoba' 'Norte de santander' 'Meta' 'Phuket'
#  'Ho Chi Minh City' 'Leningrad region' 'Wielkopolskie' 'Maharashtra'
#  'Chattogram' 'Trondheim' 'Beirut' 'Pomorskie' 'Karachi' 'Pomerania'
#  'Kalmar' 'Jonkoping' 'Dane County' 'Madison' 'Mount Horeb' 'Verona'
#  'Para' 'South Australia' 'Lazio' 'Lombardia' 'Pomorze' 'Basel Land'
#  'Basel Stadt' 'Ticino' 'Valais' 'Jura' 'Schwyz' 'Bern' 'Aargau'
#  'Graubunden' 'Uri' 'Geneve' 'Schaffhausen' 'Glarus' 'Varaždin County'
#  'Apulia' 'Malopolska' 'New Mexico' 'Virgin Islands' 'Colorado'
#  'Frankfurt' 'Navarra' 'Basque_Country' 'Leiden' 'Gavleborg'
#  'Vasternorrland' 'Istria' 'Split' 'Dubrovnik' 'Varazdin' 'Pula' 'Cacak'
#  'Rajasthan' 'Haryana' 'Pahang' 'Melilla' 'Kwara State' 'Ogun State'
#  'Osun State' 'Oyo State' 'Guerrero' 'Quintana Roo' 'Mazowieckie'
#  'Warminsko-Mazurskie' 'Wielkopolska' 'Bucuresti' 'Buzau' 'Arges'
#  'Nakhonnayok' 'Trang' 'Quangninh' 'Odisha' 'Orebro' 'Armenia' 'Leticia'
#  'Bello' 'Cartagena' 'Bucaramanga' 'Cali' 'Cienaga' 'Tumaco' 'Pereira'
#  'Southern' 'Combined Wellington' 'Lakes' 'Waikato' 'Wairarapa'
#  'Bay of Plenty' 'Counties Manukau' 'Nelson Marlborough' 'Canterbury'
#  'Waitemata' 'MidCentral' 'Emilia-Romagna' 'PA Trento' 'Muscat' 'Sicily'
#  "Valle D'Aosta" 'Molise' 'Basilicata' 'Rostock' 'Washington DC'
#  'Sardinia' 'North Batinah' 'Musca' 'South Batinah' 'Dakhiliyah' 'Buraimi'
#  'Muscta' 'Amapa' 'Acre' 'Maranhao' 'Kaggevinne' 'Sterrebeek' 'Geetbets'
#  'Dour' 'La louvière' 'Mon' 'Seneffe' 'Baudour' "Braine-l'alleud"
#  'Machelen' 'Veltem-beisem' 'Sint-pieters-woluwe' 'Laken' 'Shape' 'Flénu'
#  'Jette' 'Molenstede' 'Luttre' 'Wilrijk' 'Givry' 'Mepel' 'Le roeulx'
#  'Temse' 'Neufmaison' 'Jurbise' 'Lotenhulle' 'Edingen' 'Thulin' 'Wilsele'
#  'Paal' 'Wadelincourt' 'Madegem' 'Quévy' 'Ghlin' 'Grand-Leez' 'Morlanwelz'
#  'Bury' 'Malle' 'Aarschot' 'Tessenderlo' 'Scherpenheuvel-Zichem'
#  'Overijse' 'Wespelaar' 'Ramsel' 'Puerto Natales' 'Heilongjiang'
#  'Novi Sad' 'Uzice' 'Drenthe' 'Overijssel' 'Zeeland' 'La Calamine'
#  'Bullingen' 'Membach' 'Olen' 'Balen' 'Rijkevorsel' 'Ciney' 'La Louvière'
#  'Binche' 'Casteau' 'Genval' 'Poperinge' 'Anzegem' 'Kuurne'
#  'Montignies-sur-sambre' 'Marcinelle' 'Mellet' 'Chatelet' 'Dolembreux'
#  'Bressoux' 'Voroux-les-Liers' 'Laakdaal' 'Oostmalle' 'Beerse' 'Zoersel'
#  'Wijnegem' 'Bottelare' 'Champion' 'Ettelgem' 'Oostende' 'Asper'
#  'Blankenberge' 'Berchem' 'Genk' 'Maaseik' 'Eisden' 'Beverst' 'Wingene'
#  'Torhout' 'Assebroek' 'Brugge' 'Beerst' 'Burdinne' 'Bevel' 'Antheit'
#  'Mol' 'Retie' 'Broechem' 'Arbre' 'Buzet' 'Fontaine-Valmont' 'Lamine'
#  'Waasmont' 'Ploegsteert' 'Ans' 'Lo' 'Deerlijk' 'Bevere' 'Blaasveld'
#  'Breendonk' 'Bornem' 'Vlamertinge' 'Harelbeke' 'Avelgem' 'Brasschaat'
#  'Ekeren' 'Aisemont' 'Goutroux' 'Beuzet' 'Ransart' 'Mariakerke'
#  'Lovendegem' 'Kalken' 'Gentbrugge' 'Overpelt' 'Lommel' 'Heppen'
#  'Grote-Brogel' 'Bocholt' 'Berg' 'Kermt' 'Lippelo' 'Buggenhout' 'Hamme'
#  'Aiseau' 'Sint-Jans-Molenbeek' 'Ere' 'Wezembeek-Oppem' 'Lessines'
#  'Antwerpen' 'Beveren-Waas' 'Basecles' 'Roucourt' 'Bazel' 'Bauffe'
#  'Vorselaar' 'Turnhout' 'Oud-Turnhout' 'Ravels' 'Grobbendonk' 'Bihac'
#  'Gorazde' 'Sarajevo' 'Novi Travnik' 'Maglaj' 'Breza' 'Ilidza' 'Cazin'
#  'Ilijas' 'DZ Vitez' 'Zepce' 'Gornji Vakuf' 'KZ Kakanj' 'ASTURIAS' 'Livno'
#  'Čelinac' 'Tuzla' 'Toronto' 'Blanden' 'Brugelette' 'Vloesberg' 'Rebecq'
#  'Kortenberg' 'Buissenal' 'Monceau-sur-sambre' 'Brunehaut'
#  'Lillois-witterzée' 'Western Cape Province' 'Narayanganj' 'Chittagong'
#  'Hannut' 'Solothurn' 'Graubünden' 'Zürich' 'Canary_Islands' 'San Diego'
#  'Laocai' 'East Kalimantan' 'North Sulawesi' 'Teleorman' 'Tennessee' 'KY']

# %%
location2 = location2[60:80]
print(location2)
# Out:
# ['Zeewolde' 'Nootdorp' 'Oisterwijk' 'Tilburg' 'Rotterdam' 'NSW' 'Helsinki'
#  'Shanghai' 'Geneva' 'Argovie' 'Vaud' 'Basel' 'England' 'Tessin'
#  'Scotland' 'Zuid Holland' 'Noord Brabant' 'Noord Holland' 'Gelderland'
#  'New York']

# %%
df_list = []
for location in location2:
    df_loc = graph.run(query, location = location).to_data_frame()
    df_loc['location2'] = location
    df_list.append(df_loc)
    
df_loc2 = pd.concat(df_list)

# %%
df_loc2.head(100)
# Out:
#                      node.name        labels(node)                 next.name  \
# 0                     Zeewolde    [Location, City]         Gemeente Zeewolde
# 1            Gemeente Zeewolde  [Location, Admin2]                 Flevoland
# 0  Gemeente Pijnacker-Nootdorp  [Location, Admin2]             South Holland
# 0                   Oisterwijk    [Location, City]       Gemeente Oisterwijk
# 1          Gemeente Oisterwijk  [Location, Admin2]             North Brabant
# 0                      Tilburg    [Location, City]          Gemeente Tilburg
# 1             Gemeente Tilburg  [Location, Admin2]             North Brabant
# 0                    Rotterdam    [Location, City]        Gemeente Rotterdam
# 1                    Rotterdam    [Location, City]        Schenectady County
# 2           Gemeente Rotterdam  [Location, Admin2]             South Holland
# 0                     Helsinki  [Location, Admin2]                   Uusimaa
# 1                     Helsinki    [Location, City]                  Helsinki
# 0                     Shanghai  [Location, Admin1]                     China
# 1                     Shanghai    [Location, City]                  Shanghai
# 0                       Geneva  [Location, Admin1]               Switzerland
# 1                       Geneva  [Location, Admin2]                    Geneva
# 2                       Geneva    [Location, City]           Seminole County
# 0                         Vaud  [Location, Admin1]               Switzerland
# 1                      Le Vaud    [Location, City]             Nyon District
# 2        Gros-de-Vaud District  [Location, Admin2]                      Vaud
# 0                        Basel    [Location, City]               Basel-Stadt
# 1                   Basel-City  [Location, Admin1]               Switzerland
# 2             Basel-Landschaft  [Location, Admin1]               Switzerland
# 0                      England  [Location, Admin1]            United Kingdom
# 1                      England    [Location, City]             Lonoke County
# 2                  Old England  [Location, Admin2]                Manchester
# 0                     Scotland  [Location, Admin1]            United Kingdom
# 1                     Scotland    [Location, City]           Franklin County
# 2              Scotland County  [Location, Admin2]            North Carolina
# 0                         Zuid  [Location, Admin2]                      Para
# 1                      Holland  [Location, Admin2]             St. Elizabeth
# 2                      Holland    [Location, City]            Hampden County
# 0                        Noord  [Location, Admin2]                      Para
# 1                North Brabant  [Location, Admin1]               Netherlands
# 2             Noord-Scharwoude    [Location, City]        Gemeente Langedijk
# 0                        Noord  [Location, Admin2]                      Para
# 1                      Holland  [Location, Admin2]             St. Elizabeth
# 2                      Holland    [Location, City]            Hampden County
# 0                   Gelderland  [Location, Admin1]               Netherlands
# 0                     New York  [Location, Admin1]  Middle Atlantic Division
# 1                     New York  [Location, Admin1]             United States
# 2                East New York    [Location, City]              Kings County
#
#              labels(next)     score      location2
# 0      [Location, Admin2]  5.987919       Zeewolde
# 1      [Location, Admin1]  4.480581       Zeewolde
# 0      [Location, Admin1]  3.735385       Nootdorp
# 0      [Location, Admin2]  5.987919     Oisterwijk
# 1      [Location, Admin1]  4.480581     Oisterwijk
# 0      [Location, Admin2]  5.987919        Tilburg
# 1      [Location, Admin1]  4.480581        Tilburg
# 0      [Location, Admin2]  5.816166      Rotterdam
# 1      [Location, Admin2]  5.816166      Rotterdam
# 2      [Location, Admin1]  4.352064      Rotterdam
# 0      [Location, Admin1]  5.987919       Helsinki
# 1      [Location, Admin2]  5.987919       Helsinki
# 0     [Location, Country]  5.987919       Shanghai
# 1      [Location, Admin1]  5.987919       Shanghai
# 0     [Location, Country]  4.913864         Geneva
# 1      [Location, Admin1]  4.913864         Geneva
# 2      [Location, Admin2]  4.913864         Geneva
# 0     [Location, Country]  5.816166           Vaud
# 1      [Location, Admin2]  4.352064           Vaud
# 2      [Location, Admin1]  2.894699           Vaud
# 0      [Location, Admin2]  5.687883          Basel
# 1     [Location, Country]  4.256073          Basel
# 2     [Location, Country]  4.256073          Basel
# 0     [Location, Country]  5.585451        England
# 1      [Location, Admin2]  5.585451        England
# 2      [Location, Admin1]  4.179426        England
# 0     [Location, Country]  5.363243       Scotland
# 1      [Location, Admin2]  5.363243       Scotland
# 2      [Location, Admin1]  4.013155       Scotland
# 0      [Location, Admin1]  5.500178   Zuid Holland
# 1      [Location, Admin1]  4.822878   Zuid Holland
# 2      [Location, Admin2]  4.822878   Zuid Holland
# 0      [Location, Admin1]  5.427132  Noord Brabant
# 1     [Location, Country]  4.352064  Noord Brabant
# 2      [Location, Admin2]  4.060961  Noord Brabant
# 0      [Location, Admin1]  5.427132  Noord Holland
# 1      [Location, Admin1]  4.822878  Noord Holland
# 2      [Location, Admin2]  4.822878  Noord Holland
# 0     [Location, Country]  6.248669     Gelderland
# 0  [Location, USDivision]  5.932116       New York
# 1     [Location, Country]  5.932116       New York
# 2      [Location, Admin2]  4.739134       New York
