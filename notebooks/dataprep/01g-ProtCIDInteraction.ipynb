# %% [markdown]
# # Downloads ProtCID Interface Information
# **[Work in progress]**
#
# This notebook processes domain-domain interactions from ProtCID interface info from EPPIC
#
# Data sources:
# [ProdCID]()
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import numpy as np
import pandas as pd
import gzip
import io
import requests
import json
import dateutil
import urllib
from pathlib import Path
from py2neo import Graph

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_IMPORT = Path(os.getenv('NEO4J_IMPORT'))
print(NEO4J_IMPORT)
# Out:
# /Users/peter/Library/Application Support/com.Neo4j.Relate/data/dbmss/dbms-8bf637fc-0d20-4d9f-9c6f-f7e72e92a4da/import

# %%
CACHE = Path(NEO4J_IMPORT / 'cache/protcid/PdbPfamDomainDomainInteractions.txt.gz')

# %%
df = pd.read_csv(CACHE, sep='\t', skiprows=22)

# %%
df.head(10)
# Out:
#   PdbID AsymChain1 AsymChain2 AuthChain1 AuthChain2 SymmetryOp1 SymmetryOp2  \
# 0  2rii          A          D          A          Y       1_555       1_555
# 1  3hy2          A          D          A          Y       1_555       1_555
# 2  1sc6          B          B          B          B       2_656       1_556
# 3  3k5p          A          A          A          A       1_555      11_555
# 4  1psd          B          B          B          B       1_555       4_456
# 5  2p9c          A          A          A          A       1_555       3_456
# 6  2p9g          A          A          A          A       3_555       1_555
# 7  1c4t          A          B          A          B       1_555       1_555
# 8  1dpb          A          A          A          A       1_555       5_555
# 9  1scz          A          A          A          A       1_555      58_465
#
#   UniProt1 UniProt2 PfamAcc1 PfamAcc2  PfamPairID  ClusterID  NumCFs_cluster  \
# 0   Q06830   Q9BYN0  PF10417  PF02195           4          1               2
# 1   Q06830   Q9BYN0  PF10417  PF02195           4          1               2
# 2   P0A9T0   P0A9T0  PF02826  PF01842          16          1               2
# 3   Q2YK82   Q2YK82  PF01842  PF02826          16          1               2
# 4   P0A9T0   P0A9T0  PF02826  PF01842          16          2               1
# 5   P0A9T0   P0A9T0  PF02826  PF01842          16          2               1
# 6   P0A9T0   P0A9T0  PF01842  PF02826          16          2               1
# 7   P0AFG6   P0AFG6  PF00198  PF00198          30          1               9
# 8   P10802   P10802  PF00198  PF00198          30          1               9
# 9   P0AFG6   P0AFG6  PF00198  PF00198          30          1               9
#
#    NumEntries_cluster  MinSeqIdentity  NumCFs_PfamPair  NumEntries_PfamPair  \
# 0                   2              96                2                    2
# 1                   2              96                2                    2
# 2                   2              45                4                    7
# 3                   2              45                4                    7
# 4                   3              98                4                    7
# 5                   3              98                4                    7
# 6                   3              98                4                    7
# 7                  21              26               10                   22
# 8                  21              26               10                   22
# 9                  21              26               10                   22
#
#    SurfaceArea  NumPdbBAs  NumPisaBAs
# 0     860.7375          2           2
# 1     860.7375          2           2
# 2     266.7667          0           0
# 3     266.7667          0           0
# 4     313.9667          0           0
# 5     313.9667          0           0
# 6     313.9667          0           0
# 7    1491.0180         21          21
# 8    1491.0180         21          21
# 9    1491.0180         21          21

# %%
len(df['PdbID'].unique())
# Out:
# 78393

# %% [markdown]
# #### Remove intrachain interactions

# %%
df = df[(df['AsymChain1'] != df['AsymChain2']) & (df['SymmetryOp1'] != 'symmetryOp2')]

# %%
len(df['PdbID'].unique())
# Out:
# 51911

# %% [markdown]
# #### Remove homo interactions (same protein interacting in a complex)

# %%
df = df[df['UniProt1'] != df['UniProt2']]

# %%
len(df['PdbID'].unique())
# Out:
# 12113

# %%
#df.sort_values(by=['SurfaceArea'], ascending=False, inplace=True)

# %%
print(df.shape)
df.head()
# Out:
# (84340, 21)
#     PdbID AsymChain1 AsymChain2 AuthChain1 AuthChain2 SymmetryOp1 SymmetryOp2  \
# 0    2rii          A          D          A          Y       1_555       1_555
# 1    3hy2          A          D          A          Y       1_555       1_555
# 142  4zwj          A          B          A          B       1_555       3_445
# 143  5dgy          A          B          A          B       1_555       3_445
# 144  5w0p          C          D          C          D       1_555       1_455
#
#     UniProt1 UniProt2 PfamAcc1 PfamAcc2  PfamPairID  ClusterID  \
# 0     Q06830   Q9BYN0  PF10417  PF02195           4          1
# 1     Q06830   Q9BYN0  PF10417  PF02195           4          1
# 142   P20443   P08100  PF02752  PF00001         141          2
# 143   P20443   P08100  PF02752  PF00001         141          2
# 144   P20443   P08100  PF02752  PF00001         141          2
#
#      NumCFs_cluster  NumEntries_cluster  MinSeqIdentity  NumCFs_PfamPair  \
# 0                 2                   2              96                2
# 1                 2                   2              96                2
# 142               2                   3              99                2
# 143               2                   3              99                2
# 144               2                   3              99                2
#
#      NumEntries_PfamPair  SurfaceArea  NumPdbBAs  NumPisaBAs
# 0                      2     860.7375          2           2
# 1                      2     860.7375          2           2
# 142                    3     332.8917          0           0
# 143                    3     332.8917          0           0
# 144                    3     332.8917          0           0

# %%
# total: 320127
# (df['NumPdbBAs'] > 0) | (df['NumPisaBAs'] > 0): 186629
# (df['NumPisaBAs'] > 0): 174994
# (df['NumPdbBAs']): 163726

# %%
df = df[(df['NumPisaBAs'] > 0)]

# %%
df.shape
# Out:
# (69317, 21)

# %%
def unique_id(row):
    if row.PfamAcc1 > row.PfamAcc2:
        return row.PfamAcc2 + '_' + row.PfamAcc1
    else:
        return row.PfamAcc1 + '_' + row.PfamAcc2

# %%
df['uniqueId'] = df.apply(lambda r: unique_id(r), axis=1)

# %%
df.head()
# Out:
#     PdbID AsymChain1 AsymChain2 AuthChain1 AuthChain2 SymmetryOp1 SymmetryOp2  \
# 0    2rii          A          D          A          Y       1_555       1_555
# 1    3hy2          A          D          A          Y       1_555       1_555
# 171  4cvn          A          H          A          H       1_555       1_555
# 172  4cw7          A          B          A          B       1_555       1_555
# 181  1g4a          A          F          E          C       1_555       1_555
#
#     UniProt1 UniProt2 PfamAcc1 PfamAcc2  PfamPairID  ClusterID  \
# 0     Q06830   Q9BYN0  PF10417  PF02195           4          1
# 1     Q06830   Q9BYN0  PF10417  PF02195           4          1
# 171   Q9UZK4   P62010  PF13238  PF00411         321          1
# 172   Q9UZK4   P62010  PF13238  PF00411         321          1
# 181   P0A6H5   P0A7B8  PF07724  PF00227         338          1
#
#      NumCFs_cluster  NumEntries_cluster  MinSeqIdentity  NumCFs_PfamPair  \
# 0                 2                   2              96                2
# 1                 2                   2              96                2
# 171               1                   2             100                1
# 172               1                   2             100                1
# 181               4                   9              17                4
#
#      NumEntries_PfamPair  SurfaceArea  NumPdbBAs  NumPisaBAs         uniqueId
# 0                      2     860.7375          2           2  PF02195_PF10417
# 1                      2     860.7375          2           2  PF02195_PF10417
# 171                    2    1006.0500          2           2  PF00411_PF13238
# 172                    2    1006.0500          2           2  PF00411_PF13238
# 181                    9     224.4542          7           4  PF00227_PF07724

# %%
print('Unique Pfam pairs:', len(df['uniqueId'].unique()))
# Out:
# Unique Pfam pairs: 3585

# %%
def unique_order(row):
    if row.PfamAcc1 > row.PfamAcc2:
        row.PfamAcc1, row.PfamAcc2 = row.PfamAcc2, row.PfamAcc1
        row.UniProt1, row.UniProt2 = row.UniProt2, row.UniProt1
    return row

# %%
df_unique = df[['PfamAcc1', 'PfamAcc2', 'UniProt1', 'UniProt2']].copy()

# %%
df_unique = df_unique.apply(unique_order, axis=1)

# %%
df_unique.head()
# Out:
#     PfamAcc1 PfamAcc2 UniProt1 UniProt2
# 0    PF02195  PF10417   Q9BYN0   Q06830
# 1    PF02195  PF10417   Q9BYN0   Q06830
# 171  PF00411  PF13238   P62010   Q9UZK4
# 172  PF00411  PF13238   P62010   Q9UZK4
# 181  PF00227  PF07724   P0A7B8   P0A6H5

# %%
df_unique.shape
# Out:
# (69317, 4)

# %%
df_unique.tail()
# Out:
#        PfamAcc1 PfamAcc2 UniProt1 UniProt2
# 365535  PF00028  PF00541   Q14126   P04501
# 365536  PF00028  PF00541   Q14126   P04501
# 365561  PF01867  PF09711    6qxf2    6qxf1
# 365562  PF01867  PF09711    6qxt2    6qxt1
# 365563  PF01867  PF09711    6qy32    6qy31

# %%
df_unique['accession1'] = 'pfam:' + df_unique['PfamAcc1']
df_unique['accession2'] = 'pfam:' + df_unique['PfamAcc2']
df_unique['id'] = df_unique['PfamAcc1'] + '-' + df_unique['PfamAcc2']

# %%
# only use valid UniProt Ids
df_unique['proteinAccession1'] = df_unique['UniProt1'].apply(lambda x: '' if x[0].isdigit() else 'uniprot:' + x)
df_unique['proteinAccession2'] = df_unique['UniProt2'].apply(lambda x: '' if x[0].isdigit() else 'uniprot:' + x)

# %%
df_unique = df_unique[['id', 'accession1', 'accession2', 'proteinAccession1', 'proteinAccession2']].copy()
df_unique = df_unique.drop_duplicates()

# %%
print('Number of domain-domain pairs:', df_unique.shape[0])
# Out:
# Number of domain-domain pairs: 14581

# %%
df_unique.head()
# Out:
#                   id    accession1    accession2 proteinAccession1  \
# 0    PF02195-PF10417  pfam:PF02195  pfam:PF10417    uniprot:Q9BYN0
# 171  PF00411-PF13238  pfam:PF00411  pfam:PF13238    uniprot:P62010
# 181  PF00227-PF07724  pfam:PF00227  pfam:PF07724    uniprot:P0A7B8
# 183  PF00227-PF07724  pfam:PF00227  pfam:PF07724    uniprot:P43772
# 186  PF00227-PF07724  pfam:PF00227  pfam:PF07724    uniprot:P39070
#
#     proteinAccession2
# 0      uniprot:Q06830
# 171    uniprot:Q9UZK4
# 181    uniprot:P0A6H5
# 183    uniprot:P43773
# 186    uniprot:P0A6H5

# %%
df_unique.to_csv(NEO4J_IMPORT / "01g-ProtCIDInteraction.csv", index=False)
