# %% [markdown]
# # Load SARS-CoV-2 Strain Metadata from Nextstrain.org
# **[Work in progress]**
#
# This notebook downloads and standardizes SARS-CoV-2 strain metadata from [Nextstrain.org](https://nextstrain.org) for ingestion into a Knowledge Graph.
#
# This notebook uses a local copy of the [nextstrain_ncov_global_metadata.tsv](../../reference_data/nextstrain_ncov_global_metadata.tsv) file, since it must be manually downloaded from Nextstrain.org. It will not be updated daily.
#
# Additional information about these strains will be loaded later in the [01e-CNCBStrain.ipynb](01e-CNCBStrain.ipynb) notebook.
#
# Data source: [Nextstrain.org](https://nextstrain.org/ncov/)
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import csv
import pandas as pd
import dateutil
from pathlib import Path

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_IMPORT = Path(os.getenv('NEO4J_IMPORT'))
print(NEO4J_IMPORT)
# Out:
# /Users/peter/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-328d8379-6ab4-4cc1-a397-2de37909d2e4/installation-4.1.0/import

# %%
df = pd.read_csv("../../reference_data/nextstrain_ncov_global_metadata.tsv", sep = '\t', dtype=str, error_bad_lines=False)
# Out:
# b'Skipping line 978: expected 24 fields, saw 33\n'

# %% [markdown]
# ## Transform and standardize data

# %% [markdown]
# Graph databases don't have "null" values. By setting missing values to '', they will not be represented in the graph.

# %%
df.replace('?', '', inplace=True)
df.replace('Unknown', '', inplace=True)
df.fillna('', inplace=True)

# %%
df.head()
# Out:
#                    Strain GISAID Clade Age Clade Country Country of exposure  \
# 0  Guangdong/20SF179/2020            O  36   19A   China               China
# 1     Taiwan/TSGH-37/2020            L  21   19A  Taiwan              Taiwan
# 2   Wuhan/IVDC-HB-05/2019            L  32   19A   China               China
# 3        Wuhan/WIV07/2019            L  56   19A   China               China
# 4         Wuhan/WH01/2019            L  44   19A   China               China
#
#   Admin Division Division of exposure  gisaid_epi_isl   Host  \
# 0      Guangdong            Guangdong  EPI_ISL_428451  Human
# 1         Taiwan               Taiwan  EPI_ISL_457733  Human
# 2          Hubei                Hubei  EPI_ISL_402121  Human
# 3          Hubei                Hubei  EPI_ISL_402130  Human
# 4          Hubei                Hubei  EPI_ISL_406798  Human
#
#   Old Nextstrain clade Location  \
# 0                        Zhuhai
# 1                        Taipei
# 2                         Wuhan
# 3                         Wuhan
# 4                         Wuhan
#
#                                      Originating Lab Pangolin lineage  \
# 0  Guangdong Provincial Center for Diseases Contr...                B
# 1                              TSGH-CP molecular lab                B
# 2  National Institute for Viral Disease Control a...                B
# 3                           Wuhan Jinyintan Hospital                B
# 4  General Hospital of Central Theater Command of...                B
#
#   Submission Date Region   Sex Emerging clade  \
# 0           Older   Asia  Male            19A
# 1           Older   Asia  Male            19A
# 2           Older   Asia  Male            19A
# 3           Older   Asia  Male            19A
# 4           Older   Asia  Male            19A
#
#                                       Submitting Lab url Collection Data  \
# 0  School of Public Health, The University of Hon...          2020-01-22
# 1                              TSGH-CP molecular lab          2020-02-08
# 2  National Institute for Viral Disease Control a...          2019-12-30
# 3  Wuhan Institute of Virology, Chinese Academy o...          2019-12-30
# 4  BGI & Institute of Microbiology, Chinese Acade...          2019-12-26
#
#                                               Author genbank_accession  \
# 0                                   Bosheng Li et al
# 1                             Cherng-Lih Perng et al
# 2  Wenjie Tan et al A (https://dx.doi.org/10.1056...
# 3                                    Peng Zhou et al          MN996531
# 4  Weijun Chen et al (https://dx.doi.org/10.1016/...          LR757998
#
#   Region of exposure
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Apply Neo4j property naming conventions

# %%
df.rename(columns={'Strain': 'name', 'Clade': 'clade', 'Age': 'age', 'Sex': 'sex', 'Collection Data': 'collectionDate'}, inplace=True)
df.rename(columns={'Country of exposure': 'exposureCountry', 'Division of exposure': 'exposureAdmin1'}, inplace=True)

# %% [markdown]
# Fix collection dates

# %%
df['collectionDate'] = df['collectionDate'].apply(lambda d: dateutil.parser.parse(d) if len(d) > 0 else '')

# %% [markdown]
# Taxonomy

# %%
# assign taxonomy for SARS-CoV-2
df['taxonomyId'] = 'taxonomy:2697049'

# %%
# read Organism reference dictionary
organism_to_id = dict()
data = pd.read_csv("../../reference_data/OrganismDictionary.csv", comment='#', index_col=False)
for index, row in data.iterrows():
    organism_to_id[row['organism']] = row['taxonomyId']

# %%
# assign taxonomy id for host
df['Host'] = df['Host'].str.strip()
df['hostTaxonomyId'] = df['Host'].apply(lambda s: organism_to_id.get(s.lower(), s))

# %%
df['hostTaxonomyId'].unique()
# Out:
# array(['taxonomy:9606', '', 'taxonomy:9666', 'taxonomy:9685',
#        'Environment'], dtype=object)

# %%
# for consistency with NCBI, use lower case
df['sex'] = df['sex'].str.lower()

# %%
def create_location_string(x):
    y = x[0]
    # Nextstrain assigns the country name to the Admin Division in some cases, then ignore Admin Division
    if x[1] != '' and x[1] != x[0]:
        y = y + ',' + x[1]
    if x[2] != '':
        y = y + ',' + x[2]
    return y

# %%
df['origLocation'] = df[['Country', 'Admin Division', 'Location']].apply(lambda x: create_location_string(x),axis=1)

# %%
df.head()
# Out:
#                      name GISAID Clade age clade Country exposureCountry  \
# 0  Guangdong/20SF179/2020            O  36   19A   China           China
# 1     Taiwan/TSGH-37/2020            L  21   19A  Taiwan          Taiwan
# 2   Wuhan/IVDC-HB-05/2019            L  32   19A   China           China
# 3        Wuhan/WIV07/2019            L  56   19A   China           China
# 4         Wuhan/WH01/2019            L  44   19A   China           China
#
#   Admin Division exposureAdmin1  gisaid_epi_isl   Host Old Nextstrain clade  \
# 0      Guangdong      Guangdong  EPI_ISL_428451  Human
# 1         Taiwan         Taiwan  EPI_ISL_457733  Human
# 2          Hubei          Hubei  EPI_ISL_402121  Human
# 3          Hubei          Hubei  EPI_ISL_402130  Human
# 4          Hubei          Hubei  EPI_ISL_406798  Human
#
#   Location                                    Originating Lab  \
# 0   Zhuhai  Guangdong Provincial Center for Diseases Contr...
# 1   Taipei                              TSGH-CP molecular lab
# 2    Wuhan  National Institute for Viral Disease Control a...
# 3    Wuhan                           Wuhan Jinyintan Hospital
# 4    Wuhan  General Hospital of Central Theater Command of...
#
#   Pangolin lineage Submission Date Region   sex Emerging clade  \
# 0                B           Older   Asia  male            19A
# 1                B           Older   Asia  male            19A
# 2                B           Older   Asia  male            19A
# 3                B           Older   Asia  male            19A
# 4                B           Older   Asia  male            19A
#
#                                       Submitting Lab url collectionDate  \
# 0  School of Public Health, The University of Hon...         2020-01-22
# 1                              TSGH-CP molecular lab         2020-02-08
# 2  National Institute for Viral Disease Control a...         2019-12-30
# 3  Wuhan Institute of Virology, Chinese Academy o...         2019-12-30
# 4  BGI & Institute of Microbiology, Chinese Acade...         2019-12-26
#
#                                               Author genbank_accession  \
# 0                                   Bosheng Li et al
# 1                             Cherng-Lih Perng et al
# 2  Wenjie Tan et al A (https://dx.doi.org/10.1056...
# 3                                    Peng Zhou et al          MN996531
# 4  Weijun Chen et al (https://dx.doi.org/10.1016/...          LR757998
#
#   Region of exposure        taxonomyId hostTaxonomyId            origLocation
# 0                     taxonomy:2697049  taxonomy:9606  China,Guangdong,Zhuhai
# 1                     taxonomy:2697049  taxonomy:9606           Taiwan,Taipei
# 2                     taxonomy:2697049  taxonomy:9606       China,Hubei,Wuhan
# 3                     taxonomy:2697049  taxonomy:9606       China,Hubei,Wuhan
# 4                     taxonomy:2697049  taxonomy:9606       China,Hubei,Wuhan

# %% [markdown]
# ### Create unique and interoperable identifiers

# %% [markdown]
# **id**: URI: [https://www.gisaid.org/](https://www.gisaid.org/help/publish-with-gisaid-references) (Global Initiative on Sharing All Influenza Data, GISAID)

# %%
df['id'] = 'https://www.gisaid.org/' + df['gisaid_epi_isl']

# %% [markdown]
# ### Save data for Knowledge Graph Import

# %%
df = df[['id', 'name', 'taxonomyId', 'collectionDate',
         'hostTaxonomyId', 'sex', 'age', 'clade',
         'exposureCountry', 'exposureAdmin1', 'origLocation']]
df.head()
# Out:
#                                       id                    name  \
# 0  https://www.gisaid.org/EPI_ISL_428451  Guangdong/20SF179/2020
# 1  https://www.gisaid.org/EPI_ISL_457733     Taiwan/TSGH-37/2020
# 2  https://www.gisaid.org/EPI_ISL_402121   Wuhan/IVDC-HB-05/2019
# 3  https://www.gisaid.org/EPI_ISL_402130        Wuhan/WIV07/2019
# 4  https://www.gisaid.org/EPI_ISL_406798         Wuhan/WH01/2019
#
#          taxonomyId collectionDate hostTaxonomyId   sex age clade  \
# 0  taxonomy:2697049     2020-01-22  taxonomy:9606  male  36   19A
# 1  taxonomy:2697049     2020-02-08  taxonomy:9606  male  21   19A
# 2  taxonomy:2697049     2019-12-30  taxonomy:9606  male  32   19A
# 3  taxonomy:2697049     2019-12-30  taxonomy:9606  male  56   19A
# 4  taxonomy:2697049     2019-12-26  taxonomy:9606  male  44   19A
#
#   exposureCountry exposureAdmin1            origLocation
# 0           China      Guangdong  China,Guangdong,Zhuhai
# 1          Taiwan         Taiwan           Taiwan,Taipei
# 2           China          Hubei       China,Hubei,Wuhan
# 3           China          Hubei       China,Hubei,Wuhan
# 4           China          Hubei       China,Hubei,Wuhan

# %%
df.to_csv(NEO4J_IMPORT / "01b-Nextstrain.csv", index=False)

# %%
df.shape
# Out:
# (4702, 11)
