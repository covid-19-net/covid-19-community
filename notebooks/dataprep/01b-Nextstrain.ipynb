# %% [markdown]
# # Load SARS-CoV-2 Strain Metadata from Nextstrain.org
# **[Work in progress]**
#
# This notebook downloads and standardizes SARS-CoV-2 strain metadata from [Nextstrain.org](https://nextstrain.org) for ingestion into a Knowledge Graph.
#
# This notebook uses a local copy of the [nextstrain_ncov_global_metadata.tsv](../../reference_data/nextstrain_ncov_global_metadata.tsv) file, since it must be manually downloaded from Nextstrain.org. It will not be updated daily.
#
# Additional information about these strains will be loaded later in the [01e-CNCBStrain.ipynb](01e-CNCBStrain.ipynb) notebook.
#
# Data source: [Nextstrain.org](https://nextstrain.org/ncov/)
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import csv
import pandas as pd
import dateutil
from pathlib import Path

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_HOME = Path(os.getenv('NEO4J_HOME'))
print(NEO4J_HOME)
# Out:
# /Users/peter/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-4af96121-2328-4e2f-ba60-6d8b728a26d5/installation-4.0.3

# %%
df = pd.read_csv("../../reference_data/nextstrain_ncov_global_metadata.tsv", sep = '\t', dtype=str, error_bad_lines=False)
# Out:
# b'Skipping line 1229: expected 22 fields, saw 30\nSkipping line 1776: expected 22 fields, saw 30\n'

# %% [markdown]
# ## Transform and standardize data

# %% [markdown]
# Graph databases don't have "null" values. By setting missing values to '', they will not be represented in the graph.

# %%
df.replace('?', '', inplace=True)
df.replace('Unknown', '', inplace=True)
df.fillna('', inplace=True)

# %%
df.head()
# Out:
#                   Strain Age Clade Country Country of exposure Admin Division  \
# 0       Wuhan/WIV05/2019  52   19A   China               China          Hubei
# 1       Wuhan/WIV02/2019  32   19A   China               China          Hubei
# 2  Hangzhou/ZJU-011/2020  62   19A   China               China       Zhejiang
# 3   Hangzhou/ZJU-07/2020   0   19A   China               China       Zhejiang
# 4    Taiwan/TSGH-37/2020  21   19A  Taiwan              Taiwan         Taiwan
#
#   Division of exposure genbank_accession  gisaid_epi_isl   Host  \
# 0                Hubei          MN996529  EPI_ISL_402128  Human
# 1                Hubei          MN996527  EPI_ISL_402127  Human
# 2             Zhejiang                    EPI_ISL_418991  Human
# 3             Zhejiang                    EPI_ISL_416425  Human
# 4               Taiwan                    EPI_ISL_457733  Human
#
#   Old Nextstrain clade  Location  \
# 0                          Wuhan
# 1                          Wuhan
# 2                       Hangzhou
# 3                       Hangzhou
# 4                         Taipei
#
#                                      Originating Lab Pangolin lineage  \
# 0                           Wuhan Jinyintan Hospital                B
# 1                           Wuhan Jinyintan Hospital                B
# 2  State Key Laboratory for Diagnosis and Treatme...                B
# 3  State Key Laboratory for Diagnosis and Treatme...                B
# 4                              TSGH-CP molecular lab
#
#   Submission Date Region     Sex  \
# 0           Older   Asia  Female
# 1           Older   Asia    Male
# 2           Older   Asia    Male
# 3           Older   Asia    Male
# 4    1-2 days ago   Asia    Male
#
#                                       Submitting Lab url Collection Data  \
# 0  Wuhan Institute of Virology, Chinese Academy o...          2019-12-30
# 1  Wuhan Institute of Virology, Chinese Academy o...          2019-12-30
# 2  State Key Laboratory for Diagnosis and Treatme...          2020-02-04
# 3  State Key Laboratory for Diagnosis and Treatme...          2020-02-03
# 4                              TSGH-CP molecular lab          2020-02-08
#
#                    Author Region of exposure
# 0         Peng Zhou et al
# 1         Peng Zhou et al
# 2      Hangping Yao et al
# 3      Hangping Yao et al
# 4  Cherng-Lih Perng et al

# %% [markdown]
# Apply Neo4j property naming conventions

# %%
df.rename(columns={'Strain': 'name', 'Clade': 'clade', 'Age': 'age', 'Sex': 'sex', 'Collection Data': 'collectionDate'}, inplace=True)
df.rename(columns={'Country of exposure': 'exposureCountry', 'Division of exposure': 'exposureAdmin1'}, inplace=True)

# %% [markdown]
# Fix collection dates

# %%
df['collectionDate'] = df['collectionDate'].apply(lambda d: dateutil.parser.parse(d) if len(d) > 0 else '')

# %% [markdown]
# Taxonomy

# %%
# assign taxonomy for SARS-CoV-2
df['taxonomyId'] = 'taxonomy:2697049'

# %%
# read Organism reference dictionary
organism_to_id = dict()
data = pd.read_csv("../../reference_data/OrganismDictionary.csv", comment='#', index_col=False)
for index, row in data.iterrows():
    organism_to_id[row['organism']] = row['taxonomyId']

# %%
# assign taxonomy id for host
df['Host'] = df['Host'].str.strip()
df['hostTaxonomyId'] = df['Host'].apply(lambda s: organism_to_id.get(s.lower(), s))

# %%
df['hostTaxonomyId'].unique()
# Out:
# array(['taxonomy:9606', 'Environment', '', 'taxonomy:9666',
#        'taxonomy:9608', 'taxonomy:9685', 'taxonomy:419130'], dtype=object)

# %%
# for consistency with NCBI, use lower case
df['sex'] = df['sex'].str.lower()

# %%
df.head()
# Out:
#                     name age clade Country exposureCountry Admin Division  \
# 0       Wuhan/WIV05/2019  52   19A   China           China          Hubei
# 1       Wuhan/WIV02/2019  32   19A   China           China          Hubei
# 2  Hangzhou/ZJU-011/2020  62   19A   China           China       Zhejiang
# 3   Hangzhou/ZJU-07/2020   0   19A   China           China       Zhejiang
# 4    Taiwan/TSGH-37/2020  21   19A  Taiwan          Taiwan         Taiwan
#
#   exposureAdmin1 genbank_accession  gisaid_epi_isl   Host  \
# 0          Hubei          MN996529  EPI_ISL_402128  Human
# 1          Hubei          MN996527  EPI_ISL_402127  Human
# 2       Zhejiang                    EPI_ISL_418991  Human
# 3       Zhejiang                    EPI_ISL_416425  Human
# 4         Taiwan                    EPI_ISL_457733  Human
#
#   Old Nextstrain clade  Location  \
# 0                          Wuhan
# 1                          Wuhan
# 2                       Hangzhou
# 3                       Hangzhou
# 4                         Taipei
#
#                                      Originating Lab Pangolin lineage  \
# 0                           Wuhan Jinyintan Hospital                B
# 1                           Wuhan Jinyintan Hospital                B
# 2  State Key Laboratory for Diagnosis and Treatme...                B
# 3  State Key Laboratory for Diagnosis and Treatme...                B
# 4                              TSGH-CP molecular lab
#
#   Submission Date Region     sex  \
# 0           Older   Asia  female
# 1           Older   Asia    male
# 2           Older   Asia    male
# 3           Older   Asia    male
# 4    1-2 days ago   Asia    male
#
#                                       Submitting Lab url collectionDate  \
# 0  Wuhan Institute of Virology, Chinese Academy o...         2019-12-30
# 1  Wuhan Institute of Virology, Chinese Academy o...         2019-12-30
# 2  State Key Laboratory for Diagnosis and Treatme...         2020-02-04
# 3  State Key Laboratory for Diagnosis and Treatme...         2020-02-03
# 4                              TSGH-CP molecular lab         2020-02-08
#
#                    Author Region of exposure        taxonomyId hostTaxonomyId
# 0         Peng Zhou et al                     taxonomy:2697049  taxonomy:9606
# 1         Peng Zhou et al                     taxonomy:2697049  taxonomy:9606
# 2      Hangping Yao et al                     taxonomy:2697049  taxonomy:9606
# 3      Hangping Yao et al                     taxonomy:2697049  taxonomy:9606
# 4  Cherng-Lih Perng et al                     taxonomy:2697049  taxonomy:9606

# %% [markdown]
# ### Create unique and interoperable identifiers

# %% [markdown]
# **id**: URI: [https://www.gisaid.org/](https://www.gisaid.org/help/publish-with-gisaid-references) (Global Initiative on Sharing All Influenza Data, GISAID)

# %%
df['id'] = 'https://www.gisaid.org/' + df['gisaid_epi_isl']

# %% [markdown]
# ### Save data for Knowledge Graph Import

# %%
df = df[['id', 'name', 'taxonomyId', 'collectionDate',
         'hostTaxonomyId', 'sex', 'age', 'clade',
         'exposureCountry', 'exposureAdmin1']]
df.head()
# Out:
#                                       id                   name  \
# 0  https://www.gisaid.org/EPI_ISL_402128       Wuhan/WIV05/2019
# 1  https://www.gisaid.org/EPI_ISL_402127       Wuhan/WIV02/2019
# 2  https://www.gisaid.org/EPI_ISL_418991  Hangzhou/ZJU-011/2020
# 3  https://www.gisaid.org/EPI_ISL_416425   Hangzhou/ZJU-07/2020
# 4  https://www.gisaid.org/EPI_ISL_457733    Taiwan/TSGH-37/2020
#
#          taxonomyId collectionDate hostTaxonomyId     sex age clade  \
# 0  taxonomy:2697049     2019-12-30  taxonomy:9606  female  52   19A
# 1  taxonomy:2697049     2019-12-30  taxonomy:9606    male  32   19A
# 2  taxonomy:2697049     2020-02-04  taxonomy:9606    male  62   19A
# 3  taxonomy:2697049     2020-02-03  taxonomy:9606    male   0   19A
# 4  taxonomy:2697049     2020-02-08  taxonomy:9606    male  21   19A
#
#   exposureCountry exposureAdmin1
# 0           China          Hubei
# 1           China          Hubei
# 2           China       Zhejiang
# 3           China       Zhejiang
# 4          Taiwan         Taiwan

# %%
df.to_csv(NEO4J_HOME / "import/01b-Nextstrain.csv", index=False)
