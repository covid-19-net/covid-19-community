# %% [markdown]
# # Load SARS-CoV-2 Virus Strain Data from CNCB
# **[Work in progress]**
#
# This notebook downloads and standardizes viral strain and variation data from CNCB for ingestion into a Knowledge Graph.
#
# Data source: [China National Center for Bioinformation, 2019 Novel Coronavirus Resource (2019nCoVR)](https://bigd.big.ac.cn/ncov/release_genome)
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import pandas as pd
import dateutil
import re
from pathlib import Path
import glob
import ftplib

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
# Path will take care of handling operating system differences.
NEO4J_IMPORT = Path(os.getenv('NEO4J_IMPORT'))
print(NEO4J_IMPORT)
# Out:
# /Users/peter/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-b9d10363-6d59-4deb-9595-2cb904a99d1d/installation-4.1.0/import

# %%
# Create a directory to cache variation data
CACHE = Path(NEO4J_IMPORT / 'cache')
CACHE.mkdir(exist_ok=True)

# %%
# Create a directory to cache variation data that could not be parsed
CACHE_FAILED = Path(NEO4J_IMPORT / 'cache_failed')
CACHE_FAILED.mkdir(exist_ok=True)

# %% [markdown]
# ## Download SARS-CoV-2 Strain metadata

# %% [markdown]
# This notebook will download > 20,000 files. To work on a small sample (50 files), set
#
# `run_small_sample_only = True`

# %%
run_small_sample_only = False

# %%
metadata_url = "https://bigd.big.ac.cn/ncov/genome/export/meta"
annotation_url = "ftp://download.big.ac.cn/GVM/Coronavirus/gff3/"

# %%
df = pd.read_excel(metadata_url, dtype='str')
df.fillna('', inplace=True)

# %%
print("Total number of strains:", df.shape[0])
# Out:
# Total number of strains: 96075

# %%
df = df.query("`Sequence Quality` == 'High'")
df = df.query("`Nuc.Completeness` == 'Complete'")

# %%
print("Number of complete high quality strains", df.shape[0])
# Out:
# Number of complete high quality strains 50907

# %%
df.head()
# Out:
#                 Virus Strain Name     Accession ID Data Source  \
# 0  BetaCoV/Wuhan/HBCDC-HB-01/2019  NMDC60013088-01        NMDC
# 1        hCoV-19/Thailand/74/2020   EPI_ISL_403963      GISAID
# 2        hCoV-19/Thailand/61/2020   EPI_ISL_403962      GISAID
# 3   BetaCoV/Wuhan/IVDC-HB-04/2020  NMDC60013085-01        NMDC
# 4   BetaCoV/Wuhan/IVDC-HB-01/2019  NMDC60013084-01        NMDC
#
#        Related ID Nuc.Completeness Sequence Length Sequence Quality  \
# 0  EPI_ISL_402132         Complete           29848             High
# 1                         Complete           29859             High
# 2                         Complete           29848             High
# 3  EPI_ISL_402120         Complete           29896             High
# 4  EPI_ISL_402119         Complete           29891             High
#
#   Quality Assessment          Host Sample Collection Date  \
# 0         0/0/0/1/NO  Homo sapiens             2019-12-30
# 1         0/0/0/0/NO  Homo sapiens             2020-01-13
# 2         0/0/0/0/NO  Homo sapiens             2020-01-08
# 3         0/0/0/2/NO  Homo sapiens             2020-01-01
# 4         0/0/0/0/NO  Homo sapiens             2019-12-30
#
#                         Location  \
# 0                  China / Hubei
# 1  Thailand/ Nonthaburi Province
# 2  Thailand/ Nonthaburi Province
# 3          China / Hubei / Wuhan
# 4          China / Hubei / Wuhan
#
#                                      Originating Lab Submission Date  \
# 0  Hubei Provincial Center for Disease Control an...      2020-01-19
# 1  Department of Medical Sciences, Ministry of Pu...      2020-01-17
# 2  Department of Medical Sciences, Ministry of Pu...      2020-01-17
# 3  National Institute for Viral Disease Control a...      2020-01-11
# 4  National Institute for Viral Disease Control a...      2020-01-10
#
#                                       Submitting Lab          Create Time  \
# 0  Hubei Provincial Center for Disease Control an...  2020-01-20 20:04:48
# 1  Department of Medical Sciences, Ministry of Pu...  2020-01-20 20:04:48
# 2  Department of Medical Sciences, Ministry of Pu...  2020-01-20 20:04:48
# 3  National Institute for Viral Disease Control a...  2020-01-20 20:04:48
# 4  National Institute for Viral Disease Control a...  2020-01-20 20:04:48
#
#       Last Update Time
# 0  2020-05-07 23:03:25
# 1  2020-06-28 15:24:28
# 2  2020-06-28 15:24:28
# 3  2020-05-07 23:03:25
# 4  2020-05-07 23:03:25

# %% [markdown]
# #### Create a separate row for each Accession and Related ID

# %%
df['Accession ID'] = df['Accession ID'].str.strip()
df['Related ID'] = df['Related ID'].str.strip()

# combine all ids into a single column
df['alias'] = df['Accession ID'] + df['Related ID'].apply(lambda s: ',' + s if len(s) > 0 else s)
df['alias'] = df['alias'].str.replace(' ', '')

# then "explode" ids into separate rows
df['id'] = df['alias'].apply(lambda s: s.split(','))
df = df.explode('id')
df['id'] = df['id'].str.strip()
df['alias'] = df['alias'].str.replace(',', ';')

# %% [markdown]
# #### Assign taxonomy ids

# %%
# read Organism reference dictionary
organism_to_id = dict()
data = pd.read_csv("../../reference_data/OrganismDictionary.csv", comment='#')
for index, row in data.iterrows():
    organism_to_id[row['organism']] = row['taxonomyId']

# %%
# assign taxonomy id to host
df['Host'] = df['Host'].str.strip()
df['hostTaxonomyId'] = df['Host'].apply(lambda s: organism_to_id.get(s.lower(), s))
df['hostTaxonomyId'].unique()

# %%
df['taxonomyId'] = 'taxonomy:2697049' # SARS-CoV-2

# %% [markdown]
# #### Standardize node property names (CURIEs and URIs)

# %%
df.rename(columns={'Virus Strain Name': 'name',
                   'Sample Collection Date':'collectionDate',
                   'Location':'location'}, 
          inplace=True)

# %%
# https://registry.identifiers.org/registry/insdc
insdc_pattern = re.compile('^([A-Z]\d{5}|[A-Z]{2}\d{6}|[A-Z]{4}\d{8}|[A-J][A-Z]{2}\d{5})(\.\d+)?$')

# %%
def assign_curie(id):
    id = id.strip()
    # remove underscore to enable CURIE matching of NCBI reference sequences NC_...
    id = id.replace('NC_', 'NC') 
    if len(id) > 0:
        if id.startswith('EPI'):
            return 'https://www.gisaid.org/' + id
        elif id.startswith('NC_'):
            # NCBI reference sequences resolve with ncbiprotein CURIE
            return 'ncbiprotein:' + id
        elif insdc_pattern.match(id) != None:
            return 'insdc:' + id
        else:
            # TODO are URIs available for these cases?
            return id
    else:
        return id

# %%
df[['loc0', 'loc1', 'loc2', 'loc3']] = df['location'].str.split('/', n=3, expand=True)
# strip white space
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df['origLocation'] = df[['loc0', 'loc1', 'loc2', 'loc3']].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

# %%
strains = df[['id', 'name', 'alias', 'taxonomyId', 'hostTaxonomyId','collectionDate', 'location', 'origLocation']].copy()
strains['id'] = strains['id'].apply(assign_curie)
strains.head()
# Out:
#                                       id                            name  \
# 0                        NMDC60013088-01  BetaCoV/Wuhan/HBCDC-HB-01/2019
# 0  https://www.gisaid.org/EPI_ISL_402132  BetaCoV/Wuhan/HBCDC-HB-01/2019
# 1  https://www.gisaid.org/EPI_ISL_403963        hCoV-19/Thailand/74/2020
# 2  https://www.gisaid.org/EPI_ISL_403962        hCoV-19/Thailand/61/2020
# 3                        NMDC60013085-01   BetaCoV/Wuhan/IVDC-HB-04/2020
#
#                             alias        taxonomyId hostTaxonomyId  \
# 0  NMDC60013088-01;EPI_ISL_402132  taxonomy:2697049  taxonomy:9606
# 0  NMDC60013088-01;EPI_ISL_402132  taxonomy:2697049  taxonomy:9606
# 1                  EPI_ISL_403963  taxonomy:2697049  taxonomy:9606
# 2                  EPI_ISL_403962  taxonomy:2697049  taxonomy:9606
# 3  NMDC60013085-01;EPI_ISL_402120  taxonomy:2697049  taxonomy:9606
#
#   collectionDate                       location                  origLocation
# 0     2019-12-30                  China / Hubei                   China,Hubei
# 0     2019-12-30                  China / Hubei                   China,Hubei
# 1     2020-01-13  Thailand/ Nonthaburi Province  Thailand,Nonthaburi Province
# 2     2020-01-08  Thailand/ Nonthaburi Province  Thailand,Nonthaburi Province
# 3     2020-01-01          China / Hubei / Wuhan             China,Hubei,Wuhan

# %%
strains.query("collectionDate == '2020-01-30'")
# Out:
#                                           id  \
# 88     https://www.gisaid.org/EPI_ISL_407896
# 215    https://www.gisaid.org/EPI_ISL_412029
# 235    https://www.gisaid.org/EPI_ISL_412870
# 236    https://www.gisaid.org/EPI_ISL_412869
# 414                           insdc:MT066156
# 460                          NMDC60013027-01
# 460    https://www.gisaid.org/EPI_ISL_413860
# 462                          NMDC60013025-01
# 462    https://www.gisaid.org/EPI_ISL_413858
# 467                          NMDC60013021-01
# 467    https://www.gisaid.org/EPI_ISL_413854
# 468                          NMDC60013020-01
# 468    https://www.gisaid.org/EPI_ISL_413853
# 712    https://www.gisaid.org/EPI_ISL_414941
# 986    https://www.gisaid.org/EPI_ISL_416326
# 991    https://www.gisaid.org/EPI_ISL_416332
# 992    https://www.gisaid.org/EPI_ISL_416333
# 1011   https://www.gisaid.org/EPI_ISL_416352
# 1024   https://www.gisaid.org/EPI_ISL_416365
# 1025   https://www.gisaid.org/EPI_ISL_416366
# 4928   https://www.gisaid.org/EPI_ISL_421241
# 8408   https://www.gisaid.org/EPI_ISL_425118
# 11076                        NMDC60013105-01
# 11076  https://www.gisaid.org/EPI_ISL_428442
# 11078                        NMDC60013107-01
# 11078  https://www.gisaid.org/EPI_ISL_428444
# 11079                        NMDC60013108-01
# 11079  https://www.gisaid.org/EPI_ISL_428445
# 16902                 SARS-CoV-2/human/HKG/HKU-911a/2020
# 16902                 SARS-CoV-2/human/HKG/HKU-911a/2020
# 16905                 SARS-CoV-2/human/HKG/HKU-904a/2020
# 16905                 SARS-CoV-2/human/HKG/HKU-904a/2020
# 30551  SARS-CoV-2/human/DEU/BavPat2-ChVir984-ChVir101...
# 30551  SARS-CoV-2/human/DEU/BavPat2-ChVir984-ChVir101...
# 31806                         hCoV-19/Italy/INMI2-N/2020
# 31818                       hCoV-19/China/SC-GA-063/2020
# 31819                       hCoV-19/China/SC-GA-064/2020
# 31836                       hCoV-19/China/SC-NC-073/2020
# 31838                       hCoV-19/China/SC-NC-075/2020
# 31841                       hCoV-19/China/SC-NC-078/2020
# 31847                       hCoV-19/China/SC-NJ-094/2020
# 31892                     hCoV-19/China/SC-WCH4-287/2020
# 31898                     hCoV-19/China/SC-WCH4-301/2020
# 31899                       hCoV-19/China/SC-YA-087/2020
# 35951                     hCoV-19/Australia/VPRL014/2020
# 36099                    hCoV-19/Malaysia/IMR_WC119/2020
# 43499                           hCoV-19/Shaoxing/02/2020
# 43500                           hCoV-19/Shaoxing/03/2020
# 47613                      hCoV-19/Australia/SAP214/2020
# 47618                      hCoV-19/Australia/SAP305/2020
# 59342                     SARS-CoV-2/human/AUS/SA02/2020
# 59342                     SARS-CoV-2/human/AUS/SA02/2020
# 59343                     SARS-CoV-2/human/AUS/SA03/2020
# 59343                     SARS-CoV-2/human/AUS/SA03/2020
# 74110                        hCoV-19/Korea/KCDC2061/2020
#
#                                 alias        taxonomyId hostTaxonomyId  \
# 88                     EPI_ISL_407896  taxonomy:2697049  taxonomy:9606
# 215                    EPI_ISL_412029  taxonomy:2697049  taxonomy:9606
# 235                    EPI_ISL_412870  taxonomy:2697049  taxonomy:9606
# 236                    EPI_ISL_412869  taxonomy:2697049  taxonomy:9606
# 414                          MT066156  taxonomy:2697049  taxonomy:9606
# 460    NMDC60013027-01;EPI_ISL_413860  taxonomy:2697049  taxonomy:9606
# 460    NMDC60013027-01;EPI_ISL_413860  taxonomy:2697049  taxonomy:9606
# 462    NMDC60013025-01;EPI_ISL_413858  taxonomy:2697049  taxonomy:9606
# 462    NMDC60013025-01;EPI_ISL_413858  taxonomy:2697049  taxonomy:9606
# 467    NMDC60013021-01;EPI_ISL_413854  taxonomy:2697049  taxonomy:9606
# 467    NMDC60013021-01;EPI_ISL_413854  taxonomy:2697049  taxonomy:9606
# 468    NMDC60013020-01;EPI_ISL_413853  taxonomy:2697049  taxonomy:9606
# 468    NMDC60013020-01;EPI_ISL_413853  taxonomy:2697049  taxonomy:9606
# 712                    EPI_ISL_414941  taxonomy:2697049  taxonomy:9606
# 986                    EPI_ISL_416326  taxonomy:2697049  taxonomy:9606
# 991                    EPI_ISL_416332  taxonomy:2697049  taxonomy:9606
# 992                    EPI_ISL_416333  taxonomy:2697049  taxonomy:9606
# 1011                   EPI_ISL_416352  taxonomy:2697049  taxonomy:9606
# 1024                   EPI_ISL_416365  taxonomy:2697049  taxonomy:9606
# 1025                   EPI_ISL_416366  taxonomy:2697049  taxonomy:9606
# 4928                   EPI_ISL_421241  taxonomy:2697049  taxonomy:9606
# 8408                   EPI_ISL_425118  taxonomy:2697049  taxonomy:9606
# 11076  NMDC60013105-01;EPI_ISL_428442  taxonomy:2697049  taxonomy:9606
# 11076  NMDC60013105-01;EPI_ISL_428442  taxonomy:2697049  taxonomy:9606
# 11078  NMDC60013107-01;EPI_ISL_428444  taxonomy:2697049  taxonomy:9606
# 11078  NMDC60013107-01;EPI_ISL_428444  taxonomy:2697049  taxonomy:9606
# 11079  NMDC60013108-01;EPI_ISL_428445  taxonomy:2697049  taxonomy:9606
# 11079  NMDC60013108-01;EPI_ISL_428445  taxonomy:2697049  taxonomy:9606
# 16455                  EPI_ISL_416331  taxonomy:2697049  taxonomy:9606
# 16902         MT365029;EPI_ISL_450409  taxonomy:2697049  taxonomy:9606
# 16902         MT365029;EPI_ISL_450409  taxonomy:2697049  taxonomy:9606
# 16905         MT365032;EPI_ISL_450412  taxonomy:2697049  taxonomy:9606
# 16905         MT365032;EPI_ISL_450412  taxonomy:2697049  taxonomy:9606
# 30551         MT270112;EPI_ISL_450209  taxonomy:2697049  taxonomy:9606
# 30551         MT270112;EPI_ISL_450209  taxonomy:2697049  taxonomy:9606
# 31806                  EPI_ISL_451302  taxonomy:2697049  taxonomy:9606
# 31818                  EPI_ISL_451314  taxonomy:2697049  taxonomy:9606
# 31819                  EPI_ISL_451315  taxonomy:2697049  taxonomy:9606
# 31836                  EPI_ISL_451332  taxonomy:2697049  taxonomy:9606
# 31838                  EPI_ISL_451334  taxonomy:2697049  taxonomy:9606
# 31841                  EPI_ISL_451337  taxonomy:2697049  taxonomy:9606
# 31847                  EPI_ISL_451343  taxonomy:2697049  taxonomy:9606
# 31892                  EPI_ISL_451389  taxonomy:2697049  taxonomy:9606
# 31898                  EPI_ISL_451395  taxonomy:2697049  taxonomy:9606
# 31899                  EPI_ISL_451396  taxonomy:2697049  taxonomy:9606
# 35951                  EPI_ISL_455603  taxonomy:2697049  taxonomy:9606
# 36099                  EPI_ISL_455790  taxonomy:2697049  taxonomy:9606
# 43499                  EPI_ISL_463894  taxonomy:2697049  taxonomy:9606
# 43500                  EPI_ISL_463895  taxonomy:2697049  taxonomy:9606
# 47613                  EPI_ISL_468032  taxonomy:2697049  taxonomy:9606
# 47618                  EPI_ISL_468037  taxonomy:2697049  taxonomy:9606
# 59342         MT745747;EPI_ISL_480779  taxonomy:2697049  taxonomy:9606
# 59342         MT745747;EPI_ISL_480779  taxonomy:2697049  taxonomy:9606
# 59343         MT745748;EPI_ISL_480780  taxonomy:2697049  taxonomy:9606
# 59343         MT745748;EPI_ISL_480780  taxonomy:2697049  taxonomy:9606
# 74110                  EPI_ISL_497962  taxonomy:2697049  taxonomy:9606
#
#       collectionDate                             location  \
# 88        2020-01-30  Australia / Queensland / Gold Coast
# 215       2020-01-30                    China / Hong Kong
# 235       2020-01-30                   South Korea/ Seoul
# 236       2020-01-30                   South Korea /Seoul
# 11079          China,Guangdong,Huizhou
# 11079          China,Guangdong,Huizhou
# 16455                   China,Shanghai
# 16902                  China,Hong Kong
# 16902                  China,Hong Kong
# 16905                  China,Hong Kong
# 16905                  China,Hong Kong
# 30551                  Germany,Bavaria
# 30551                  Germany,Bavaria
# 31806                      Italy,Lazio
# 31818                    China,Sichuan
# 31819                    China,Sichuan
# 31836                    China,Sichuan
# 31838                    China,Sichuan
# 31841                    China,Sichuan
# 31847                    China,Sichuan
# 31892                    China,Sichuan
# 31898                    China,Sichuan
# 31899                    China,Sichuan
# 35951        Australia,South Australia
# 36099                Malaysia,Selangor
# 43499          China,Zhejiang,Shaoxing
# 43500          China,Zhejiang,Shaoxing
# 47613        Australia,South Australia
# 47618        Australia,South Australia
# 59342        Australia,South Australia
# 59342        Australia,South Australia
# 59343        Australia,South Australia
# 59343        Australia,South Australia
# 74110                      South Korea

# %%
strains.to_csv(NEO4J_IMPORT / "01d-CNCBStrain.csv", index=False)

# %% [markdown]
# ## Merge Metadata with Variation Data

# %% [markdown]
# #### Get list of file names from FTP site

# %%
server = "download.big.ac.cn"
user = "anonymous"
password = "anonymous"
source = "/GVM/Coronavirus/gff3/"

ftp = ftplib.FTP(server)
ftp.login(user, password)
ftp.cwd(source) 
filelist=ftp.nlst()
ftp.quit()
# Out:
# '221 Goodbye.'

# %%
df_file = pd.DataFrame(filelist, columns=['filename'])

# %% [markdown]
# Extract identifiers from file name
#
# Example: 2019-nCoV_CNA0013697_variants.gff3 -> CNA0013697

# %%
df_file['id'] = df_file['filename'].str[10:]
df_file['id'] = df_file['id'].str.replace('_variants.gff3','')

# %%
df_file = df_file.query("id != ''")

# %%
print("Number of available files:", df_file.shape[0])
# Out:
# Number of available files: 43946

# %%
df_file.head()
# Out:
#                              filename          id
# 0  2019-nCoV_CNA0007332_variants.gff3  CNA0007332
# 1  2019-nCoV_CNA0007334_variants.gff3  CNA0007334
# 2  2019-nCoV_CNA0007335_variants.gff3  CNA0007335
# 3  2019-nCoV_CNA0013697_variants.gff3  CNA0013697
# 4  2019-nCoV_CNA0013698_variants.gff3  CNA0013698

# %%
df = df.merge(df_file, on='id')

# %%
print('Strains with a matching filename:', df.shape[0])
# Out:
# Strains with a matching filename: 43804

# %%
if run_small_sample_only:
    df = df.sample(n=50, random_state=5)

# %%
df.head()
# Out:
#                              name     Accession ID Data Source  \
# 0  BetaCoV/Wuhan/HBCDC-HB-01/2019  NMDC60013088-01        NMDC
# 1        hCoV-19/Thailand/74/2020   EPI_ISL_403963      GISAID
# 2        hCoV-19/Thailand/61/2020   EPI_ISL_403962      GISAID
# 3   BetaCoV/Wuhan/IVDC-HB-04/2020  NMDC60013085-01        NMDC
# 4   BetaCoV/Wuhan/IVDC-HB-01/2019  NMDC60013084-01        NMDC
#
#        Related ID Nuc.Completeness Sequence Length Sequence Quality  \
# 0  EPI_ISL_402132         Complete           29848             High
# 1                         Complete           29859             High
# 2                         Complete           29848             High
# 3  EPI_ISL_402120         Complete           29896             High
# 4  EPI_ISL_402119         Complete           29891             High
#
#   Quality Assessment          Host collectionDate  \
# 0         0/0/0/1/NO  Homo sapiens     2019-12-30
# 1         0/0/0/0/NO  Homo sapiens     2020-01-13
# 2         0/0/0/0/NO  Homo sapiens     2020-01-08
# 3         0/0/0/2/NO  Homo sapiens     2020-01-01
# 4         0/0/0/0/NO  Homo sapiens     2019-12-30
#
#                         location  \
# 0                  China / Hubei
# 1  Thailand/ Nonthaburi Province
# 2  Thailand/ Nonthaburi Province
# 3          China / Hubei / Wuhan
# 4          China / Hubei / Wuhan
#
#                                      Originating Lab Submission Date  \
# 0  Hubei Provincial Center for Disease Control an...      2020-01-19
# 1  Department of Medical Sciences, Ministry of Pu...      2020-01-17
# 2  Department of Medical Sciences, Ministry of Pu...      2020-01-17
# 3  National Institute for Viral Disease Control a...      2020-01-11
# 4  National Institute for Viral Disease Control a...      2020-01-10
#
#                                       Submitting Lab          Create Time  \
# 0  Hubei Provincial Center for Disease Control an...  2020-01-20 20:04:48
# 1  Department of Medical Sciences, Ministry of Pu...  2020-01-20 20:04:48
# 2  Department of Medical Sciences, Ministry of Pu...  2020-01-20 20:04:48
# 3  National Institute for Viral Disease Control a...  2020-01-20 20:04:48
# 4  National Institute for Viral Disease Control a...  2020-01-20 20:04:48
#
#       Last Update Time                           alias              id  \
# 0  2020-05-07 23:03:25  NMDC60013088-01;EPI_ISL_402132  EPI_ISL_402132
# 1  2020-06-28 15:24:28                  EPI_ISL_403963  EPI_ISL_403963
# 2  2020-06-28 15:24:28                  EPI_ISL_403962  EPI_ISL_403962
# 3  2020-05-07 23:03:25  NMDC60013085-01;EPI_ISL_402120  EPI_ISL_402120
# 4  2020-05-07 23:03:25  NMDC60013084-01;EPI_ISL_402119  EPI_ISL_402119
#
#   hostTaxonomyId        taxonomyId      loc1                 loc2   loc3  \
# 0  taxonomy:9606  taxonomy:2697049     China                Hubei   None
# 1  taxonomy:9606  taxonomy:2697049  Thailand  Nonthaburi Province   None
# 2  taxonomy:9606  taxonomy:2697049  Thailand  Nonthaburi Province   None
# 3  taxonomy:9606  taxonomy:2697049     China                Hubei  Wuhan
# 4  taxonomy:9606  taxonomy:2697049     China                Hubei  Wuhan
#
#    loc4                  origLocation                                filename
# 0  None                   China,Hubei  2019-nCoV_EPI_ISL_402132_variants.gff3
# 1  None  Thailand,Nonthaburi Province  2019-nCoV_EPI_ISL_403963_variants.gff3
# 2  None  Thailand,Nonthaburi Province  2019-nCoV_EPI_ISL_403962_variants.gff3
# 3  None             China,Hubei,Wuhan  2019-nCoV_EPI_ISL_402120_variants.gff3
# 4  None             China,Hubei,Wuhan  2019-nCoV_EPI_ISL_402119_variants.gff3

# %% [markdown]
# Keep only unique entries (there are a few duplicate cases)

# %%
df.drop_duplicates(subset='name', inplace=True)
df.drop_duplicates(subset='id', inplace=True)

# %%
print('Strains with a matching filename:', df.shape[0])
# Out:
# Strains with a matching filename: 43743

# %% [markdown]
# #### Download variant annotations for each strain
# To avoid download the same files every time, they are cached, and newly downloaded files are added to the cache.

# %%
names = ['taxon1', 'variantType', 'name', 'start', 'end','x1', 'x2', 'x3','taxon2', 'x4', 'strainStart', 'taxon3', 'x5', 'strainEnd', 'ref', 'alt', 'vepAnnotation']

# %%
def download_gff3(filename, url):
    gff3 = pd.read_csv(url, header=None, comment='#', sep='[\t|;]', engine='python', names=names)
    try:
        gff3['ref'] = gff3['ref'].str.replace('REF=','')
        gff3['alt'] = gff3['alt'].str.replace('ALT=','')
        gff3['vepAnnotation'] = gff3['vepAnnotation'].str.replace('VEP=','')
        # prepare for 3-way split (need at least two commas)
        gff3['vepAnnotation'] = gff3['vepAnnotation'].apply(lambda s: s + ',,' if s.count(',') < 2 else s)
        # 3-way split
        gff3[['variantConsequence','proteinVariant','geneVariant']] = gff3['vepAnnotation'].str.split(',', n=2, expand=True)
        gff3['geneVariant'] = gff3['geneVariant'].str.replace('gene-','')
        gff3 = gff3[['name', 'variantType', 'start', 'end', 'ref', 'alt', 'variantConsequence', 'proteinVariant', 'geneVariant']]
    
        filename = row['filename'] + '.csv'
        gff3.to_csv(CACHE / filename, index=False)
    except:
        print('Parsing failed for: ', row['filename'])
        # cache files that failed to parse so we don't reprocess them next time
        filename = row['filename'] + '.csv'
        gff3 = pd.read_csv(url, header=None, comment='#', sep='[\t|;]', engine='python', names=names)
        gff3.to_csv(CACHE_FAILED / filename, index=False)

# %%
for index, row in df.iterrows():
    url = annotation_url + row['filename']
    filename = row['filename'] + '.csv'
    # skip files that have been processed in previous runs
    if not (Path.exists(CACHE / filename) or Path.exists(CACHE_FAILED / filename)):
        try:
            download_gff3(row['filename'], url)
            print(row['filename'], end=' ')
        except:
            print('Download failed for: ', row['filename'])
# Out:
# 2019-nCoV_EPI_ISL_411220_variants.gff3 2019-nCoV_EPI_ISL_415787_variants.gff3 2019-nCoV_EPI_ISL_416907_variants.gff3 2019-nCoV_EPI_ISL_418186_variants.gff3 2019-nCoV_EPI_ISL_419264_variants.gff3 2019-nCoV_EPI_ISL_419265_variants.gff3 2019-nCoV_EPI_ISL_419266_variants.gff3 2019-nCoV_EPI_ISL_419908_variants.gff3 2019-nCoV_EPI_ISL_419909_variants.gff3 2019-nCoV_EPI_ISL_419910_variants.gff3 2019-nCoV_EPI_ISL_419911_variants.gff3 2019-nCoV_EPI_ISL_419912_variants.gff3 2019-nCoV_EPI_ISL_419914_variants.gff3 2019-nCoV_EPI_ISL_419915_variants.gff3 2019-nCoV_EPI_ISL_419916_variants.gff3 2019-nCoV_EPI_ISL_419917_variants.gff3 2019-nCoV_EPI_ISL_419918_variants.gff3 2019-nCoV_EPI_ISL_419919_variants.gff3 2019-nCoV_EPI_ISL_419920_variants.gff3 2019-nCoV_EPI_ISL_419921_variants.gff3 2019-nCoV_EPI_ISL_419922_variants.gff3 2019-nCoV_EPI_ISL_419923_variants.gff3 2019-nCoV_EPI_ISL_419924_variants.gff3 2019-nCoV_EPI_ISL_419925_variants.gff3 2019-nCoV_EPI_ISL_419926_variants.gff3 2019-nCoV_EPI_IS
EPI_ISL_419989_variants.gff3 2019-nCoV_EPI_ISL_419990_variants.gff3 2019-nCoV_EPI_ISL_419991_variants.gff3 2019-nCoV_EPI_ISL_419992_variants.gff3 2019-nCoV_EPI_ISL_419993_variants.gff3 2019-nCoV_EPI_ISL_419994_variants.gff3 2019-nCoV_EPI_ISL_419995_variants.gff3 2019-nCoV_EPI_ISL_419996_variants.gff3 2019-nCoV_EPI_ISL_419997_variants.gff3 2019-nCoV_EPI_ISL_419998_variants.gff3 2019-nCoV_EPI_ISL_419999_variants.gff3 2019-nCoV_EPI_ISL_420000_variants.gff3 2019-nCoV_EPI_ISL_420001_variants.gff3 2019-nCoV_EPI_ISL_420002_variants.gff3 2019-nCoV_EPI_ISL_420003_variants.gff3 2019-nCoV_EPI_ISL_420004_variants.gff3 2019-nCoV_EPI_ISL_420005_variants.gff3 2019-nCoV_EPI_ISL_420006_variants.gff3 2019-nCoV_EPI_ISL_4200 ...
# 2019-nCoV_EPI_ISL_420903_variants.gff3 2019-nCoV_EPI_ISL_420912_variants.gff3 2019-nCoV_EPI_ISL_420929_variants.gff3

# %% [markdown]
# ### Concatenate all variation data into a single dataframe

# %%
# use all cached data files
path = str(CACHE / '*.gff3.csv')
filenames = glob.glob(path)

variations = pd.concat((pd.read_csv(f, index_col=None, header=0) for f in filenames))
variations.fillna('', inplace=True)

# %% [markdown]
# List of variant types and consequences:
#
# https://uswest.ensembl.org/info/genome/variation/prediction/classification.html
#
# https://uswest.ensembl.org/info/genome/variation/prediction/predicted_data.html#consequences

# %% [markdown]
# #### Extract protein position and protein id from proteinVariant string
#
# Example: QHD43415.1:p.5828P>L
#
# proteinPosition: 5828
# proteinId: QHD43415

# %%
position_pattern = re.compile(':p\.(.*?)[A-Z|\-]+')

# %%
def extract_protein_position(s):
    if s == '':
        return s
    else:
        groups = position_pattern.search(s)
        if groups == None:
            return ''
        else:
            return groups.group(1)

# %%
variations['proteinPosition'] = variations['proteinVariant'].apply(extract_protein_position)

# %%
variations['proteinAccession'] = variations['proteinVariant'].apply(lambda s: s.split('.')[0] if '.' in s else '')

# %%
variations['proteinAccession'].unique()

# %% [markdown]
# #### Assign SARS-CoV-2 taxonomy id

# %%
variations['taxonomyId'] = 'taxonomy:2697049'

# %% [markdown]
# #### Assign Reference genome
#
# The first SARS-CoV-2 genome sequence is the reference for the variant annotation below.
#
# [Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1](https://www.ncbi.nlm.nih.gov/nuccore/MN908947)

# %%
# variations['referenceGenome'] = 'insdc:MN908947' -> same as NCBI reference sequence NC_045512
variations['referenceGenome'] = 'ncbiprotein:NC_045512'

# %%
variations['proteinAccession'] = variations['proteinAccession'].apply(lambda s: 'ncbiprotein:' + s if s != '' else s)

# %%
print('variantType:', variations['variantType'].unique())

# %%
print("variantConsequence:", variations['variantConsequence'].unique())

# %%
print("Number of variants:", variations.shape[0])

# %%
variations.to_csv(NEO4J_IMPORT / "01d-CNCBVariant.csv", index=False)

# %%
variations.head()
