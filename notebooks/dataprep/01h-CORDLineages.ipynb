# %% [markdown]
# # Downloads Publication Information for PANGO Lineages from the CORD-19 Data Set
# **[Work in progress]**
#
# This notebook text-mines [PANGO lineage](https://cov-lineages.org/) mentions in the titles and abstracts of publications and preprints from the CORD-19 data set. Note, the text-mined results may contain false positive!
#
# Data sources: [PANGO Lineage Designations](https://github.com/cov-lineages/pango-designation),
# [CORD-19](https://allenai.org/data/cord-19)
#
# References:
#
# Rambaut A, et al., A dynamic nomenclature proposal for SARS-CoV-2 lineages to assist genomic epidemiology(2020) Nature Microbiology [doi:10.1038/s41564-020-0770-5](https://doi.org/10.1038/s41564-020-0770-5).
#
# Lucy Lu Wang, et al., CORD-19: The COVID-19 Open Research Dataset (2020) [arXiv:2004.10706v4](https://arxiv.org/abs/2004.10706).
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import pandas as pd
import io
import dateutil
import re
from pathlib import Path

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_IMPORT = Path(os.getenv('NEO4J_IMPORT'))
print(NEO4J_IMPORT)
# Out:
# /Users/peter/Library/Application Support/com.Neo4j.Relate/data/dbmss/dbms-8bf637fc-0d20-4d9f-9c6f-f7e72e92a4da/import

# %% [markdown]
# ## Get PANGO lineages

# %%
pango = pd.read_csv(NEO4J_IMPORT / "00b-PANGOLineage.csv", dtype=str)

# %%
pango.sample(5)
# Out:
#          lineage                                        description  \
# 1208         M.1                       Alias of B.1.1.294.1, Israel
# 966      B.1.510  Iceland, Sweden, North America (could be disso...
# 622   B.1.177.53                                         UK lineage
# 1158         C.2  Alias of B.1.1.1.2, South Africa and some Euro...
# 529      B.1.153  English lineage with some Australian, New Zeal...
#
#             alias predecessor          l0       l1   l2   l3 levels
# 1208  B.1.1.294.1   B.1.1.294         M.1        M  NaN  NaN      2
# 966           NaN         NaN     B.1.510      B.1    B  NaN      3
# 622           NaN         NaN  B.1.177.53  B.1.177  B.1    B      4
# 1158    B.1.1.1.2     B.1.1.1         C.2        C  NaN  NaN      2
# 529           NaN         NaN     B.1.153      B.1    B  NaN      3

# %%
lineages = set(pango['lineage'].unique())

# %% [markdown]
# ## Get CORD-19 Metadata

# %%
CACHE = Path(NEO4J_IMPORT / 'cache/cord19/metadata.csv')

# %%
metadata = pd.read_csv(CACHE, dtype='str')

# %%
metadata.fillna('', inplace=True)
#convert datetime column to just date
metadata['year'] = metadata['publish_time'].apply(lambda d: d[:4] if len(d) > 4 else '')
metadata['date'] = metadata['publish_time'].apply(lambda d: dateutil.parser.parse(d) if len(d) > 0 else '')

# %%
print("Total number of papers", metadata.shape[0])
# Out:
# Total number of papers 536817

# %% [markdown]
# ## Extract a list of PANGO lineages

# %% [markdown]
# Remove special characters to simply parsing for lineages in parenthesis, comma-separated lists, etc.

# %%
metadata['title'] = metadata['title'].replace('[()/,]', ' ', regex=True)
metadata['abstract'] = metadata['abstract'].replace('[()/,]', ' ', regex=True)

# %% [markdown]
# Match PANGO patterns and check agains list of known lineages.

# %%
pattern1 = re.compile(' [A-Z]{1,2}[.]\d+ ')
pattern2 = re.compile(' [A-Z]{1,2}[.]\d+[.]\d+ ')
pattern3 = re.compile(' [A-Z]{1,2}[.]\d+[.]\d+[.]+\d+ ')

# %%
def get_lineages(row):
    text = ' ' + row.title + ' ' + row.abstract + ' '
    lin = pattern1.findall(text) + pattern2.findall(text) + pattern3.findall(text)
    u_lin = set()
    
    for l in lin:
        l = l.strip()
        # check if lineage is valid (e.g., not a withdrawn lineage or false positive)
        if l in lineages:
            u_lin.add(l)
            
    return ";".join(u_lin)

# %%
metadata['lineages'] = metadata.apply(get_lineages, axis=1)

# %% [markdown]
# Keep only papers that map to PANGO lineages

# %%
hits = metadata[metadata['lineages'].str.len() > 0].copy()

# %% [markdown]
# ### Assign CURIEs from [Identifiers.org](https://identifiers.org)

# %%
hits['doi'] = hits['doi'].apply(lambda x: 'doi:' + x if len(x) > 0 else '')
hits['pubmed_id'] = hits['pubmed_id'].apply(lambda x: 'pubmed:' + x if len(x) > 0 else '')
hits['pmcid'] = hits['pmcid'].apply(lambda x: 'pmc:' + x if len(x) > 0 else '')
hits['arxiv_id'] = hits['arxiv_id'].apply(lambda x: 'arxiv:' + x if len(x) > 0 else '')

# %%
#hits.sort_values(by=['publish_time'], ascending=False, inplace=True)

# %%
print("Number of matches", hits.shape[0])
# Out:
# Number of matches 592

# %%
def create_id(row):
    """Creates a unique id using the most commonly available id in priority order"""
    if row.doi != '':
        return row.doi
    elif row.pubmed_id != '':
        return row.pubmed_id
    elif row.pmcid != '':
        return row.pmcid
    elif row.arxiv_id != '':
        return row.arxiv_id
    elif row.url != '':
        return row.url
    else:
        # TODO deal with WHO papers here?
        return ''

# %%
hits['id'] = hits.apply(create_id, axis=1)

# %%
hits.sample(20)
# Out:
#         cord_uid                                                sha  \
# 286738  itikugkk
# 247931  ftvatk0a
# 16254   g157h5sn           cc129c4cd6dc4523658db923b90f269e11d9d09a
# 420424  vw3cuiof  69fa13b80bb407e8bca177cfb906bbf604ffcf63; c0ee...
# 395962  wun5rwsk           3966d03d72440c939928b54f0d024f49181db116
# 96776   k3qp2lxc
# 477204  g9pwxfd2           5adfe79458623b8b71e1c1b3ccf370a81445a654
# 447927  3ztgrafg
# 169766  h5e8bi73
# 483453  ccqq5734           38be32b65618c66a2e3d41db5be9cda55a01b324
# 452322  770f1qn6           e49ae48fbdccbf290c84f9670a9257f2d3e00fa3
# 96842   6bne3x68
# 454903  ufybfmp4
# 462424  0usbo1yu
# 279515  f6yc8ho0
# 529853  k0uolif0           c5bf135c660e1a18623d3f3c40c7b89c9630e310
# 424949  1ms5m97x           fbf9052e9c2076014217462000f8fdc35464e5dc
# 219772  61ck712f
# 331889  3qe1tyur
# 485445  9ju00ryh           5fc2ca54b6535130b999af0cd24f41cbc1321c94
#
#                       source_x  \
# 286738                     WHO
# 247931                     WHO
# 16254                      PMC
# 420424  Elsevier; Medline; PMC
# 395962  Elsevier; Medline; PMC
# 96776                  Medline
# 477204  Elsevier; Medline; PMC
# 447927            MedRxiv; WHO
# 169766                     WHO
# 483453            BioRxiv; WHO
# 452322  Elsevier; Medline; PMC
# 96842                  Medline
# 454903            MedRxiv; WHO
# 462424            BioRxiv; WHO
# 279515                     WHO
# 529853            BioRxiv; WHO
# 424949            Medline; PMC
# 219772                     WHO
# 331889                     WHO
# 485445            MedRxiv; WHO
#
#                                                     title  \
# 286738  An Observational Laboratory-Based Assessment o...
# 247931  Immunoinformatic analysis of structural and ep...
# 16254   Could it be that the B.1.1.7 lineage is more d...
# 420424  Genomic characteristics and clinical effect of...
# 395962  Emergence and rapid transmission of SARS-CoV-2...
# 96776   Detection of B.1.351 SARS-CoV-2 Variant Strain...
# 477204  Characterizing SARS-CoV-2 genome diversity cir...
# 447927  SARS-CoV-2 B.1.1.7 lineage-related perceptions...
# 169766  Identification of B.1.346 Lineage of SARS-CoV-...
# 483453  A human antibody with blocking activity to RBD...
# 452322  Effect of the new SARS-CoV-2 variant B.1.1.7 o...
# 96842   Sensitivity of infectious SARS-CoV-2 B.1.1.7 a...
# 454903  Epidemiological and Clinical Characteristics  ...
# 462424  Phylogenetic analyses of SARS-CoV-2 B.1.1.7 li...
# 279515  Detection of B.1.351 SARS-CoV-2 Variant Strain...
# 529853  Computational assessment of the spike protein ...
# 424949  SARS-CoV-2 Variant of Concern 202 012 01  B.1....
# 219772  Sixteen novel lineages of SARS-CoV-2 in South ...
# 331889  Detection and Genome Sequencing of SARS-CoV-2 ...
# 485445  Immunodominant B cell epitope in SARS-CoV-2 RB...
#
#                                       doi           pmcid        pubmed_id  \
# 286738
# 247931
# 16254             doi:10.1017/ice.2021.59  pmc:PMC7948098  pubmed:33557960
# 420424  doi:10.1016/s1473-3099(21)00170-5  pmc:PMC8041359  pubmed:33857406
# 395962     doi:10.1016/j.cell.2021.03.052  pmc:PMC8009040  pubmed:33861950
# 96776          doi:10.15585/mmwr.mm7008e2                  pubmed:33630820
# 477204     doi:10.1016/j.ijid.2021.02.073  pmc:PMC7895695  pubmed:33618008
# 447927    doi:10.1101/2021.01.19.21250111
# 169766
# 483453      doi:10.1101/2021.02.07.429299
# 452322  doi:10.1016/s2352-4642(21)00030-4  pmc:PMC7906637  pubmed:33581054
# 96842      doi:10.1038/s41591-021-01318-5                  pubmed:33772244
# 454903    doi:10.1101/2021.01.06.20249091
# 462424      doi:10.1101/2021.01.12.426373
# 279515
# 529853      doi:10.1101/2021.03.25.437035
# 424949            doi:10.1093/jtm/taab032  pmc:PMC7989411  pubmed:33693926
# 219772
# 331889
# 485445    doi:10.1101/2021.03.11.21253399
#
#           license                                           abstract  \
# 286738        unk  Information on severe acute respiratory syndro...
# 247931        unk  A newly emerged strain of SARS-CoV-2 of B.1.1....
# 16254       no-cc
# 420424      no-cc  BACKGROUND: Emergence of variants with specifi...
# 395962  els-covid  The highly transmissible B.1.1.7 variant of SA...
# 96776         unk  The first laboratory-confirmed cases of corona...
# 477204  els-covid  Objectives To evaluate the genomic diversity a...
# 447927    medrxiv  Background: Healthcare workers'  HCWs'  travel...
# 169766        unk  SARS-CoV-2 whole-genome sequencing of samples ...
# 483453    biorxiv  Severe acute respiratory syndrome coronavirus-...
# 452322      no-cc
# 96842         unk  Severe acute respiratory syndrome coronavirus ...
# 454903    medrxiv  Background: The earliest coronavirus disease-2...
# 462424    biorxiv  The authors have withdrawn this manuscript bec...
# 279515        unk  The first laboratory-confirmed cases of corona...
# 529853    biorxiv  Since its emergence into the human population ...
# 424949      no-cc  We report the complete genome of SARS-CoV-2 VO...
# 219772        unk  The first severe acute respiratory syndrome co...
# 331889        unk  Since the emergence of coronavirus disease  CO...
# 485445    medrxiv  Recent SARS-CoV-2 variants pose important conc...
#
#        publish_time                                            authors  \
# 286738         2021  Sander, Anna-Lena; Yadouleton, Anges; Moreira-...
# 247931         2021  Hussain, Mushtaq; Shabbir, Sanya; Amanullah, A...
# 16254    2021-02-09               Kow, Chia Siang; Hasan, Syed Shahzad
# 420424   2021-04-12  Frampton, Dan; Rampling, Tommy; Cross, Aidan; ...
# 395962   2021-03-30  Washington, Nicole L.; Gangavarapu, Karthik; Z...
# 96776    2021-02-26  Mwenda, Mulenga; Saasa, Ngonda; Sinyange, Nyam...
# 477204   2021-02-20  Muñoz, Marina; Patiño, Luz H.; Ballesteros, Na...
# 447927   2021-01-21  Temsah, M.-H.; Barry, M.; Aljamaan, F.; Alhuza...
# 169766         2021  Abe, Kodai; Shimura, Takako; Takenouchi, Toshi...
# 483453   2021-02-08  Gu, Chunyin; Cao, Xiaodan; Wang, Zongda; Hu, X...
# 452322   2021-02-10  Brookman, Sarah; Cook, James; Zucherman, Mark;...
# 96842    2021-03-26  Planas, Delphine; Bruel, Timothée; Grzelak, Lu...
# 454903   2021-01-08  Yegorov, S.; Goremykina, M.; Ivanova, R.; Good...
# 462424   2021-01-15  Vrancken, B.; Dellicour, S.; Smith, D.M.; Chai...
# 279515         2021  Mwenda, Mulenga; Saasa, Ngonda; Sinyange, Nyam...
# 529853   2021-03-25        Ge, Anni; Rioux, Melissa; Kelvin, Alyson A.
# 424949   2021-03-08  Yao, Mingxiao; Jiang, Fachun; Zhang, Yuwei; Li...
# 219772         2021  Tegally, Houriiyah; Wilkinson, Eduan; Lessells...
# 331889         2021  Klaus, Julia; Meli, Marina L; Willi, Barbara; ...
# 485445   2021-03-12  Santos, K. S.; Oliveira, J. R.; Machado, R. R....
#
#                                             journal mag_id who_covidence_id  \
# 286738                                      MSphere                #1029965
# 247931                                J. med. virol                #1126508
# 16254
# 420424                            Lancet Infect Dis
# 395962                                         Cell
# 96776   MMWR. Morbidity and mortality weekly report
# 477204                             Int J Infect Dis
# 447927
# 169766                                  Keio j. med                #1183786
# 483453                                      bioRxiv
# 452322                  Lancet Child Adolesc Health
# 96842                               Nature medicine
# 454903
# 462424                                      bioRxiv
# 279515                    MMWR Morb Mortal Wkly Rep                #1102701
# 529853                                      bioRxiv
# 424949                                 J Travel Med
# 219772                                      Nat Med                #1061182
# 331889                                      Viruses                #1138760
# 485445
#
#        arxiv_id                                     pdf_json_files  \
# 286738
# 247931
# 16254            document_parses/pdf_json/cc129c4cd6dc4523658db...
# 420424           document_parses/pdf_json/69fa13b80bb407e8bca17...
# 395962           document_parses/pdf_json/3966d03d72440c939928b...
# 96776
# 477204           document_parses/pdf_json/5adfe79458623b8b71e1c...
# 447927
# 169766
# 483453           document_parses/pdf_json/38be32b65618c66a2e3d4...
# 452322           document_parses/pdf_json/e49ae48fbdccbf290c84f...
# 96842
# 454903
# 462424
# 279515
# 529853           document_parses/pdf_json/c5bf135c660e1a18623d3...
# 424949           document_parses/pdf_json/fbf9052e9c20760142174...
# 219772
# 331889
# 485445           document_parses/pdf_json/5fc2ca54b6535130b999a...
#
#                                       pmc_json_files  \
# 286738
# 247931
# 16254   document_parses/pmc_json/PMC7948098.xml.json
# 420424  document_parses/pmc_json/PMC8041359.xml.json
# 395962
# 96776
# 477204
# 447927
# 169766
# 483453
# 452322  document_parses/pmc_json/PMC7906637.xml.json
# 96842
# 454903
# 462424
# 279515
# 529853
# 424949
# 219772
# 331889
# 485445
#
#                                                       url      s2_id  year  \
# 286738                                                     231605197
# 247931                                                     232196602
# 16254   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...             2021
# 420424  https://www.sciencedirect.com/science/article/...  233215323  2021
# 395962  https://www.ncbi.nlm.nih.gov/pubmed/33861950/;...  232412011  2021
# 96776   https://doi.org/10.15585/mmwr.mm7008e2; https:...  232058475  2021
# 477204  https://api.elsevier.com/content/article/pii/S...  231965833  2021
# 447927  http://medrxiv.org/cgi/content/short/2021.01.1...  231653830  2021
# 169766                                                     231729271
# 483453          https://doi.org/10.1101/2021.02.07.429299  231885348  2021
# 452322  https://api.elsevier.com/content/article/pii/S...  231919047  2021
# 96842   https://doi.org/10.1038/s41591-021-01318-5; ht...  232375717  2021
# 454903  https://doi.org/10.1101/2021.01.06.20249091; h...  231138384  2021
# 462424          https://doi.org/10.1101/2021.01.12.426373  231666904  2021
# 279515                                                     232058475
# 529853          https://doi.org/10.1101/2021.03.25.437035  232412338  2021
# 424949  https://doi.org/10.1093/jtm/taab032; https://w...  232197534  2021
# 219772                                                     231788423
# 331889                                                     232383967
# 485445  https://doi.org/10.1101/2021.03.11.21253399; h...  232204178  2021
#
#              date                       lineages  \
# 286738 2021-04-23                        A.4;B.1
# 247931 2021-04-23                        B.1.1.7
# 16254  2021-02-09                        B.1.1.7
# 420424 2021-04-12                        B.1.1.7
# 395962 2021-03-30                        B.1.1.7
# 96776  2021-02-26                        B.1.351
# 477204 2021-02-20            B.1.351;B.1.1.7;P.1
# 447927 2021-01-21                        B.1.1.7
# 169766 2021-04-23    B.1.1.284;B.1.1.214;B.1.346
# 483453 2021-02-08                        B.1.351
# 452322 2021-02-10                        B.1.1.7
# 96842  2021-03-26                B.1.351;B.1.1.7
# 454903 2021-01-08      B.4.1;B.1.3;B.1.1;B.1;A.2
# 462424 2021-01-15                        B.1.1.7
# 279515 2021-04-23                        B.1.351
# 529853 2021-03-25    B.1.351;B.1.1.7;B.1.429;P.1
# 424949 2021-03-08                        B.1.1.7
# 219772 2021-04-23  B.1.1.54;B.1.1.56;C.1;B.1.106
# 331889 2021-04-23                       B.1.1.39
# 485445 2021-03-12                    B.1.351;P.1
#
#                                        id
# 286738
# 247931
# 16254             doi:10.1017/ice.2021.59
# 420424  doi:10.1016/s1473-3099(21)00170-5
# 395962     doi:10.1016/j.cell.2021.03.052
# 96776          doi:10.15585/mmwr.mm7008e2
# 477204     doi:10.1016/j.ijid.2021.02.073
# 447927    doi:10.1101/2021.01.19.21250111
# 169766
# 483453      doi:10.1101/2021.02.07.429299
# 452322  doi:10.1016/s2352-4642(21)00030-4
# 96842      doi:10.1038/s41591-021-01318-5
# 454903    doi:10.1101/2021.01.06.20249091
# 462424      doi:10.1101/2021.01.12.426373
# 279515
# 529853      doi:10.1101/2021.03.25.437035
# 424949            doi:10.1093/jtm/taab032
# 219772
# 331889
# 485445    doi:10.1101/2021.03.11.21253399

# %% [markdown]
# WHO documents seem to be copies of articles that are already present in the dataset and will be ignored for now.

# %%
hits[hits['abstract'].str.contains('INTRODUCTION: Venezuela and')]
# Out:
#         cord_uid                                       sha  \
# 278446  84bhzaqw
# 518529  0vtredu8  d2d3b8b04378bebdde024760e49c297a24dd2af7
#
#                       source_x  \
# 278446                     WHO
# 518529  Elsevier; Medline; PMC
#
#                                                     title  \
# 278446  SARS-CoV-2 spread across the Colombian-Venezue...
# 518529  SARS-CoV-2 spread across the Colombian-Venezue...
#
#                                      doi           pmcid        pubmed_id  \
# 278446
# 518529  doi:10.1016/j.meegid.2020.104616  pmc:PMC7609240  pubmed:33157300
#
#        license                                           abstract  \
# 278446     unk  INTRODUCTION: Venezuela and Colombia both adop...
# 518529   no-cc  INTRODUCTION: Venezuela and Colombia both adop...
#
#        publish_time                                            authors  \
# 278446         2020  Paniz-Mondolfi, Alberto; Muñoz, Marina; Florez...
# 518529   2020-11-04  Paniz-Mondolfi, Alberto; Muñoz, Marina; Florez...
#
#                   journal mag_id who_covidence_id arxiv_id  \
# 278446  Infect Genet Evol                 #907154
# 518529  Infect Genet Evol
#
#                                            pdf_json_files  \
# 278446
# 518529  document_parses/pdf_json/d2d3b8b04378bebdde024...
#
#                                       pmc_json_files  \
# 278446
# 518529  document_parses/pmc_json/PMC7609240.xml.json
#
#                                                       url      s2_id  year  \
# 278446                                                     220444484
# 518529  https://www.ncbi.nlm.nih.gov/pubmed/33157300/;...  226238553  2020
#
#              date lineages                                id
# 278446 2020-04-23   B.1.13
# 518529 2020-11-04   B.1.13  doi:10.1016/j.meegid.2020.104616

# %%
hits.query('id != ""', inplace=True)

# %%
print("Total number of matches", hits.shape[0])
# Out:
# Total number of matches 449

# %%
hits.to_csv(NEO4J_IMPORT / "01h-CORDLineages.csv", index=False)
