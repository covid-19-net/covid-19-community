# %% [markdown]
# # Downloads Publication Information for Pangolin Linages from the CORD-19 Data Set
# **[Work in progress]**
#
# This notebook identifies publications in preprints in the CORD-19 data set that mention PANGO lineages.
#
# Data sources: [PANGO Lineage Designations](https://github.com/cov-lineages/pango-designation),
# [CORD-19](https://allenai.org/data/cord-19)
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
import pandas as pd
import io
import dateutil
import re
from pathlib import Path

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_IMPORT = Path(os.getenv('NEO4J_IMPORT'))
print(NEO4J_IMPORT)
# Out:
# /Users/peter/Library/Application Support/com.Neo4j.Relate/data/dbmss/dbms-8bf637fc-0d20-4d9f-9c6f-f7e72e92a4da/import

# %% [markdown]
# ## Get PANGO lineages

# %%
pango_url = 'https://raw.githubusercontent.com/cov-lineages/pango-designation/master/lineage_notes.txt'

# %%
pangolin = pd.read_csv(pango_url, sep='\t', skiprows=1, dtype=str, names=['lineage', 'description'])

# %%
pangolin['lineage'] = pangolin['lineage'].str.strip()

# %%
pangolin.sample(10)
# Out:
#          lineage                                        description
# 18          A.16                                   Japanese lineage
# 56      B.1.1.37                                         UK lineage
# 1292   *B.1.1.76                             Withdrawn: USA lineage
# 333    B.1.1.381                                           Peruvian
# 1194         D.5      Alias of B.1.1.25.5, Swedish/ Denmark lineage
# 1314  *B.1.1.156                   Withdrawn: South African lineage
# 1209         N.4                       Alias of B.1.1.33.4, Chilean
# 1461    *B.1.283                             Withdrawn: USA lineage
# 17          A.15                            Sweden/ Denmark lineage
# 1436    *B.1.204  Withdrawn: Reassigned in the current tree. USA...

# %%
lineages = set(pangolin['lineage'].unique())

# %% [markdown]
# ## Get CORD-19 Metadata

# %%
CACHE = Path(NEO4J_IMPORT / 'cache/cord19/metadata.csv')

# %%
metadata = pd.read_csv(CACHE, dtype='str')

# %%
metadata.fillna('', inplace=True)
#convert datetime column to just date
metadata['year'] = metadata['publish_time'].apply(lambda d: d[:4] if len(d) > 4 else '')
metadata['date'] = metadata['publish_time'].apply(lambda d: dateutil.parser.parse(d) if len(d) > 0 else '')

# %%
print("Total number of papers", metadata.shape[0])
# Out:
# Total number of papers 536817

# %% [markdown]
# ## Extract a list of PANGO lineages

# %% [markdown]
# Remove special characters to simply parsing for lineages in parenthesis, comma-separated lists, etc.

# %%
metadata['title'] = metadata['title'].replace('[()/,]', ' ', regex=True)
metadata['abstract'] = metadata['abstract'].replace('[()/,]', ' ', regex=True)

# %% [markdown]
# Match PANGO patterns and check agains list of known lineages.

# %%
pattern1 = re.compile(' [A-Z]{1,2}[.]\d+ ')
pattern2 = re.compile(' [A-Z]{1,2}[.]\d+[.]\d+ ')
pattern3 = re.compile(' [A-Z]{1,2}[.]\d+[.]\d+[.]+\d+ ')

# %%
def get_lineages(row):
    text = ' ' + row.title + ' ' + row.abstract + ' '
    lin = pattern1.findall(text) + pattern2.findall(text) + pattern3.findall(text)
    u_lin = set()
    for l in lin:
        l = l.strip()
        if l in lineages:
            u_lin.add(l)
    return ";".join(u_lin)

# %%
metadata['lineages'] = metadata.apply(get_lineages, axis=1)

# %% [markdown]
# Keep only papers that map to PANGO lineages

# %%
hits = metadata[metadata['lineages'].str.len() > 0].copy()

# %% [markdown]
# ### Assign CURIEs from [Identifiers.org](https://identifiers.org)

# %%
hits['doi'] = hits['doi'].apply(lambda x: 'doi:' + x if len(x) > 0 else '')
hits['pubmed_id'] = hits['pubmed_id'].apply(lambda x: 'pubmed:' + x if len(x) > 0 else '')
hits['pmcid'] = hits['pmcid'].apply(lambda x: 'pmc:' + x if len(x) > 0 else '')
hits['arxiv_id'] = hits['arxiv_id'].apply(lambda x: 'arxiv:' + x if len(x) > 0 else '')

# %%
#hits.sort_values(by=['publish_time'], ascending=False, inplace=True)

# %%
print("Number of matches", hits.shape[0])
# Out:
# Number of matches 592

# %%
def create_id(row):
    """Creates a unique id using the most commonly available id in priority order"""
    if row.doi != '':
        return row.doi
    elif row.pubmed_id != '':
        return row.pubmed_id
    elif row.pmcid != '':
        return row.pmcid
    elif row.arxiv_id != '':
        return row.arxiv_id
    elif row.url != '':
        return row.url
    else:
        # TODO deal with WHO papers here?
        return ''

# %%
hits['id'] = hits.apply(create_id, axis=1)

# %%
hits.sample(20)
# Out:
#         cord_uid                                       sha  \
# 383903  46pqwsqw  b729ed05d200a4c90dcf2a384f93f8ed84ca0ca8
# 48848   y41z0l47
# 230447  ylhoydgr
# 496497  it1lbk8q  3c63f6f65d70209f54329313fd9136ae2cafb8d4
# 423146  v115xwc3  eb1e5c04651fa8e660474feafe29cf6667316a74
# 273960  fdxvruj2
# 426052  yxo2cooa  fba9a188a93615d3f36205ad150e67d23d893bb9
# 380251  g9mzoyw9  31ac1241c8ee1021ecdd8923fd9efb219ec85896
# 453462  ole0fpmo  2de3e960ae944f08ff04bae8edd063e229c4ea6c
# 50608   q0ysdgsf
# 534972  g3iczwue  125a3e8ce28c90a68af2a96b701975498da2824f
# 419161  tm67efpw  72c4a3b22fcfc2df353c56610aa054afee86f5a9
# 297366  9cua6sd7
# 455698  epd5r7td  50024c19bac0faab870daf59083fd7fe488bf21a
# 429141  h9ds8qwl  0252dcb6b38cd1869db79c6a5c362e4310e6f684
# 510449  zoe8vn8m  35ad67ba5cbc7df7daedef147077476c6d64b9aa
# 532446  trdcg6zw  4bd7add648e3850d56e82b96561804b72bc688d1
# 177686  qekaciup
# 111002  di45k0dp
# 490339  lsk1311o  cb2c0c1dd2ff3ceeb391df259d61bdf20a0b741b
#
#                           source_x  \
# 383903  BioRxiv; Medline; PMC; WHO
# 48848                      Medline
# 230447                         WHO
# 496497       BioRxiv; Medline; WHO
# 423146                BioRxiv; WHO
# 273960                         WHO
# 426052                Medline; PMC
# 380251                MedRxiv; WHO
# 453462                BioRxiv; WHO
# 50608                      Medline
# 534972                MedRxiv; WHO
# 419161                MedRxiv; WHO
# 297366                         WHO
# 455698       MedRxiv; Medline; WHO
# 429141                MedRxiv; WHO
# 510449                BioRxiv; WHO
# 532446                MedRxiv; WHO
# 177686                         WHO
# 111002                     Medline
# 490339                MedRxiv; WHO
#
#                                                     title  \
# 383903  A new SARS-CoV-2 lineage that shares mutations...
# 48848   Response to: COVID-19 re-infection. Vaccinated...
# 230447           The variant gambit: COVID-19's next move
# 496497  Effect of natural mutations of SARS-CoV-2 on s...
# 423146  Emerging variants of concern in SARS-CoV-2 mem...
# 273960  VOC 202012 01 Variant Is Effectively Neutraliz...
# 426052  Will the emergent SARS‐CoV2 B.1.1.7 lineage af...
# 380251  Detection of the Novel SARS-CoV-2 European Lin...
# 453462  Molecular Mechanism of the N501Y Mutation for ...
# 50608   The first SARS-CoV-2 genetic variants of conce...
# 534972  Evaluation of a fully automated high-throughpu...
# 419161  Genomic characterization of a novel SARS-CoV-2...
# 297366  SARS-CoV-2 mRNA vaccines induce broad CD4+ T c...
# 455698  mRNA vaccination compared to infection elicits...
# 429141  Early Analysis of a potential link between vir...
# 510449  The B1.351 and P.1 variants extend SARS-CoV-2 ...
# 532446  An allele-specific primer extension assay to q...
# 177686  Can mRNA Vaccines Turn the Tables During the C...
# 111002  Sensitivity of SARS-CoV-2 B.1.1.7 to mRNA vacc...
# 490339  Impact of Clinical and Genomic Factors on SARS...
#
#                                     doi           pmcid        pubmed_id  \
# 383903    doi:10.1101/2021.04.05.438352  pmc:PMC8043452  pubmed:33851162
# 48848             doi:10.1111/eci.13544                  pubmed:33725359
# 230447
# 496497    doi:10.1101/2021.03.11.435037                  pubmed:33758838
# 423146    doi:10.1101/2021.03.11.434758
# 273960
# 426052            doi:10.1002/jmv.26823  pmc:PMC8013853  pubmed:33506970
# 380251  doi:10.1101/2020.11.30.20241265
# 453462    doi:10.1101/2021.01.04.425316
# 50608   doi:10.1016/j.advms.2021.03.005                  pubmed:33827042
# 534972  doi:10.1101/2021.02.12.21251614
# 419161  doi:10.1101/2020.12.23.20248598
# 297366
# 455698  doi:10.1101/2021.04.05.21254952                  pubmed:33851181
# 429141  doi:10.1101/2021.01.12.20249080
# 510449    doi:10.1101/2021.03.18.436013
# 532446  doi:10.1101/2021.02.22.21252041
# 177686
# 111002   doi:10.1038/s41586-021-03412-7                  pubmed:33706364
# 490339  doi:10.1101/2021.03.15.21253549
#
#         license                                           abstract  \
# 383903  biorxiv  We report a SARS-CoV-2 lineage that shares N50...
# 48848       unk  Vaccination against SARS-CoV-2 has shown to of...
# 230447      unk  More than a year after its emergence  COVID-19...
# 496497  biorxiv  New SARS-CoV-2 variants that have accumulated ...
# 423146  biorxiv  Mutations in the SARS-CoV-2 Membrane  M  gene ...
# 273960      unk  The coronavirus disease 2019  Covid-19  pandem...
# 426052    no-cc  As the coronavirus disease 2019 pandemic keep ...
# 380251  medrxiv  Background: Travel-related dissemination of SA...
# 453462  biorxiv  Coronavirus disease 2019  COVID-19  has been a...
# 50608       unk  PURPOSE We analyzed the SARS-CoV-2 genome usin...
# 534972  medrxiv  Background: New SARS-CoV-2 variants with incre...
# 419161  medrxiv  In this study  we report the sequencing of 180...
# 297366      unk  Recent studies have shown T cell cross-recogni...
# 455698  medrxiv  During the severe acute respiratory syndrome c...
# 429141  medrxiv  A new variant of SARS-CoV-2 has emerged which ...
# 510449  biorxiv  Receptor recognition is a major determinant of...
# 532446  medrxiv  The coronavirus disease 2019  COVID-19  pandem...
# 177686      unk  The COVID-19 pandemic continues to affect mill...
# 111002      unk  SARS-CoV-2 transmission is uncontrolled in man...
# 490339  medrxiv  The SARS-CoV2 virus behind the COVID-19 pandem...
#
#        publish_time                                            authors  \
# 383903   2021-04-06  Thornlow, Bryan; Hinrichs, Angie S.; Jain, Mit...
# 48848    2021-03-16  Schiavone, Marco; Gasperetti, Alessio; Mitacch...
# 230447         2021  Plante, Jessica A; Mitchell, Brooke M; Plante,...
# 496497   2021-03-15  Gobeil, Sophie M-C.; Janowska, Katarzyna; McDo...
# 423146   2021-03-11  Shen, Lishuang; Bard, Jennifer Dien; Triche, T...
# 273960         2021  Rondinone, Valeria; Pace, Lorenzo; Fasanella, ...
# 426052   2021-02-09  Ramírez, Juan D.; Muñoz, Marina; Patiño, Luz H...
# 380251   2020-12-02  Guthrie, J. L.; Teatero, S.; Zittermann, S.; C...
# 453462   2021-01-05           Luan, Binquan; Wang, Haoran; Huynh, Tien
# 50608    2021-03-30  Charkiewicz, Radosław; Nikliński, Jacek; Biece...
# 534972   2021-02-18  NoÌrz, D.; Grunwald, M.; Olearo, F.; Fischer,...
# 419161   2020-12-26  Voloch, C. M.; Francisco Junior, R. d. S.; de ...
# 297366         2021  Woldemeskel, Bezawit A; Garliss, Caroline C; B...
# 455698   2021-04-07  Roeltgen, K.; Nielsen, S. C. A.; Arunachalam, ...
# 429141   2021-01-15  Golubchik, T.; Lythgoe, K. A.; Hall, M. D.; Fe...
# 510449   2021-03-18  Montagutelli, Xavier; Prot, Matthieu; Levillay...
# 532446   2021-02-23  Graber, T. E.; Mercier, E.; D'Aoust, P. M.; Ho...
# 177686         2021  Deva Priya, Sagili Anthony; Kavitha, Shivakuma...
# 111002   2021-03-11  Collier, Dami A; De Marco, Anna; Ferreira, Isa...
# 490339   2021-03-24  Dey, S.; Bose, A.; Chakraborty, P.; Ghalwash, ...
#
#                                                   journal mag_id  \
# 383903                                            bioRxiv
# 48848          European journal of clinical investigation
# 230447                                  Cell host microbe
# 496497                                            bioRxiv
# 423146                                            bioRxiv
# 273960                                            Viruses
# 426052                                        J Med Virol
# 380251
# 453462                                            bioRxiv
# 50608                        Advances in medical sciences
# 534972
# 419161
# 297366                                    J. clin. invest
# 455698  medRxiv : the preprint server for health sciences
# 429141
# 510449                                            bioRxiv
# 532446
# 177686                                 Clin. drug investg
# 111002                                             Nature
# 490339
#
#        who_covidence_id arxiv_id  \
# 383903
# 48848
# 230447         #1116431
# 496497
# 423146
# 273960         #1079723
# 426052
# 380251
# 453462
# 50608
# 534972
# 419161
# 297366         #1171752
# 455698
# 429141
# 510449
# 532446
# 177686         #1146167
# 111002
# 490339
#
#                                            pdf_json_files  \
# 383903  document_parses/pdf_json/b729ed05d200a4c90dcf2...
# 48848
# 230447
# 496497  document_parses/pdf_json/3c63f6f65d70209f54329...
# 423146  document_parses/pdf_json/eb1e5c04651fa8e660474...
# 273960
# 426052  document_parses/pdf_json/fba9a188a93615d3f3620...
# 380251  document_parses/pdf_json/31ac1241c8ee1021ecdd8...
# 453462  document_parses/pdf_json/2de3e960ae944f08ff04b...
# 50608
# 534972  document_parses/pdf_json/125a3e8ce28c90a68af2a...
# 419161  document_parses/pdf_json/72c4a3b22fcfc2df353c5...
# 297366
# 455698  document_parses/pdf_json/50024c19bac0faab870da...
# 429141  document_parses/pdf_json/0252dcb6b38cd1869db79...
# 510449  document_parses/pdf_json/35ad67ba5cbc7df7daede...
# 532446  document_parses/pdf_json/4bd7add648e3850d56e82...
# 177686
# 111002
# 490339  document_parses/pdf_json/cb2c0c1dd2ff3ceeb391d...
#
#                                       pmc_json_files  \
# 383903  document_parses/pmc_json/PMC8043452.xml.json
# 48848
# 230447
# 496497
# 423146
# 273960
# 426052  document_parses/pmc_json/PMC8013853.xml.json
# 380251
# 453462
# 50608
# 534972
# 419161
# 297366
# 455698
# 429141
# 510449
# 532446
# 177686
# 111002
# 490339
#
#                                                       url      s2_id  year  \
# 383903  https://doi.org/10.1101/2021.04.05.438352; htt...  233175293  2021
# 48848   https://doi.org/10.1111/eci.13544; https://www...  232261925  2021
# 230447                                                     232081438
# 496497  https://www.ncbi.nlm.nih.gov/pubmed/33758838/;...  232224525  2021
# 423146          https://doi.org/10.1101/2021.03.11.434758  232224629  2021
# 273960                                                     232075133
# 426052  https://doi.org/10.1002/jmv.26823; https://www...  231756849  2021
# 380251  https://doi.org/10.1101/2020.11.30.20241265; h...  227247303  2020
# 453462          https://doi.org/10.1101/2021.01.04.425316  231615049  2021
# 50608   https://doi.org/10.1016/j.advms.2021.03.005; h...  233183354  2021
# 534972  http://medrxiv.org/cgi/content/short/2021.02.1...  231946939  2021
# 419161  http://medrxiv.org/cgi/content/short/2020.12.2...  229379623  2020
# 297366                                                     233172933
# 455698  https://doi.org/10.1101/2021.04.05.21254952; h...  233152556  2021
# 429141  http://medrxiv.org/cgi/content/short/2021.01.1...  231609885  2021
# 510449          https://doi.org/10.1101/2021.03.18.436013  232327734  2021
# 532446  https://doi.org/10.1101/2021.02.22.21252041; h...  231994900  2021
# 177686                                                     232315284
# 111002  https://doi.org/10.1038/s41586-021-03412-7; ht...  232206995  2021
# 490339  https://doi.org/10.1101/2021.03.15.21253549; h...  232333726  2021
#
#              date                     lineages  \
# 383903 2021-04-06                      B.1.1.7
# 48848  2021-03-16          P.1;B.1.351;B.1.1.7
# 230447 2021-04-22  P.1;B.1.429;B.1.351;B.1.1.7
# 496497 2021-03-15     B.1.1.28;B.1.351;B.1.1.7
# 423146 2021-03-11          B.1.429;B.1;B.1.1.7
# 273960 2021-04-22                  B.1;B.1.1.7
# 426052 2021-02-09                      B.1.1.7
# 380251 2020-12-02                      B.1.177
# 453462 2021-01-05                      B.1.1.7
# 50608  2021-03-30              B.1.351;B.1.1.7
# 534972 2021-02-18                      B.1.1.7
# 419161 2020-12-26                     B.1.1.28
# 297366 2021-04-22              B.1.351;B.1.1.7
# 455698 2021-04-07          P.1;B.1.351;B.1.1.7
# 429141 2021-01-15                      B.1.1.7
# 510449 2021-03-18                          P.1
# 532446 2021-02-23          P.1;B.1.351;B.1.1.7
# 177686 2021-04-22                      B.1.351
# 111002 2021-03-11                      B.1.1.7
# 490339 2021-03-24                      B.1.1.7
#
#                                      id
# 383903    doi:10.1101/2021.04.05.438352
# 48848             doi:10.1111/eci.13544
# 230447
# 496497    doi:10.1101/2021.03.11.435037
# 423146    doi:10.1101/2021.03.11.434758
# 273960
# 426052            doi:10.1002/jmv.26823
# 380251  doi:10.1101/2020.11.30.20241265
# 453462    doi:10.1101/2021.01.04.425316
# 50608   doi:10.1016/j.advms.2021.03.005
# 534972  doi:10.1101/2021.02.12.21251614
# 419161  doi:10.1101/2020.12.23.20248598
# 297366
# 455698  doi:10.1101/2021.04.05.21254952
# 429141  doi:10.1101/2021.01.12.20249080
# 510449    doi:10.1101/2021.03.18.436013
# 532446  doi:10.1101/2021.02.22.21252041
# 177686
# 111002   doi:10.1038/s41586-021-03412-7
# 490339  doi:10.1101/2021.03.15.21253549

# %% [markdown]
# WHO documents seem to be copies of articles that are already present in the dataset and will be ignored for now.

# %%
hits[hits['abstract'].str.contains('INTRODUCTION: Venezuela and')]
# Out:
#         cord_uid                                       sha  \
# 278446  84bhzaqw
# 518529  0vtredu8  d2d3b8b04378bebdde024760e49c297a24dd2af7
#
#                       source_x  \
# 278446                     WHO
# 518529  Elsevier; Medline; PMC
#
#                                                     title  \
# 278446  SARS-CoV-2 spread across the Colombian-Venezue...
# 518529  SARS-CoV-2 spread across the Colombian-Venezue...
#
#                                      doi           pmcid        pubmed_id  \
# 278446
# 518529  doi:10.1016/j.meegid.2020.104616  pmc:PMC7609240  pubmed:33157300
#
#        license                                           abstract  \
# 278446     unk  INTRODUCTION: Venezuela and Colombia both adop...
# 518529   no-cc  INTRODUCTION: Venezuela and Colombia both adop...
#
#        publish_time                                            authors  \
# 278446         2020  Paniz-Mondolfi, Alberto; Muñoz, Marina; Florez...
# 518529   2020-11-04  Paniz-Mondolfi, Alberto; Muñoz, Marina; Florez...
#
#                   journal mag_id who_covidence_id arxiv_id  \
# 278446  Infect Genet Evol                 #907154
# 518529  Infect Genet Evol
#
#                                            pdf_json_files  \
# 278446
# 518529  document_parses/pdf_json/d2d3b8b04378bebdde024...
#
#                                       pmc_json_files  \
# 278446
# 518529  document_parses/pmc_json/PMC7609240.xml.json
#
#                                                       url      s2_id  year  \
# 278446                                                     220444484
# 518529  https://www.ncbi.nlm.nih.gov/pubmed/33157300/;...  226238553  2020
#
#              date lineages                                id
# 278446 2020-04-22   B.1.13
# 518529 2020-11-04   B.1.13  doi:10.1016/j.meegid.2020.104616

# %%
hits.query('id != ""', inplace=True)

# %%
print("Total number of matches", hits.shape[0])
# Out:
# Total number of matches 449

# %%
hits.to_csv(NEO4J_IMPORT / "01h-CORDLineages.csv", index=False)
