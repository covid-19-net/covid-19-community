# %% [markdown]
# # Add data from GeoNames

# %% [markdown]
# **[Work in progress]**
#
# This notebook adds latitude, longitude, elevation, and population data from GeoNames to Country, Admin1, Admin2, and City .csv files for ingestion into the Knowledge Graph.
#
# Data source: [GeoNames.org](https://download.geonames.org/export/dump/)
#
# Author: Peter Rose (pwrose@ucsd.edu)

# %%
import os
from pathlib import Path
from io import BytesIO
import io
import csv
import requests
from zipfile import ZipFile
import pandas as pd

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
NEO4J_IMPORT = Path(os.getenv('NEO4J_IMPORT'))
print(NEO4J_IMPORT)
# Out:
# /Users/peter/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-19636412-9e74-4bac-8a4c-c6c8b49bb9d3/installation-4.1.0/import

# %% [markdown]
# ### Download data from GeoNames

# %%
country_url = 'https://download.geonames.org/export/dump/allCountries.zip'

# %%
content = requests.get(country_url)
zf = ZipFile(BytesIO(content.content))

for item in zf.namelist():
    print("File in zip: "+  item)
# Out:
# File in zip: allCountries.txt

# %%
# Intermediate data file is cached here
CACHE = Path(NEO4J_IMPORT / 'cache')
CACHE.mkdir(exist_ok=True)

# %% [markdown]
# ### Cache cleaned-up data
# Fix encoding and extract features for class A (country, state, region,...) and P(city, village,...)

# %%
encoding = 'utf-8'
path = CACHE / 'allCountries.csv'

# %%
try:
    with zf.open('allCountries.txt') as readfile:
        with open(path, "w") as file_out:
            writer = csv.writer(file_out)
            for line in io.TextIOWrapper(readfile, encoding):
                row = line.strip().split("\t")
                if row[6] == 'A' or row[6] == 'P':
                    writer.writerow([row[0], row[4], row[5], row[14], row[15]])
except:
    print('Download of allCountries.txt failed, using cached version of data')

# %% [markdown]
# ### Read cleaned-up data file from Cache
# If data download failed, the cached file from a previous run is used.

# %%
columns = ['geonameId', 'latitude', 'longitude', 'population', 'elevation']

# %%
df = pd.read_csv(path, names=columns, dtype='str', header=0)
df.fillna('', inplace=True)

# %%
# Missing population data are sometimes represented as zero, these will be ignored.
df['population'] = df['population'].str.replace('0', '')

# %% [markdown]
# ### Add latitude, longitude, and elevation data for countries
# Note, elevation data are excluded here since they are missing for countries.

# %%
dfc = df[['geonameId', 'latitude', 'longitude', 'population']]

# %%
dfc.head()
# Out:
#   geonameId  latitude longitude population
# 0   3038832  42.53176   1.56654
# 1   3038899  42.48597    1.4891
# 2   3038987  42.56461   1.52757
# 3   3038999  42.57688   1.66769         62
# 4   3039039  42.53695   1.58068

# %%
country = pd.read_csv(NEO4J_IMPORT / "00e-GeoNamesCountry.csv", dtype='str')

# %%
country = pd.merge(country, dfc, on='geonameId', how='left')
country.fillna('', inplace=True)

# %% [markdown]
# Fix id and iso code for Namibia (NA is interpreted as NaN in Pandas!)

# %%
# reset the id and iso code for Namibi.
index = country.query("iso3 == 'NAM'").index
country.at[index, 'iso'] = 'NA'
country.at[index, 'id'] = 'NA'

# %%
country.to_csv(NEO4J_IMPORT / "00e-GeoNamesCountry.csv", index=False)

# %%
country.head(300)
# Out:
#      id                                          name iso iso3 isoNumeric  \
# 0    AD                                       Andorra  AD  AND        020
# 1    AE                          United Arab Emirates  AE  ARE        784
# 2    AF                                   Afghanistan  AF  AFG        004
# 3    AG                           Antigua and Barbuda  AG  ATG        028
# 4    AI                                      Anguilla  AI  AIA        660
# 5    AL                                       Albania  AL  ALB        008
# 6    AM                                       Armenia  AM  ARM        051
# 7    AO                                        Angola  AO  AGO        024
# 8    AQ                                    Antarctica  AQ  ATA        010
# 9    AR                                     Argentina  AR  ARG        032
# 10   AS                                American Samoa  AS  ASM        016
# 11   AT                                       Austria  AT  AUT        040
# 12   AU                                     Australia  AU  AUS        036
# 13   AW                                         Aruba  AW  ABW        533
# 14   AX                                 Aland Islands  AX  ALA        248
# 15   AZ                                    Azerbaijan  AZ  AZE        031
# 16   BA                        Bosnia and Herzegovina  BA  BIH        070
# 17   BB                                      Barbados  BB  BRB        052
# 18   BD                                    Bangladesh  BD  BGD        050
# 19   BE                                       Belgium  BE  BEL        056
# 20   BF                                  Burkina Faso  BF  BFA        854
# 21   BG                                      Bulgaria  BG  BGR        100
# 22   BH                                       Bahrain  BH  BHR        048
# 23   BI                                       Burundi  BI  BDI        108
# 24   BJ                                         Benin  BJ  BEN        204
# 25   BL                              Saint Barthelemy  BL  BLM        652
# 26   BM                                       Bermuda  BM  BMU        060
# 27   BN                                        Brunei  BN  BRN        096
# 28   BO                                       Bolivia  BO  BOL        068
# 29   BQ            Bonaire, Saint Eustatius and Saba   BQ  BES        535
# 30   BR                                        Brazil  BR  BRA        076
# 31   BS                                       Bahamas  BS  BHS        044
# 32   BT                                        Bhutan  BT  BTN        064
# 33   BV                                 Bouvet Island  BV  BVT        074
# 34   BW                                      Botswana  BW  BWA        072
# 35   BY                                       Belarus  BY  BLR        112
# 36   BZ                                        Belize  BZ  BLZ        084
# 37   CA                                        Canada  CA  CAN        124
# 38   CC                                 Cocos Islands  CC  CCK        166
# 39   CD              Democratic Republic of the Congo  CD  COD        180
# 40   CF                      Central African Republic  CF  CAF        140
# 41   CG                         Republic of the Congo  CG  COG        178
# 42   CH                                   Switzerland  CH  CHE        756
# 43   CI                                   Ivory Coast  CI  CIV        384
# 44   CK                                  Cook Islands  CK  COK        184
# 45   CL                                         Chile  CL  CHL        152
# 46   CM                                      Cameroon  CM  CMR        120
# 47   CN                                         China  CN  CHN        156
# 48   CO                                      Colombia  CO  COL        170
# 49   CR                                    Costa Rica  CR  CRI        188
# 50   CU                                          Cuba  CU  CUB        192
# 51   CV                                    Cabo Verde  CV  CPV        132
# 52   CW                                       Curacao  CW  CUW        531
# 53   CX                              Christmas Island  CX  CXR        162
# 54   CY                                        Cyprus  CY  CYP        196
# 55   CZ                                       Czechia  CZ  CZE        203
# 56   DE                                       Germany  DE  DEU        276
# 57   DJ                                      Djibouti  DJ  DJI        262
# 58   DK                                       Denmark  DK  DNK        208
# 59   DM                                      Dominica  DM  DMA        212
# 60   DO                            Dominican Republic  DO  DOM        214
# 61   DZ                                       Algeria  DZ  DZA        012
# 62   EC                                       Ecuador  EC  ECU        218
# 63   EE                                       Estonia  EE  EST        233
# 64   EG                                         Egypt  EG  EGY        818
# 65   EH                                Western Sahara  EH  ESH        732
# 66   ER                                       Eritrea  ER  ERI        232
# 67   ES                                         Spain  ES  ESP        724
# 68   ET                                      Ethiopia  ET  ETH        231
# 69   FI                                       Finland  FI  FIN        246
# 70   FJ                                          Fiji  FJ  FJI        242
# 71   FK                              Falkland Islands  FK  FLK        238
# 72   FM                                    Micronesia  FM  FSM        583
# 73   FO                                 Faroe Islands  FO  FRO        234
# 74   FR                                        France  FR  FRA        250
# 75   GA                                         Gabon  GA  GAB        266
# 76   GB                                United Kingdom  GB  GBR        826
# 77   GD                                       Grenada  GD  GRD        308
# 78   GE                                       Georgia  GE  GEO        268
# 79   GF                                 French Guiana  GF  GUF        254
# 80   GG                                      Guernsey  GG  GGY        831
# 81   GH                                         Ghana  GH  GHA        288
# 82   GI                                     Gibraltar  GI  GIB        292
# 83   GL                                     Greenland  GL  GRL        304
# 84   GM                                        Gambia  GM  GMB        270
# 85   GN                                        Guinea  GN  GIN        324
# 86   GP                                    Guadeloupe  GP  GLP        312
# 87   GQ                             Equatorial Guinea  GQ  GNQ        226
# 88   GR                                        Greece  GR  GRC        300
# 89   GS  South Georgia and the South Sandwich Islands  GS  SGS        239
# 90   GT                                     Guatemala  GT  GTM        320
# 91   GU                                          Guam  GU  GUM        316
# 92   GW                                 Guinea-Bissau  GW  GNB        624
# 93   GY                                        Guyana  GY  GUY        328
# 94   HK                                     Hong Kong  HK  HKG        344
# 95   HM             Heard Island and McDonald Islands  HM  HMD        334
# 96   HN                                      Honduras  HN  HND        340
# 97   HR                                       Croatia  HR  HRV        191
# 98   HT                                         Haiti  HT  HTI        332
# 99   HU                                       Hungary  HU  HUN        348
# 100  ID                                     Indonesia  ID  IDN        360
# 101  IE                                       Ireland  IE  IRL        372
# 102  IL                                        Israel  IL  ISR        376
# 103  IM                                   Isle of Man  IM  IMN        833
# 104  IN                                         India  IN  IND        356
# 105  IO                British Indian Ocean Territory  IO  IOT        086
# 106  IQ                                          Iraq  IQ  IRQ        368
# 107  IR                                          Iran  IR  IRN        364
# 108  IS                                       Iceland  IS  ISL        352
# 109  IT                                         Italy  IT  ITA        380
# 110  JE                                        Jersey  JE  JEY        832
# 111  JM                                       Jamaica  JM  JAM        388
# 112  JO                                        Jordan  JO  JOR        400
# 113  JP                                         Japan  JP  JPN        392
# 114  KE                                         Kenya  KE  KEN        404
# 115  KG                                    Kyrgyzstan  KG  KGZ        417
# 116  KH                                      Cambodia  KH  KHM        116
# 117  KI                                      Kiribati  KI  KIR        296
# 118  KM                                       Comoros  KM  COM        174
# 119  KN                         Saint Kitts and Nevis  KN  KNA        659
# 120  KP                                   North Korea  KP  PRK        408
# 121  KR                                   South Korea  KR  KOR        410
# 122  XK                                        Kosovo  XK  XKX          0
# 123  KW                                        Kuwait  KW  KWT        414
# 124  KY                                Cayman Islands  KY  CYM        136
# 125  KZ                                    Kazakhstan  KZ  KAZ        398
# 126  LA                                          Laos  LA  LAO        418
# 127  LB                                       Lebanon  LB  LBN        422
# 128  LC                                   Saint Lucia  LC  LCA        662
# 129  LI                                 Liechtenstein  LI  LIE        438
# 130  LK                                     Sri Lanka  LK  LKA        144
# 131  LR                                       Liberia  LR  LBR        430
# 132  LS                                       Lesotho  LS  LSO        426
# 133  LT                                     Lithuania  LT  LTU        440
# 134  LU                                    Luxembourg  LU  LUX        442
# 135  LV                                        Latvia  LV  LVA        428
# 136  LY                                         Libya  LY  LBY        434
# 137  MA                                       Morocco  MA  MAR        504
# 138  MC                                        Monaco  MC  MCO        492
# 139  MD                                       Moldova  MD  MDA        498
# 140  ME                                    Montenegro  ME  MNE        499
# 141  MF                                  Saint Martin  MF  MAF        663
# 142  MG                                    Madagascar  MG  MDG        450
# 143  MH                              Marshall Islands  MH  MHL        584
# 144  MK                               North Macedonia  MK  MKD        807
# 145  ML                                          Mali  ML  MLI        466
# 146  MM                                       Myanmar  MM  MMR        104
# 147  MN                                      Mongolia  MN  MNG        496
# 148  MO                                         Macao  MO  MAC        446
# 149  MP                      Northern Mariana Islands  MP  MNP        580
# 150  MQ                                    Martinique  MQ  MTQ        474
# 151  MR                                    Mauritania  MR  MRT        478
# 152  MS                                    Montserrat  MS  MSR        500
# 153  MT                                         Malta  MT  MLT        470
# 154  MU                                     Mauritius  MU  MUS        480
# 155  MV                                      Maldives  MV  MDV        462
# 156  MW                                        Malawi  MW  MWI        454
# 157  MX                                        Mexico  MX  MEX        484
# 158  MY                                      Malaysia  MY  MYS        458
# 159  MZ                                    Mozambique  MZ  MOZ        508
# 160  NA                                       Namibia  NA  NAM        516
# 161  NC                                 New Caledonia  NC  NCL        540
# 162  NE                                         Niger  NE  NER        562
# 163  NF                                Norfolk Island  NF  NFK        574
# 164  NG                                       Nigeria  NG  NGA        566
# 165  NI                                     Nicaragua  NI  NIC        558
# 166  NL                                   Netherlands  NL  NLD        528
# 167  NO                                        Norway  NO  NOR        578
# 168  NP                                         Nepal  NP  NPL        524
# 169  NR                                         Nauru  NR  NRU        520
# 170  NU                                          Niue  NU  NIU        570
# 171  NZ                                   New Zealand  NZ  NZL        554
# 172  OM                                          Oman  OM  OMN        512
# 173  PA                                        Panama  PA  PAN        591
# 174  PE                                          Peru  PE  PER        604
# 175  PF                              French Polynesia  PF  PYF        258
# 176  PG                              Papua New Guinea  PG  PNG        598
# 177  PH                                   Philippines  PH  PHL        608
# 178  PK                                      Pakistan  PK  PAK        586
# 179  PL                                        Poland  PL  POL        616
# 180  PM                     Saint Pierre and Miquelon  PM  SPM        666
# 181  PN                                      Pitcairn  PN  PCN        612
# 182  PR                                   Puerto Rico  PR  PRI        630
# 183  PS                         Palestinian Territory  PS  PSE        275
# 184  PT                                      Portugal  PT  PRT        620
# 185  PW                                         Palau  PW  PLW        585
# 186  PY                                      Paraguay  PY  PRY        600
# 187  QA                                         Qatar  QA  QAT        634
# 188  RE                                       Reunion  RE  REU        638
# 189  RO                                       Romania  RO  ROU        642
# 190  RS                                        Serbia  RS  SRB        688
# 191  RU                                        Russia  RU  RUS        643
# 192  RW                                        Rwanda  RW  RWA        646
# 193  SA                                  Saudi Arabia  SA  SAU        682
# 194  SB                               Solomon Islands  SB  SLB        090
# 195  SC                                    Seychelles  SC  SYC        690
# 196  SD                                         Sudan  SD  SDN        729
# 197  SS                                   South Sudan  SS  SSD        728
# 198  SE                                        Sweden  SE  SWE        752
# 199  SG                                     Singapore  SG  SGP        702
# 200  SH                                  Saint Helena  SH  SHN        654
# 201  SI                                      Slovenia  SI  SVN        705
# 202  SJ                        Svalbard and Jan Mayen  SJ  SJM        744
# 203  SK                                      Slovakia  SK  SVK        703
# 204  SL                                  Sierra Leone  SL  SLE        694
# 205  SM                                    San Marino  SM  SMR        674
# 206  SN                                       Senegal  SN  SEN        686
# 207  SO                                       Somalia  SO  SOM        706
# 208  SR                                      Suriname  SR  SUR        740
# 209  ST                         Sao Tome and Principe  ST  STP        678
# 210  SV                                   El Salvador  SV  SLV        222
# 211  SX                                  Sint Maarten  SX  SXM        534
# 212  SY                                         Syria  SY  SYR        760
# 213  SZ                                      Eswatini  SZ  SWZ        748
# 214  TC                      Turks and Caicos Islands  TC  TCA        796
# 215  TD                                          Chad  TD  TCD        148
# 216  TF                   French Southern Territories  TF  ATF        260
# 217  TG                                          Togo  TG  TGO        768
# 218  TH                                      Thailand  TH  THA        764
# 219  TJ                                    Tajikistan  TJ  TJK        762
# 220  TK                                       Tokelau  TK  TKL        772
# 221  TL                                   Timor Leste  TL  TLS        626
# 222  TM                                  Turkmenistan  TM  TKM        795
# 223  TN                                       Tunisia  TN  TUN        788
# 224  TO                                         Tonga  TO  TON        776
# 225  TR                                        Turkey  TR  TUR        792
# 226  TT                           Trinidad and Tobago  TT  TTO        780
# 227  TV                                        Tuvalu  TV  TUV        798
# 228  TW                                        Taiwan  TW  TWN        158
# 229  TZ                                      Tanzania  TZ  TZA        834
# 230  UA                                       Ukraine  UA  UKR        804
# 231  UG                                        Uganda  UG  UGA        800
# 232  UM          United States Minor Outlying Islands  UM  UMI        581
# 233  US                                 United States  US  USA        840
# 234  UY                                       Uruguay  UY  URY        858
# 235  UZ                                    Uzbekistan  UZ  UZB        860
# 236  VA                                       Vatican  VA  VAT        336
# 237  VC              Saint Vincent and the Grenadines  VC  VCT        670
# 238  VE                                     Venezuela  VE  VEN        862
# 239  VG                        British Virgin Islands  VG  VGB        092
# 240  VI                           U.S. Virgin Islands  VI  VIR        850
# 241  VN                                       Vietnam  VN  VNM        704
# 242  VU                                       Vanuatu  VU  VUT        548
# 243  WF                             Wallis and Futuna  WF  WLF        876
# 244  WS                                         Samoa  WS  WSM        882
# 245  YE                                         Yemen  YE  YEM        887
# 246  YT                                       Mayotte  YT  MYT        175
# 247  ZA                                  South Africa  ZA  ZAF        710
# 248  ZM                                        Zambia  ZM  ZMB        894
# 249  ZW                                      Zimbabwe  ZW  ZWE        716
# 250  CS                         Serbia and Montenegro  CS  SCG        891
# 251  AN                          Netherlands Antilles  AN  ANT        530
#
#      areaSqKm geonameId   latitude   longitude population
# 0         468
# 1       82880    290557      23.75        54.5     963959
# 2      647500   1149361         33          66   37172386
# 3         443   3576396      17.05       -61.8      96286
# 4         102   3573511   18.21667      -63.05      13254
# 5       28748
# 6       29800
# 7     1246700   3351879      -12.5        18.5     389762
# 8    14000000   6697173  -82.67628     8.78906
# 9     2766890
# 10        199
# 11      83858
# 12    7686850
# 13        193   3577279       12.5   -69.96667      15845
# 14       1580
# 15      86600
# 16      51129
# 17        431
# 18     144000
# 19      30510
# 20     274200   2361809       12.5    -1.66667   19751535
# 21     110910
# 22        665
# 23      27830    433561       -3.5          30   11175378
# 24     112620   2395170        9.5        2.25    1148548
# 25         21
# 26         53
# 27       5770
# 28    1098580   3923057        -17         -65   11353142
# 29        328   7626844   12.21286   -68.29445       1812
# 30    8511965
# 31      13940   3572887   25.04082   -77.37122      38564
# 32      47000   1252634       27.5        90.5     754394
# 33         49   3371123  -54.43333         3.4
# 34     600370    933860        -22          24    2254126
# 35     207600
# 36      22966   3582678      17.25      -88.75      38371
# 37    9984670
# 38         14   1547376   -12.1642    96.87332        628
# 39    2345410    203312       -2.5        23.5     846891
# 40     622984    239880          7          21    4666377
# 41     342000   2260494         -1        15.5    5244363
# 42      41290
# 43     322460   2287781          8        -5.5    2569229
# 44        240   1899402  -21.24842  -159.78516      21388
# 45     756950
# 46     475440   2233387          6        12.5   25216237
# 47    9596960
# 48    1138910
# 49      51100
# 50     110860
# 51       4033
# 52        444   7626836   12.16667   -68.96667     159849
# 53        135
# 54       9250
# 55      78866
# 56     357021
# 57      23000    223816   11.83333        42.5      95892
# 58      43094
# 59        754   3575830       15.5   -61.33333      71625
# 60      48730
# 61    2381740
# 62     283560
# 63      45226
# 64    1001450
# 65     266000   2461445   24.49215   -12.65625       2738
# 66     121320    338010         15          39
# 67     504782
# 68    1127127
# 69     337030
# 70      18270   2205218        -18         178     883483
# 71      12173   3474414     -51.75   -59.16667       2638
# 72        702
# 73       1399
# 74     547030
# 75     267667   2400553         -1       11.75    2119275
# 76     244820
# 77        344   3580239   12.11667   -61.66667     111454
# 78      69700
# 79      91000
# 80         78
# 81     239460   2300660        8.1        -1.2    2976718
# 82        6.5   2411586   36.13333       -5.35      33718
# 83    2166086
# 84      11300   2413451       13.5       -15.5      22812
# 85     245857   2420477   10.83333   -10.66667   12414318
# 86       1780
# 87      28051   2309096        1.7        10.5     138974
# 88     131940
# 89       3903   3474415        -56         -33          3
# 90     108890
# 91        549
# 92      36120
# 93     214970   3378535          5         -59       7794
# 94       1092   1819730      22.25   114.16667       7451
# 95        412   1547314  -53.11711    73.50952
# 96     112090
# 97      56542
# 98      27750
# 99      93030
# 100   1919440
# 101     70280   2963597         53          -8     485356
# 102     20770
# 103       572
# 104   3287590
# 105        60   1282588         -6          72          4
# 106    437072
# 107   1648000
# 108    103000
# 109    301230
# 110       116
# 111     10991   3489940   18.16667      -77.25    2934855
# 112     92300
# 113    377835
# 114    582650
# 115    198500
# 116    181040
# 117       811   4030945      1.421     172.984     115847
# 118      2170    921929  -12.23333    44.44553     832322
# 119       261   3575174   17.33333      -62.75      52441
# 120    120540
# 121     98480
# 122     10908    831053   42.58333    20.91667      18453
# 123     17820
# 124       262   3580718       19.5   -80.66667      64174
# 125   2717300
# 126    236800
# 127     10400
# 128       616   3576468   13.88333   -60.96667     181889
# 129       160
# 130     65610
# 131    111370
# 132     30355
# 133     65200
# 134      2586
# 135     64589
# 136   1759540   2215636         28          17    6678567
# 137    446550
# 138      1.95
# 139     33843
# 140     14026
# 141        53
# 142    587040
# 143     181.3
# 144     25333
# 145   1240000   2453866         18          -2     197769
# 146    678500
# 147   1565000
# 148       254   1821275   22.15778   113.55972     631636
# 149       477
# 150      1100
# 151   1030700   2378080      20.25       -10.5     443319
# 152       102   3578097      16.75       -62.2       9341
# 153       316
# 154      2040    934292      -20.3    57.58333     126533
# 155       300
# 156    118480
# 157   1972550
# 158    329750
# 159    801590
# 160    825418   3355338        -22          17    2448255
# 161     19060
# 162   1267000
# 163      34.6
# 164    923768
# 165    129494
# 166     41526
# 167    324220
# 168    140800
# 169        21   2110425     -0.517     166.933       1274
# 170       260   4036232  -19.03333  -169.86667       2166
# 171    268680
# 172    212460
# 173     78200   3703430          9         -80    4176873
# 174   1285220   3932488        -10      -75.25   31989256
# 175      4167
# 176    462840
# 177    300000
# 178    803940
# 179    312685
# 180       242
# 181        47   4030699  -25.06667      -130.1         46
# 182      9104
# 183      5970   6254930   31.92157    35.20329     456987
# 184     92391
# 185       458   1559582      7.503     134.621       1797
# 186    406750
# 187     11437    289688       25.5       51.25    2781677
# 188      2517
# 189    237500
# 190     88361
# 191  17100000
# 192     26338     49518         -2          30    1231939
# 193   1960582
# 194     28450   2103350         -8         159     652858
# 195       455    241170   -4.58333    55.66667      96762
# 196   1861484
# 197    644329   7909807        7.5          30      82649
# 198    449964
# 199     692.7
# 200       410   3370751     -15.95        -5.7        746
# 201     20273
# 202     62049
# 203     48845
# 204     71740   2403846        8.5       -11.5     765154
# 205      61.2
# 206    196190
# 207    637657
# 208    163270   3382998          4         -56     575991
# 209      1001   2410758          1           7       1977
# 210     21040
# 211        21   7609695   18.04167   -63.06667       4654
# 212    185180    163843         35          38    1696283
# 213     17363
# 214       430   3576916   21.73333   -71.58333      37665
# 215   1284000   2434508         15          19   15477751
# 216      7829   1546748        -43          67         14
# 217     56785   2363686    8.66667     1.08333     788994
# 218    514000
# 219    143100
# 220        10   4031074     -9.167     -171.83       1466
# 221     15007   1966436   -8.83333      125.75    1267972
# 222    488100
# 223    163610
# 224       748   4032283        -20        -175      13197
# 225    780580
# 226      5128   3573591         11         -61    1389858
# 227        26   2110297   -8.51719   179.14478       1158
# 228     35980
# 229    945087    149590         -6          35   56318348
# 230    603700
# 231    236040    226074       1.25        32.5   42723139
# 232         0   5854968      5.875    -162.057
# 233   9629091
# 234    176220
# 235    447400
# 236      0.44
# 237       389   3577815   13.08333       -61.2      11211
# 238    912050
# 239       153   3577718       18.5       -64.5       2982
# 240       352
# 241    329560
# 242     12200   2134431        -16         167      29268
# 243       274
# 244      2944   4034894      -13.8  -172.13333      19613
# 245    527970     69543       15.5        47.5   28498687
# 246       374
# 247   1219912
# 248    752614
# 249    390580    878675        -19       29.75    1443918
# 250    102350
# 251       960   8505032   12.11721   -68.91964          3

# %% [markdown]
# ### Add latitude, longitude, elevation, and population data for admin1 divisions

# %%
admin1 = pd.read_csv(NEO4J_IMPORT / "00f-GeoNamesAdmin1.csv", dtype='str')
admin1 = pd.merge(admin1, df, on='geonameId', how='left')
admin1.fillna('', inplace=True)
admin1.to_csv(NEO4J_IMPORT / "00f-GeoNamesAdmin1.csv", index=False)

# %%
admin1.head()
# Out:
#       id                 name code parentId geonameId  latitude longitude  \
# 0  AD.06  Sant Julia de Loria   06       AD   3039162  42.46247   1.48247
# 1  AD.05               Ordino   05       AD   3039676  42.59758   1.52573
# 2  AD.04           La Massana   04       AD   3040131  42.55417   1.48333
# 3  AD.03               Encamp   03       AD   3040684  42.53333   1.63333
# 4  AD.02              Canillo   02       AD   3041203  42.58333   1.65833
#
#   population elevation
# 0       9448
# 1       3467
# 2       8953
# 3      13685
# 4        567

# %% [markdown]
# ### Add latitude, longitude, elevation, and population data for admin2 divisions

# %%
admin2 = pd.read_csv(NEO4J_IMPORT / "00g-GeoNamesAdmin2.csv", dtype='str')
admin2 = pd.merge(admin2, df, on='geonameId', how='left')
admin2.fillna('', inplace=True)
admin2.to_csv(NEO4J_IMPORT / "00g-GeoNamesAdmin2.csv", index=False)

# %%
admin2.head()
# Out:
#           id                            name geonameId parentId  latitude  \
# 0  AE.01.101          Abu Dhabi Municipality  12047239    AE.01  24.41361
# 1  AE.01.102             Al Ain Municipality  12047240    AE.01  24.15223
# 2  AE.01.103                       Al Dhafra  12047241    AE.01  23.65745
# 3  AE.04.701        Al Fujairah Municipality  12047242    AE.04  25.13557
# 4  AE.04.702  Dibba Al Fujairah Municipality  12047243    AE.04   25.5858
#
#   longitude population elevation
# 0  54.43295    1797294
# 1   55.8204     776935
# 2  53.72225     319433
# 3  56.33279     168822
# 4  56.24792      67989

# %% [markdown]
# ### Add latitude, longitude, elevation, and population data for cities

# %%
city = pd.read_csv(NEO4J_IMPORT / "00h-GeoNamesCity.csv", dtype='str')
city = pd.merge(city, df, on='geonameId', how='left')
city.fillna('', inplace=True)
city.to_csv(NEO4J_IMPORT / "00h-GeoNamesCity.csv", index=False)

# %%
city.head()
# Out:
#         id                 name   parentId geonameId  latitude longitude  \
# 0  3040051         les Escaldes      AD.08   3040051  42.50729   1.53414
# 1  3041563     Andorra la Vella      AD.07   3041563  42.50779   1.52109
# 2   290594   Umm Al Quwain City      AE.07    290594  25.56473  55.55517
# 3   291074  Ras Al Khaimah City      AE.05    291074  25.78953   55.9432
# 4   291580           Zayed City  AE.01.103    291580  23.65416  53.70522
#
#   population elevation
# 0      15853
# 1        243
# 2      62747
# 3     351943
# 4      63482
